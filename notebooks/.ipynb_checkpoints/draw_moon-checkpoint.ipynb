# %%
import csv
import ndjson
import os
import sys

# %%
base_path = os.getcwd().split('sliver-maestro')[0]
root_path = os.path.join(base_path, "sliver-maestro")
print("root_path: {}".format(root_path))
# Out:
# root_path: C:\Users\ozgur\Desktop\sandbox\sliver-maestro

# %%
sys.path.insert(1, root_path)
from src.utils.model_utils import *
from src.draw_model import *

# %%
config = ConfigParser()
config_file = "config.cfg"
config_path = os.path.join(root_path, "src", config_file)
config.read_file(open(config_path))

# %%
categories_file = os.path.join(root_path, "src", "data", "categories.csv")

# %%
with open(categories_file, newline='') as f:
    reader = csv.reader(f)
    categories = {rows[0]:rows[0] for rows in reader}

# %% [markdown]
# #### Select a category to download images from

# %%
for key, value in categories.items():
    #print(key)
    pass

# %%
print("Selected category from the list above:")
#category=input()
category='moon'
print(category)
# Out:
# Selected category from the list above:
# moon

# %%
print("Creating directories to save images, weights and the model ...")
src_list, dst_list, paths_dict = create_folders(root_path, categories, category)

for (src_file, dst_file) in zip(src_list, dst_list): 
    print('src_file: {}, dst_file: {}'.format(src_file, dst_file))
# Out:
# Creating directories to save images, weights and the model ...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\save folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\input folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\positions folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\raw folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\save\moon folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\input\moon folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\raw\moon folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon folder exists...
# src_file: gs://quickdraw_dataset/full/numpy_bitmap/moon.npy, dst_file: C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\input\moon\moon.npy
# src_file: gs://quickdraw_dataset/full/raw/moon.ndjson, dst_file: C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\raw\moon\moon.ndjson

# %%
for (src_file, dst_file) in zip(src_list, dst_list): 
    # !gsutil -m cp {src_file} {dst_file}
# Out:
# Copying gs://quickdraw_dataset/full/numpy_bitmap/moon.npy...
# / [0/1 files][    0.0 B/ 91.0 MiB]   0% Done
# -
# - [0/1 files][  3.6 MiB/ 91.0 MiB]   3% Done
# \
# |
# | [0/1 files][  9.8 MiB/ 91.0 MiB]  10% Done
# /
# / [0/1 files][ 15.2 MiB/ 91.0 MiB]  16% Done
# -
# \
# \ [0/1 files][ 21.1 MiB/ 91.0 MiB]  23% Done
# |
# /
# / [0/1 files][ 27.6 MiB/ 91.0 MiB]  30% Done
# -
# - [0/1 files][ 34.6 MiB/ 91.0 MiB]  37% Done
# \
# |
# | [0/1 files][ 41.0 MiB/ 91.0 MiB]  45% Done
# /
# -
# - [0/1 files][ 47.2 MiB/ 91.0 MiB]  51% Done
# \
# \ [0/1 files][ 52.3 MiB/ 91.0 MiB]  57% Done
# |
# /
# / [0/1 files][ 59.0 MiB/ 91.0 MiB]  64% Done
# -
# \
# \ [0/1 files][ 64.4 MiB/ 91.0 MiB]  70% Done   5.8 MiB/s ETA 00:00:05
# |
# | [0/1 files][ 71.9 MiB/ 91.0 MiB]  79% Done   6.1 MiB/s ETA 00:00:03
# /
# -
# - [0/1 files][ 78.4 MiB/ 91.0 MiB]  86% Done   6.2 MiB/s ETA 00:00:02
# \
# |
# | [0/1 files][ 83.8 MiB/ 91.0 MiB]  92% Done   6.2 MiB/s ETA 00:00:01
# /
# / [0/1 files][ 89.7 MiB/ 91.0 MiB]  98% Done   6.0 MiB/s ETA 00:00:00
# -
# - [1/1 files][ 91.0 MiB/ 91.0 MiB] 100% Done   6.1 MiB/s ETA 00:00:00
#
# Operation completed over 1 objects/91.0 MiB.
# Copying gs://quickdraw_dataset/full/raw/moon.ndjson...
# / [0/1 files][    0.0 B/315.6 MiB]   0% Done
# / [0/1 files][    0.0 B/315.6 MiB]   0% Done
# -
# \
# \ [0/1 files][  2.6 MiB/315.6 MiB]   0% Done
# |
# /
# / [0/1 files][  8.8 MiB/315.6 MiB]   2% Done
# -
# - [0/1 files][ 15.5 MiB/315.6 MiB]   4% Done
# \
# |
# | [0/1 files][ 22.2 MiB/315.6 MiB]   7% Done
# /
# -
# - [0/1 files][ 28.6 MiB/315.6 MiB]   9% Done
# \
# \ [0/1 files][ 35.6 MiB/315.6 MiB]  11% Done
# |
# /
# / [0/1 files][ 42.0 MiB/315.6 MiB]  13% Done
# -
# \
# \ [0/1 files][ 47.4 MiB/315.6 MiB]  15% Done
# |
# | [0/1 files][ 53.9 MiB/315.6 MiB]  17% Done   6.2 MiB/s ETA 00:00:42
# /
# -
# - [0/1 files][ 60.1 MiB/315.6 MiB]  19% Done   6.2 MiB/s ETA 00:00:41
# \
# \ [0/1 files][ 65.2 MiB/315.6 MiB]  20% Done   5.7 MiB/s ETA 00:00:44
# |
# /
# / [0/1 files][ 71.2 MiB/315.6 MiB]  22% Done   5.6 MiB/s ETA 00:00:43
# -
# \
# \ [0/1 files][ 77.6 MiB/315.6 MiB]  24% Done   5.8 MiB/s ETA 00:00:41
# |
# | [0/1 files][ 84.6 MiB/315.6 MiB]  26% Done   5.8 MiB/s ETA 00:00:39
# /
# -
# - [0/1 files][ 91.0 MiB/315.6 MiB]  28% Done   6.2 MiB/s ETA 00:00:36
# \
# |
# | [0/1 files][ 97.7 MiB/315.6 MiB]  30% Done   6.3 MiB/s ETA 00:00:35
# /
# / [0/1 files][103.9 MiB/315.6 MiB]  32% Done   6.4 MiB/s ETA 00:00:33
# -
# \
# \ [0/1 files][109.6 MiB/315.6 MiB]  34% Done   6.2 MiB/s ETA 00:00:33
# |
# /
# / [0/1 files][114.7 MiB/315.6 MiB]  36% Done   5.8 MiB/s ETA 00:00:34
# -
# - [0/1 files][120.4 MiB/315.6 MiB]  38% Done   5.8 MiB/s ETA 00:00:34
# \
# |
# | [0/1 files][125.8 MiB/315.6 MiB]  39% Done   5.4 MiB/s ETA 00:00:35
# /
# / [0/1 files][131.0 MiB/315.6 MiB]  41% Done   5.2 MiB/s ETA 00:00:36
# -
# \
# \ [0/1 files][136.4 MiB/315.6 MiB]  43% Done   5.2 MiB/s ETA 00:00:35
# |
# /
# / [0/1 files][143.3 MiB/315.6 MiB]  45% Done   5.6 MiB/s ETA 00:00:31
# -
# - [0/1 files][149.0 MiB/315.6 MiB]  47% Done   5.7 MiB/s ETA 00:00:29
# \
# |
# | [0/1 files][155.7 MiB/315.6 MiB]  49% Done   5.8 MiB/s ETA 00:00:27
# /
# -
# - [0/1 files][163.2 MiB/315.6 MiB]  51% Done   6.4 MiB/s ETA 00:00:24
# \
# \ [0/1 files][169.4 MiB/315.6 MiB]  53% Done   6.2 MiB/s ETA 00:00:23
# |
# /
# / [0/1 files][171.7 MiB/315.6 MiB]  54% Done   5.4 MiB/s ETA 00:00:27
# -
# \
# \ [0/1 files][177.4 MiB/315.6 MiB]  56% Done   5.4 MiB/s ETA 00:00:26
# |
# | [0/1 files][181.8 MiB/315.6 MiB]  57% Done   4.8 MiB/s ETA 00:00:28
# /
# -
# - [0/1 files][187.2 MiB/315.6 MiB]  59% Done   4.4 MiB/s ETA 00:00:29
# \
# |
# | [0/1 files][193.6 MiB/315.6 MiB]  61% Done   4.8 MiB/s ETA 00:00:25
# /
# / [0/1 files][198.8 MiB/315.6 MiB]  62% Done   5.3 MiB/s ETA 00:00:22
# -
# \
# \ [0/1 files][204.5 MiB/315.6 MiB]  64% Done   5.3 MiB/s ETA 00:00:21
# |
# /
# / [0/1 files][209.1 MiB/315.6 MiB]  66% Done   5.4 MiB/s ETA 00:00:20
# -
# - [0/1 files][214.0 MiB/315.6 MiB]  67% Done   5.2 MiB/s ETA 00:00:19
# \
# |
# | [0/1 files][218.9 MiB/315.6 MiB]  69% Done   4.9 MiB/s ETA 00:00:20
# /
# / [0/1 files][222.0 MiB/315.6 MiB]  70% Done   4.5 MiB/s ETA 00:00:21
# -
# \
# \ [0/1 files][227.2 MiB/315.6 MiB]  71% Done   4.4 MiB/s ETA 00:00:20
# |
# /
# / [0/1 files][231.8 MiB/315.6 MiB]  73% Done   4.4 MiB/s ETA 00:00:19
# -
# - [0/1 files][235.4 MiB/315.6 MiB]  74% Done   4.0 MiB/s ETA 00:00:20
# \
# |
# | [0/1 files][240.3 MiB/315.6 MiB]  76% Done   4.4 MiB/s ETA 00:00:17
# /
# -
# - [0/1 files][245.0 MiB/315.6 MiB]  77% Done   4.4 MiB/s ETA 00:00:16
# \
# \ [0/1 files][251.1 MiB/315.6 MiB]  79% Done   4.8 MiB/s ETA 00:00:14
# |
# /
# / [0/1 files][258.4 MiB/315.6 MiB]  81% Done   5.2 MiB/s ETA 00:00:11
# -
# - [0/1 files][264.5 MiB/315.6 MiB]  83% Done   5.8 MiB/s ETA 00:00:09
# \
# |
# | [0/1 files][268.7 MiB/315.6 MiB]  85% Done   5.6 MiB/s ETA 00:00:08
# /
# / [0/1 files][273.0 MiB/315.6 MiB]  86% Done   5.5 MiB/s ETA 00:00:08
# -
# \
# \ [0/1 files][279.5 MiB/315.6 MiB]  88% Done   5.5 MiB/s ETA 00:00:07
# |
# /
# / [0/1 files][285.4 MiB/315.6 MiB]  90% Done   5.2 MiB/s ETA 00:00:06
# -
# - [0/1 files][291.6 MiB/315.6 MiB]  92% Done   5.3 MiB/s ETA 00:00:05
# \
# |
# | [0/1 files][297.0 MiB/315.6 MiB]  94% Done   5.8 MiB/s ETA 00:00:03
# /
# -
# - [0/1 files][300.9 MiB/315.6 MiB]  95% Done   5.4 MiB/s ETA 00:00:03
# \
# \ [0/1 files][305.8 MiB/315.6 MiB]  96% Done   5.1 MiB/s ETA 00:00:02
# |
# /
# / [0/1 files][311.2 MiB/315.6 MiB]  98% Done   5.0 MiB/s ETA 00:00:01
# -
# - [0/1 files][315.3 MiB/315.6 MiB]  99% Done   4.7 MiB/s ETA 00:00:00
# \
# \ [1/1 files][315.6 MiB/315.6 MiB] 100% Done   4.6 MiB/s ETA 00:00:00
#
# Operation completed over 1 objects/315.6 MiB.

# %%
npy_data = np.load(paths_dict['base_input'] + '.npy', allow_pickle=True)

# %%
# load from file-like objects
with open(paths_dict['base_raw'] + '.ndjson') as f:
    ndjson_data = ndjson.load(f)

# %%
def plot_bitmap():
    print("Bitmap image:")
    plt.imshow(npy_data[int(index)].reshape(28,28))

# %%
def plot_raw():
    print("Raw image:")
    i = 0
    for stroke in ndjson_data[int(index)]['drawing']:
        stroke = np.array(stroke)
        plt.plot(stroke[0], stroke[1]*-1)
        i += 1
    print('There are', i, 'number of strokes in this raw image file!')

# %%
print('There are ', len(npy_data)+1, ' images in selected category', categories[category])
print("Select an index value from 0 to", len(npy_data), "to display and compare bitmap and raw images:")
#index=input()
index='0'
plot_bitmap()
plt.show()
plot_raw()
# Out:
# There are  121662  images in selected category moon
# Select an index value from 0 to 121661 to display and compare bitmap and raw images:
# Bitmap image:
# Raw image:
# There are 1 number of strokes in this raw image file!

# %%
# TRAIN TEST SPLIT
filepath = paths_dict['input_path']
x_train, x_test, y_train, y_test = split_data(filepath, categories[category], shuffle=False)

# %%
T = int(config['DRAW']['T'])
batch_size = int(config['DRAW']['batch_size'])
A = int(config['DRAW']['A'])
B = int(config['DRAW']['B'])
z_size = int(config['DRAW']['z_size'])
N = int(config['DRAW']['N'])
dec_size = int(config['DRAW']['dec_size'])
enc_size = int(config['DRAW']['enc_size'])
epoch_num = int(config['DRAW']['epoch_num'])
learning_rate = float(config['DRAW']['learning_rate'])
beta1 = float(config['DRAW']['beta1'])
USE_CUDA = eval(config['DRAW']['USE_CUDA'])
clip = float(config['DRAW']['clip'])
path = os.path.join(root_path, "src", config['DRAW']['path'])
image_output_file=os.path.join(root_path, "src", config['DRAW']['image_output_file'])
base_img_name=os.path.join(root_path, "src", config['DRAW']['base_img_name'])

# %%
# TRAINING AND TESTING

train_data = Dataset(x_train)
print('training data length:', int(len(train_data.data)/batch_size))

test_data = Dataset(x_test)
print('test data length:', int(len(test_data.data)/batch_size))

model = DRAW(T, A, B, batch_size, z_size, N, dec_size, enc_size, learning_rate, beta1, clip, path, category)

if USE_CUDA:
    model.cuda()

def train():
    print("training...")
    img_loc = {'startr':0,
               'endr':30,
               'startc':0,
               'endc':30}
    model.start(img_loc, epoch_num, phase='train') 

def test():    
    print("testing...")
    img_loc = {'startr':0,
               'endr':30,
               'startc':0,
               'endc':30}    
    model.start(img_loc, epoch_num, phase='test')
# Out:
# training data length: 1520
# test data length: 380

# %%
#epoch_num = 1

# %%
# TRAINING
train()
# Out:
# training...
# start, end:0, 64
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\draw_model.py:221: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(self.parameters(), self.clip)
# start, end:64, 128
# start, end:128, 192
# start, end:192, 256
# start, end:256, 320
# start, end:320, 384
# start, end:384, 448
# start, end:448, 512
# start, end:512, 576
# start, end:576, 640
# start, end:640, 704
# start, end:704, 768
# start, end:768, 832
# start, end:832, 896
# start, end:896, 960
# start, end:960, 1024
# start, end:1024, 1088
# start, end:1088, 1152
# start, end:1152, 1216
# start, end:1216, 1280
# start, end:1280, 1344
# start, end:1344, 1408
# start, end:1408, 1472
# start, end:1472, 1536
# start, end:1536, 1600
# start, end:1600, 1664
# start, end:1664, 1728
# start, end:1728, 1792
# start, end:1792, 1856
# start, end:1856, 1920
# start, end:1920, 1984
# start, end:1984, 2048
# start, end:2048, 2112
# start, end:2112, 2176
# start, end:2176, 2240
# start, end:2240, 2304
# start, end:2304, 2368
# start, end:2368, 2432
# start, end:2432, 2496
# start, end:2496, 2560
# start, end:2560, 2624
# start, end:2624, 2688
# start, end:2688, 2752
# start, end:2752, 2816
# start, end:2816, 2880
# start, end:2880, 2944
# start, end:2944, 3008
# start, end:3008, 3072
# start, end:3072, 3136
# start, end:3136, 3200
# start, end:3200, 3264
# start, end:3264, 3328
# start, end:3328, 3392
# start, end:3392, 3456
# start, end:3456, 3520
# start, end:3520, 3584
# start, end:3584, 3648
# start, end:3648, 3712
# start, end:3712, 3776
# start, end:3776, 3840
# start, end:3840, 3904
# start, end:3904, 3968
# start, end:3968, 4032
# start, end:4032, 4096
# start, end:4096, 4160
# start, end:4160, 4224
# start, end:4224, 4288
# start, end:4288, 4352
# start, end:4352, 4416
# start, end:4416, 4480
# start, end:4480, 4544
# start, end:4544, 4608
# start, end:4608, 4672
# start, end:4672, 4736
# start, end:4736, 4800
# start, end:4800, 4864
# start, end:4864, 4928
# start, end:4928, 4992
# start, end:4992, 5056
# start, end:5056, 5120
# start, end:5120, 5184
# start, end:5184, 5248
# start, end:5248, 5312
# start, end:5312, 5376
# start, end:5376, 5440
# start, end:5440, 5504
# start, end:5504, 5568
# start, end:5568, 5632
# start, end:5632, 5696
# start, end:5696, 5760
# start, end:5760, 5824
# start, end:5824, 5888
# start, end:5888, 5952
# start, end:5952, 6016
# start, end:6016, 6080
# start, end:6080, 6144
# start, end:6144, 6208
# start, end:6208, 6272
# start, end:6272, 6336
# start, end:6336, 6400
# Phase: train | Epoch: 0 | Count: 100 \ Start Time: 21:14:38 | Loss: 331
# start, end:6400, 6464
# start, end:6464, 6528
# start, end:6528, 6592
# start, end:6592, 6656
# start, end:6656, 6720
# start, end:6720, 6784
# start, end:6784, 6848
# start, end:6848, 6912
# start, end:6912, 6976
# start, end:6976, 7040
# start, end:7040, 7104
# start, end:7104, 7168
# start, end:7168, 7232
# start, end:7232, 7296
# start, end:7296, 7360
# start, end:7360, 7424
# start, end:7424, 7488
# start, end:7488, 7552
# start, end:7552, 7616
# start, end:7616, 7680
# start, end:7680, 7744
# start, end:7744, 7808
# start, end:7808, 7872
# start, end:7872, 7936
# start, end:7936, 8000
# start, end:8000, 8064
# start, end:8064, 8128
# start, end:8128, 8192
# start, end:8192, 8256
# start, end:8256, 8320
# start, end:8320, 8384
# start, end:8384, 8448
# start, end:8448, 8512
# start, end:8512, 8576
# start, end:8576, 8640
# start, end:8640, 8704
# start, end:8704, 8768
# start, end:8768, 8832
# start, end:8832, 8896
# start, end:8896, 8960
# start, end:8960, 9024
# start, end:9024, 9088
# start, end:9088, 9152
# start, end:9152, 9216
# start, end:9216, 9280
# start, end:9280, 9344
# start, end:9344, 9408
# start, end:9408, 9472
# start, end:9472, 9536
# start, end:9536, 9600
# start, end:9600, 9664
# start, end:9664, 9728
# start, end:9728, 9792
# start, end:9792, 9856
# start, end:9856, 9920
# start, end:9920, 9984
# start, end:9984, 10048
# start, end:10048, 10112
# start, end:10112, 10176
# start, end:10176, 10240
# start, end:10240, 10304
# start, end:10304, 10368
# start, end:10368, 10432
# start, end:10432, 10496
# start, end:10496, 10560
# start, end:10560, 10624
# start, end:10624, 10688
# start, end:10688, 10752
# start, end:10752, 10816
# start, end:10816, 10880
# start, end:10880, 10944
# start, end:10944, 11008
# start, end:11008, 11072
# start, end:11072, 11136
# start, end:11136, 11200
# start, end:11200, 11264
# start, end:11264, 11328
# start, end:11328, 11392
# start, end:11392, 11456
# start, end:11456, 11520
# start, end:11520, 11584
# start, end:11584, 11648
# start, end:11648, 11712
# start, end:11712, 11776
# start, end:11776, 11840
# start, end:11840, 11904
# start, end:11904, 11968
# start, end:11968, 12032
# start, end:12032, 12096
# start, end:12096, 12160
# start, end:12160, 12224
# start, end:12224, 12288
# start, end:12288, 12352
# start, end:12352, 12416
# start, end:12416, 12480
# start, end:12480, 12544
# start, end:12544, 12608
# start, end:12608, 12672
# start, end:12672, 12736
# start, end:12736, 12800
# Phase: train | Epoch: 0 | Count: 200 \ Start Time: 21:15:10 | Loss: 292
# start, end:12800, 12864
# start, end:12864, 12928
# start, end:12928, 12992
# start, end:12992, 13056
# start, end:13056, 13120
# start, end:13120, 13184
# start, end:13184, 13248
# start, end:13248, 13312
# start, end:13312, 13376
# start, end:13376, 13440
# start, end:13440, 13504
# start, end:13504, 13568
# start, end:13568, 13632
# start, end:13632, 13696
# start, end:13696, 13760
# start, end:13760, 13824
# start, end:13824, 13888
# start, end:13888, 13952
# start, end:13952, 14016
# start, end:14016, 14080
# start, end:14080, 14144
# start, end:14144, 14208
# start, end:14208, 14272
# start, end:14272, 14336
# start, end:14336, 14400
# start, end:14400, 14464
# start, end:14464, 14528
# start, end:14528, 14592
# start, end:14592, 14656
# start, end:14656, 14720
# start, end:14720, 14784
# start, end:14784, 14848
# start, end:14848, 14912
# start, end:14912, 14976
# start, end:14976, 15040
# start, end:15040, 15104
# start, end:15104, 15168
# start, end:15168, 15232
# start, end:15232, 15296
# start, end:15296, 15360
# start, end:15360, 15424
# start, end:15424, 15488
# start, end:15488, 15552
# start, end:15552, 15616
# start, end:15616, 15680
# start, end:15680, 15744
# start, end:15744, 15808
# start, end:15808, 15872
# start, end:15872, 15936
# start, end:15936, 16000
# start, end:16000, 16064
# start, end:16064, 16128
# start, end:16128, 16192
# start, end:16192, 16256
# start, end:16256, 16320
# start, end:16320, 16384
# start, end:16384, 16448
# start, end:16448, 16512
# start, end:16512, 16576
# start, end:16576, 16640
# start, end:16640, 16704
# start, end:16704, 16768
# start, end:16768, 16832
# start, end:16832, 16896
# start, end:16896, 16960
# start, end:16960, 17024
# start, end:17024, 17088
# start, end:17088, 17152
# start, end:17152, 17216
# start, end:17216, 17280
# start, end:17280, 17344
# start, end:17344, 17408
# start, end:17408, 17472
# start, end:17472, 17536
# start, end:17536, 17600
# start, end:17600, 17664
# start, end:17664, 17728
# start, end:17728, 17792
# start, end:17792, 17856
# start, end:17856, 17920
# start, end:17920, 17984
# start, end:17984, 18048
# start, end:18048, 18112
# start, end:18112, 18176
# start, end:18176, 18240
# start, end:18240, 18304
# start, end:18304, 18368
# start, end:18368, 18432
# start, end:18432, 18496
# start, end:18496, 18560
# start, end:18560, 18624
# start, end:18624, 18688
# start, end:18688, 18752
# start, end:18752, 18816
# start, end:18816, 18880
# start, end:18880, 18944
# start, end:18944, 19008
# start, end:19008, 19072
# start, end:19072, 19136
# start, end:19136, 19200
# Phase: train | Epoch: 0 | Count: 300 \ Start Time: 21:15:43 | Loss: 289
# start, end:19200, 19264
# start, end:19264, 19328
# start, end:19328, 19392
# start, end:19392, 19456
# start, end:19456, 19520
# start, end:19520, 19584
# start, end:19584, 19648
# start, end:19648, 19712
# start, end:19712, 19776
# start, end:19776, 19840
# start, end:19840, 19904
# start, end:19904, 19968
# start, end:19968, 20032
# start, end:20032, 20096
# start, end:20096, 20160
# start, end:20160, 20224
# start, end:20224, 20288
# start, end:20288, 20352
# start, end:20352, 20416
# start, end:20416, 20480
# start, end:20480, 20544
# start, end:20544, 20608
# start, end:20608, 20672
# start, end:20672, 20736
# start, end:20736, 20800
# start, end:20800, 20864
# start, end:20864, 20928
# start, end:20928, 20992
# start, end:20992, 21056
# start, end:21056, 21120
# start, end:21120, 21184
# start, end:21184, 21248
# start, end:21248, 21312
# start, end:21312, 21376
# start, end:21376, 21440
# start, end:21440, 21504
# start, end:21504, 21568
# start, end:21568, 21632
# start, end:21632, 21696
# start, end:21696, 21760
# start, end:21760, 21824
# start, end:21824, 21888
# start, end:21888, 21952
# start, end:21952, 22016
# start, end:22016, 22080
# start, end:22080, 22144
# start, end:22144, 22208
# start, end:22208, 22272
# start, end:22272, 22336
# start, end:22336, 22400
# start, end:22400, 22464
# start, end:22464, 22528
# start, end:22528, 22592
# start, end:22592, 22656
# start, end:22656, 22720
# start, end:22720, 22784
# start, end:22784, 22848
# start, end:22848, 22912
# start, end:22912, 22976
# start, end:22976, 23040
# start, end:23040, 23104
# start, end:23104, 23168
# start, end:23168, 23232
# start, end:23232, 23296
# start, end:23296, 23360
# start, end:23360, 23424
# start, end:23424, 23488
# start, end:23488, 23552
# start, end:23552, 23616
# start, end:23616, 23680
# start, end:23680, 23744
# start, end:23744, 23808
# start, end:23808, 23872
# start, end:23872, 23936
# start, end:23936, 24000
# start, end:24000, 24064
# start, end:24064, 24128
# start, end:24128, 24192
# start, end:24192, 24256
# start, end:24256, 24320
# start, end:24320, 24384
# start, end:24384, 24448
# start, end:24448, 24512
# start, end:24512, 24576
# start, end:24576, 24640
# start, end:24640, 24704
# start, end:24704, 24768
# start, end:24768, 24832
# start, end:24832, 24896
# start, end:24896, 24960
# start, end:24960, 25024
# start, end:25024, 25088
# start, end:25088, 25152
# start, end:25152, 25216
# start, end:25216, 25280
# start, end:25280, 25344
# start, end:25344, 25408
# start, end:25408, 25472
# start, end:25472, 25536
# start, end:25536, 25600
# Phase: train | Epoch: 0 | Count: 400 \ Start Time: 21:16:16 | Loss: 281
# start, end:25600, 25664
# start, end:25664, 25728
# start, end:25728, 25792
# start, end:25792, 25856
# start, end:25856, 25920
# start, end:25920, 25984
# start, end:25984, 26048
# start, end:26048, 26112
# start, end:26112, 26176
# start, end:26176, 26240
# start, end:26240, 26304
# start, end:26304, 26368
# start, end:26368, 26432
# start, end:26432, 26496
# start, end:26496, 26560
# start, end:26560, 26624
# start, end:26624, 26688
# start, end:26688, 26752
# start, end:26752, 26816
# start, end:26816, 26880
# start, end:26880, 26944
# start, end:26944, 27008
# start, end:27008, 27072
# start, end:27072, 27136
# start, end:27136, 27200
# start, end:27200, 27264
# start, end:27264, 27328
# start, end:27328, 27392
# start, end:27392, 27456
# start, end:27456, 27520
# start, end:27520, 27584
# start, end:27584, 27648
# start, end:27648, 27712
# start, end:27712, 27776
# start, end:27776, 27840
# start, end:27840, 27904
# start, end:27904, 27968
# start, end:27968, 28032
# start, end:28032, 28096
# start, end:28096, 28160
# start, end:28160, 28224
# start, end:28224, 28288
# start, end:28288, 28352
# start, end:28352, 28416
# start, end:28416, 28480
# start, end:28480, 28544
# start, end:28544, 28608
# start, end:28608, 28672
# start, end:28672, 28736
# start, end:28736, 28800
# start, end:28800, 28864
# start, end:28864, 28928
# start, end:28928, 28992
# start, end:28992, 29056
# start, end:29056, 29120
# start, end:29120, 29184
# start, end:29184, 29248
# start, end:29248, 29312
# start, end:29312, 29376
# start, end:29376, 29440
# start, end:29440, 29504
# start, end:29504, 29568
# start, end:29568, 29632
# start, end:29632, 29696
# start, end:29696, 29760
# start, end:29760, 29824
# start, end:29824, 29888
# start, end:29888, 29952
# start, end:29952, 30016
# start, end:30016, 30080
# start, end:30080, 30144
# start, end:30144, 30208
# start, end:30208, 30272
# start, end:30272, 30336
# start, end:30336, 30400
# start, end:30400, 30464
# start, end:30464, 30528
# start, end:30528, 30592
# start, end:30592, 30656
# start, end:30656, 30720
# start, end:30720, 30784
# start, end:30784, 30848
# start, end:30848, 30912
# start, end:30912, 30976
# start, end:30976, 31040
# start, end:31040, 31104
# start, end:31104, 31168
# start, end:31168, 31232
# start, end:31232, 31296
# start, end:31296, 31360
# start, end:31360, 31424
# start, end:31424, 31488
# start, end:31488, 31552
# start, end:31552, 31616
# start, end:31616, 31680
# start, end:31680, 31744
# start, end:31744, 31808
# start, end:31808, 31872
# start, end:31872, 31936
# start, end:31936, 32000
# Phase: train | Epoch: 0 | Count: 500 \ Start Time: 21:16:49 | Loss: 272
# start, end:32000, 32064
# start, end:32064, 32128
# start, end:32128, 32192
# start, end:32192, 32256
# start, end:32256, 32320
# start, end:32320, 32384
# start, end:32384, 32448
# start, end:32448, 32512
# start, end:32512, 32576
# start, end:32576, 32640
# start, end:32640, 32704
# start, end:32704, 32768
# start, end:32768, 32832
# start, end:32832, 32896
# start, end:32896, 32960
# start, end:32960, 33024
# start, end:33024, 33088
# start, end:33088, 33152
# start, end:33152, 33216
# start, end:33216, 33280
# start, end:33280, 33344
# start, end:33344, 33408
# start, end:33408, 33472
# start, end:33472, 33536
# start, end:33536, 33600
# start, end:33600, 33664
# start, end:33664, 33728
# start, end:33728, 33792
# start, end:33792, 33856
# start, end:33856, 33920
# start, end:33920, 33984
# start, end:33984, 34048
# start, end:34048, 34112
# start, end:34112, 34176
# start, end:34176, 34240
# start, end:34240, 34304
# start, end:34304, 34368
# start, end:34368, 34432
# start, end:34432, 34496
# start, end:34496, 34560
# start, end:34560, 34624
# start, end:34624, 34688
# start, end:34688, 34752
# start, end:34752, 34816
# start, end:34816, 34880
# start, end:34880, 34944
# start, end:34944, 35008
# start, end:35008, 35072
# start, end:35072, 35136
# start, end:35136, 35200
# start, end:35200, 35264
# start, end:35264, 35328
# start, end:35328, 35392
# start, end:35392, 35456
# start, end:35456, 35520
# start, end:35520, 35584
# start, end:35584, 35648
# start, end:35648, 35712
# start, end:35712, 35776
# start, end:35776, 35840
# start, end:35840, 35904
# start, end:35904, 35968
# start, end:35968, 36032
# start, end:36032, 36096
# start, end:36096, 36160
# start, end:36160, 36224
# start, end:36224, 36288
# start, end:36288, 36352
# start, end:36352, 36416
# start, end:36416, 36480
# start, end:36480, 36544
# start, end:36544, 36608
# start, end:36608, 36672
# start, end:36672, 36736
# start, end:36736, 36800
# start, end:36800, 36864
# start, end:36864, 36928
# start, end:36928, 36992
# start, end:36992, 37056
# start, end:37056, 37120
# start, end:37120, 37184
# start, end:37184, 37248
# start, end:37248, 37312
# start, end:37312, 37376
# start, end:37376, 37440
# start, end:37440, 37504
# start, end:37504, 37568
# start, end:37568, 37632
# start, end:37632, 37696
# start, end:37696, 37760
# start, end:37760, 37824
# start, end:37824, 37888
# start, end:37888, 37952
# start, end:37952, 38016
# start, end:38016, 38080
# start, end:38080, 38144
# start, end:38144, 38208
# start, end:38208, 38272
# start, end:38272, 38336
# start, end:38336, 38400
# Phase: train | Epoch: 0 | Count: 600 \ Start Time: 21:17:23 | Loss: 266
# start, end:38400, 38464
# start, end:38464, 38528
# start, end:38528, 38592
# start, end:38592, 38656
# start, end:38656, 38720
# start, end:38720, 38784
# start, end:38784, 38848
# start, end:38848, 38912
# start, end:38912, 38976
# start, end:38976, 39040
# start, end:39040, 39104
# start, end:39104, 39168
# start, end:39168, 39232
# start, end:39232, 39296
# start, end:39296, 39360
# start, end:39360, 39424
# start, end:39424, 39488
# start, end:39488, 39552
# start, end:39552, 39616
# start, end:39616, 39680
# start, end:39680, 39744
# start, end:39744, 39808
# start, end:39808, 39872
# start, end:39872, 39936
# start, end:39936, 40000
# start, end:40000, 40064
# start, end:40064, 40128
# start, end:40128, 40192
# start, end:40192, 40256
# start, end:40256, 40320
# start, end:40320, 40384
# start, end:40384, 40448
# start, end:40448, 40512
# start, end:40512, 40576
# start, end:40576, 40640
# start, end:40640, 40704
# start, end:40704, 40768
# start, end:40768, 40832
# start, end:40832, 40896
# start, end:40896, 40960
# start, end:40960, 41024
# start, end:41024, 41088
# start, end:41088, 41152
# start, end:41152, 41216
# start, end:41216, 41280
# start, end:41280, 41344
# start, end:41344, 41408
# start, end:41408, 41472
# start, end:41472, 41536
# start, end:41536, 41600
# start, end:41600, 41664
# start, end:41664, 41728
# start, end:41728, 41792
# start, end:41792, 41856
# start, end:41856, 41920
# start, end:41920, 41984
# start, end:41984, 42048
# start, end:42048, 42112
# start, end:42112, 42176
# start, end:42176, 42240
# start, end:42240, 42304
# start, end:42304, 42368
# start, end:42368, 42432
# start, end:42432, 42496
# start, end:42496, 42560
# start, end:42560, 42624
# start, end:42624, 42688
# start, end:42688, 42752
# start, end:42752, 42816
# start, end:42816, 42880
# start, end:42880, 42944
# start, end:42944, 43008
# start, end:43008, 43072
# start, end:43072, 43136
# start, end:43136, 43200
# start, end:43200, 43264
# start, end:43264, 43328
# start, end:43328, 43392
# start, end:43392, 43456
# start, end:43456, 43520
# start, end:43520, 43584
# start, end:43584, 43648
# start, end:43648, 43712
# start, end:43712, 43776
# start, end:43776, 43840
# start, end:43840, 43904
# start, end:43904, 43968
# start, end:43968, 44032
# start, end:44032, 44096
# start, end:44096, 44160
# start, end:44160, 44224
# start, end:44224, 44288
# start, end:44288, 44352
# start, end:44352, 44416
# start, end:44416, 44480
# start, end:44480, 44544
# start, end:44544, 44608
# start, end:44608, 44672
# start, end:44672, 44736
# start, end:44736, 44800
# Phase: train | Epoch: 0 | Count: 700 \ Start Time: 21:17:56 | Loss: 265
# start, end:44800, 44864
# start, end:44864, 44928
# start, end:44928, 44992
# start, end:44992, 45056
# start, end:45056, 45120
# start, end:45120, 45184
# start, end:45184, 45248
# start, end:45248, 45312
# start, end:45312, 45376
# start, end:45376, 45440
# start, end:45440, 45504
# start, end:45504, 45568
# start, end:45568, 45632
# start, end:45632, 45696
# start, end:45696, 45760
# start, end:45760, 45824
# start, end:45824, 45888
# start, end:45888, 45952
# start, end:45952, 46016
# start, end:46016, 46080
# start, end:46080, 46144
# start, end:46144, 46208
# start, end:46208, 46272
# start, end:46272, 46336
# start, end:46336, 46400
# start, end:46400, 46464
# start, end:46464, 46528
# start, end:46528, 46592
# start, end:46592, 46656
# start, end:46656, 46720
# start, end:46720, 46784
# start, end:46784, 46848
# start, end:46848, 46912
# start, end:46912, 46976
# start, end:46976, 47040
# start, end:47040, 47104
# start, end:47104, 47168
# start, end:47168, 47232
# start, end:47232, 47296
# start, end:47296, 47360
# start, end:47360, 47424
# start, end:47424, 47488
# start, end:47488, 47552
# start, end:47552, 47616
# start, end:47616, 47680
# start, end:47680, 47744
# start, end:47744, 47808
# start, end:47808, 47872
# start, end:47872, 47936
# start, end:47936, 48000
# start, end:48000, 48064
# start, end:48064, 48128
# start, end:48128, 48192
# start, end:48192, 48256
# start, end:48256, 48320
# start, end:48320, 48384
# start, end:48384, 48448
# start, end:48448, 48512
# start, end:48512, 48576
# start, end:48576, 48640
# start, end:48640, 48704
# start, end:48704, 48768
# start, end:48768, 48832
# start, end:48832, 48896
# start, end:48896, 48960
# start, end:48960, 49024
# start, end:49024, 49088
# start, end:49088, 49152
# start, end:49152, 49216
# start, end:49216, 49280
# start, end:49280, 49344
# start, end:49344, 49408
# start, end:49408, 49472
# start, end:49472, 49536
# start, end:49536, 49600
# start, end:49600, 49664
# start, end:49664, 49728
# start, end:49728, 49792
# start, end:49792, 49856
# start, end:49856, 49920
# start, end:49920, 49984
# start, end:49984, 50048
# start, end:50048, 50112
# start, end:50112, 50176
# start, end:50176, 50240
# start, end:50240, 50304
# start, end:50304, 50368
# start, end:50368, 50432
# start, end:50432, 50496
# start, end:50496, 50560
# start, end:50560, 50624
# start, end:50624, 50688
# start, end:50688, 50752
# start, end:50752, 50816
# start, end:50816, 50880
# start, end:50880, 50944
# start, end:50944, 51008
# start, end:51008, 51072
# start, end:51072, 51136
# start, end:51136, 51200
# Phase: train | Epoch: 0 | Count: 800 \ Start Time: 21:18:29 | Loss: 257
# start, end:51200, 51264
# start, end:51264, 51328
# start, end:51328, 51392
# start, end:51392, 51456
# start, end:51456, 51520
# start, end:51520, 51584
# start, end:51584, 51648
# start, end:51648, 51712
# start, end:51712, 51776
# start, end:51776, 51840
# start, end:51840, 51904
# start, end:51904, 51968
# start, end:51968, 52032
# start, end:52032, 52096
# start, end:52096, 52160
# start, end:52160, 52224
# start, end:52224, 52288
# start, end:52288, 52352
# start, end:52352, 52416
# start, end:52416, 52480
# start, end:52480, 52544
# start, end:52544, 52608
# start, end:52608, 52672
# start, end:52672, 52736
# start, end:52736, 52800
# start, end:52800, 52864
# start, end:52864, 52928
# start, end:52928, 52992
# start, end:52992, 53056
# start, end:53056, 53120
# start, end:53120, 53184
# start, end:53184, 53248
# start, end:53248, 53312
# start, end:53312, 53376
# start, end:53376, 53440
# start, end:53440, 53504
# start, end:53504, 53568
# start, end:53568, 53632
# start, end:53632, 53696
# start, end:53696, 53760
# start, end:53760, 53824
# start, end:53824, 53888
# start, end:53888, 53952
# start, end:53952, 54016
# start, end:54016, 54080
# start, end:54080, 54144
# start, end:54144, 54208
# start, end:54208, 54272
# start, end:54272, 54336
# start, end:54336, 54400
# start, end:54400, 54464
# start, end:54464, 54528
# start, end:54528, 54592
# start, end:54592, 54656
# start, end:54656, 54720
# start, end:54720, 54784
# start, end:54784, 54848
# start, end:54848, 54912
# start, end:54912, 54976
# start, end:54976, 55040
# start, end:55040, 55104
# start, end:55104, 55168
# start, end:55168, 55232
# start, end:55232, 55296
# start, end:55296, 55360
# start, end:55360, 55424
# start, end:55424, 55488
# start, end:55488, 55552
# start, end:55552, 55616
# start, end:55616, 55680
# start, end:55680, 55744
# start, end:55744, 55808
# start, end:55808, 55872
# start, end:55872, 55936
# start, end:55936, 56000
# start, end:56000, 56064
# start, end:56064, 56128
# start, end:56128, 56192
# start, end:56192, 56256
# start, end:56256, 56320
# start, end:56320, 56384
# start, end:56384, 56448
# start, end:56448, 56512
# start, end:56512, 56576
# start, end:56576, 56640
# start, end:56640, 56704
# start, end:56704, 56768
# start, end:56768, 56832
# start, end:56832, 56896
# start, end:56896, 56960
# start, end:56960, 57024
# start, end:57024, 57088
# start, end:57088, 57152
# start, end:57152, 57216
# start, end:57216, 57280
# start, end:57280, 57344
# start, end:57344, 57408
# start, end:57408, 57472
# start, end:57472, 57536
# start, end:57536, 57600
# Phase: train | Epoch: 0 | Count: 900 \ Start Time: 21:19:02 | Loss: 253
# start, end:57600, 57664
# start, end:57664, 57728
# start, end:57728, 57792
# start, end:57792, 57856
# start, end:57856, 57920
# start, end:57920, 57984
# start, end:57984, 58048
# start, end:58048, 58112
# start, end:58112, 58176
# start, end:58176, 58240
# start, end:58240, 58304
# start, end:58304, 58368
# start, end:58368, 58432
# start, end:58432, 58496
# start, end:58496, 58560
# start, end:58560, 58624
# start, end:58624, 58688
# start, end:58688, 58752
# start, end:58752, 58816
# start, end:58816, 58880
# start, end:58880, 58944
# start, end:58944, 59008
# start, end:59008, 59072
# start, end:59072, 59136
# start, end:59136, 59200
# start, end:59200, 59264
# start, end:59264, 59328
# start, end:59328, 59392
# start, end:59392, 59456
# start, end:59456, 59520
# start, end:59520, 59584
# start, end:59584, 59648
# start, end:59648, 59712
# start, end:59712, 59776
# start, end:59776, 59840
# start, end:59840, 59904
# start, end:59904, 59968
# start, end:59968, 60032
# start, end:60032, 60096
# start, end:60096, 60160
# start, end:60160, 60224
# start, end:60224, 60288
# start, end:60288, 60352
# start, end:60352, 60416
# start, end:60416, 60480
# start, end:60480, 60544
# start, end:60544, 60608
# start, end:60608, 60672
# start, end:60672, 60736
# start, end:60736, 60800
# start, end:60800, 60864
# start, end:60864, 60928
# start, end:60928, 60992
# start, end:60992, 61056
# start, end:61056, 61120
# start, end:61120, 61184
# start, end:61184, 61248
# start, end:61248, 61312
# start, end:61312, 61376
# start, end:61376, 61440
# start, end:61440, 61504
# start, end:61504, 61568
# start, end:61568, 61632
# start, end:61632, 61696
# start, end:61696, 61760
# start, end:61760, 61824
# start, end:61824, 61888
# start, end:61888, 61952
# start, end:61952, 62016
# start, end:62016, 62080
# start, end:62080, 62144
# start, end:62144, 62208
# start, end:62208, 62272
# start, end:62272, 62336
# start, end:62336, 62400
# start, end:62400, 62464
# start, end:62464, 62528
# start, end:62528, 62592
# start, end:62592, 62656
# start, end:62656, 62720
# start, end:62720, 62784
# start, end:62784, 62848
# start, end:62848, 62912
# start, end:62912, 62976
# start, end:62976, 63040
# start, end:63040, 63104
# start, end:63104, 63168
# start, end:63168, 63232
# start, end:63232, 63296
# start, end:63296, 63360
# start, end:63360, 63424
# start, end:63424, 63488
# start, end:63488, 63552
# start, end:63552, 63616
# start, end:63616, 63680
# start, end:63680, 63744
# start, end:63744, 63808
# start, end:63808, 63872
# start, end:63872, 63936
# start, end:63936, 64000
# Phase: train | Epoch: 0 | Count: 1000 \ Start Time: 21:19:35 | Loss: 253
# start, end:64000, 64064
# start, end:64064, 64128
# start, end:64128, 64192
# start, end:64192, 64256
# start, end:64256, 64320
# start, end:64320, 64384
# start, end:64384, 64448
# start, end:64448, 64512
# start, end:64512, 64576
# start, end:64576, 64640
# start, end:64640, 64704
# start, end:64704, 64768
# start, end:64768, 64832
# start, end:64832, 64896
# start, end:64896, 64960
# start, end:64960, 65024
# start, end:65024, 65088
# start, end:65088, 65152
# start, end:65152, 65216
# start, end:65216, 65280
# start, end:65280, 65344
# start, end:65344, 65408
# start, end:65408, 65472
# start, end:65472, 65536
# start, end:65536, 65600
# start, end:65600, 65664
# start, end:65664, 65728
# start, end:65728, 65792
# start, end:65792, 65856
# start, end:65856, 65920
# start, end:65920, 65984
# start, end:65984, 66048
# start, end:66048, 66112
# start, end:66112, 66176
# start, end:66176, 66240
# start, end:66240, 66304
# start, end:66304, 66368
# start, end:66368, 66432
# start, end:66432, 66496
# start, end:66496, 66560
# start, end:66560, 66624
# start, end:66624, 66688
# start, end:66688, 66752
# start, end:66752, 66816
# start, end:66816, 66880
# start, end:66880, 66944
# start, end:66944, 67008
# start, end:67008, 67072
# start, end:67072, 67136
# start, end:67136, 67200
# start, end:67200, 67264
# start, end:67264, 67328
# start, end:67328, 67392
# start, end:67392, 67456
# start, end:67456, 67520
# start, end:67520, 67584
# start, end:67584, 67648
# start, end:67648, 67712
# start, end:67712, 67776
# start, end:67776, 67840
# start, end:67840, 67904
# start, end:67904, 67968
# start, end:67968, 68032
# start, end:68032, 68096
# start, end:68096, 68160
# start, end:68160, 68224
# start, end:68224, 68288
# start, end:68288, 68352
# start, end:68352, 68416
# start, end:68416, 68480
# start, end:68480, 68544
# start, end:68544, 68608
# start, end:68608, 68672
# start, end:68672, 68736
# start, end:68736, 68800
# start, end:68800, 68864
# start, end:68864, 68928
# start, end:68928, 68992
# start, end:68992, 69056
# start, end:69056, 69120
# start, end:69120, 69184
# start, end:69184, 69248
# start, end:69248, 69312
# start, end:69312, 69376
# start, end:69376, 69440
# start, end:69440, 69504
# start, end:69504, 69568
# start, end:69568, 69632
# start, end:69632, 69696
# start, end:69696, 69760
# start, end:69760, 69824
# start, end:69824, 69888
# start, end:69888, 69952
# start, end:69952, 70016
# start, end:70016, 70080
# start, end:70080, 70144
# start, end:70144, 70208
# start, end:70208, 70272
# start, end:70272, 70336
# start, end:70336, 70400
# Phase: train | Epoch: 0 | Count: 1100 \ Start Time: 21:20:08 | Loss: 248
# start, end:70400, 70464
# start, end:70464, 70528
# start, end:70528, 70592
# start, end:70592, 70656
# start, end:70656, 70720
# start, end:70720, 70784
# start, end:70784, 70848
# start, end:70848, 70912
# start, end:70912, 70976
# start, end:70976, 71040
# start, end:71040, 71104
# start, end:71104, 71168
# start, end:71168, 71232
# start, end:71232, 71296
# start, end:71296, 71360
# start, end:71360, 71424
# start, end:71424, 71488
# start, end:71488, 71552
# start, end:71552, 71616
# start, end:71616, 71680
# start, end:71680, 71744
# start, end:71744, 71808
# start, end:71808, 71872
# start, end:71872, 71936
# start, end:71936, 72000
# start, end:72000, 72064
# start, end:72064, 72128
# start, end:72128, 72192
# start, end:72192, 72256
# start, end:72256, 72320
# start, end:72320, 72384
# start, end:72384, 72448
# start, end:72448, 72512
# start, end:72512, 72576
# start, end:72576, 72640
# start, end:72640, 72704
# start, end:72704, 72768
# start, end:72768, 72832
# start, end:72832, 72896
# start, end:72896, 72960
# start, end:72960, 73024
# start, end:73024, 73088
# start, end:73088, 73152
# start, end:73152, 73216
# start, end:73216, 73280
# start, end:73280, 73344
# start, end:73344, 73408
# start, end:73408, 73472
# start, end:73472, 73536
# start, end:73536, 73600
# start, end:73600, 73664
# start, end:73664, 73728
# start, end:73728, 73792
# start, end:73792, 73856
# start, end:73856, 73920
# start, end:73920, 73984
# start, end:73984, 74048
# start, end:74048, 74112
# start, end:74112, 74176
# start, end:74176, 74240
# start, end:74240, 74304
# start, end:74304, 74368
# start, end:74368, 74432
# start, end:74432, 74496
# start, end:74496, 74560
# start, end:74560, 74624
# start, end:74624, 74688
# start, end:74688, 74752
# start, end:74752, 74816
# start, end:74816, 74880
# start, end:74880, 74944
# start, end:74944, 75008
# start, end:75008, 75072
# start, end:75072, 75136
# start, end:75136, 75200
# start, end:75200, 75264
# start, end:75264, 75328
# start, end:75328, 75392
# start, end:75392, 75456
# start, end:75456, 75520
# start, end:75520, 75584
# start, end:75584, 75648
# start, end:75648, 75712
# start, end:75712, 75776
# start, end:75776, 75840
# start, end:75840, 75904
# start, end:75904, 75968
# start, end:75968, 76032
# start, end:76032, 76096
# start, end:76096, 76160
# start, end:76160, 76224
# start, end:76224, 76288
# start, end:76288, 76352
# start, end:76352, 76416
# start, end:76416, 76480
# start, end:76480, 76544
# start, end:76544, 76608
# start, end:76608, 76672
# start, end:76672, 76736
# start, end:76736, 76800
# Phase: train | Epoch: 0 | Count: 1200 \ Start Time: 21:20:41 | Loss: 245
# start, end:76800, 76864
# start, end:76864, 76928
# start, end:76928, 76992
# start, end:76992, 77056
# start, end:77056, 77120
# start, end:77120, 77184
# start, end:77184, 77248
# start, end:77248, 77312
# start, end:77312, 77376
# start, end:77376, 77440
# start, end:77440, 77504
# start, end:77504, 77568
# start, end:77568, 77632
# start, end:77632, 77696
# start, end:77696, 77760
# start, end:77760, 77824
# start, end:77824, 77888
# start, end:77888, 77952
# start, end:77952, 78016
# start, end:78016, 78080
# start, end:78080, 78144
# start, end:78144, 78208
# start, end:78208, 78272
# start, end:78272, 78336
# start, end:78336, 78400
# start, end:78400, 78464
# start, end:78464, 78528
# start, end:78528, 78592
# start, end:78592, 78656
# start, end:78656, 78720
# start, end:78720, 78784
# start, end:78784, 78848
# start, end:78848, 78912
# start, end:78912, 78976
# start, end:78976, 79040
# start, end:79040, 79104
# start, end:79104, 79168
# start, end:79168, 79232
# start, end:79232, 79296
# start, end:79296, 79360
# start, end:79360, 79424
# start, end:79424, 79488
# start, end:79488, 79552
# start, end:79552, 79616
# start, end:79616, 79680
# start, end:79680, 79744
# start, end:79744, 79808
# start, end:79808, 79872
# start, end:79872, 79936
# start, end:79936, 80000
# start, end:80000, 80064
# start, end:80064, 80128
# start, end:80128, 80192
# start, end:80192, 80256
# start, end:80256, 80320
# start, end:80320, 80384
# start, end:80384, 80448
# start, end:80448, 80512
# start, end:80512, 80576
# start, end:80576, 80640
# start, end:80640, 80704
# start, end:80704, 80768
# start, end:80768, 80832
# start, end:80832, 80896
# start, end:80896, 80960
# start, end:80960, 81024
# start, end:81024, 81088
# start, end:81088, 81152
# start, end:81152, 81216
# start, end:81216, 81280
# start, end:81280, 81344
# start, end:81344, 81408
# start, end:81408, 81472
# start, end:81472, 81536
# start, end:81536, 81600
# start, end:81600, 81664
# start, end:81664, 81728
# start, end:81728, 81792
# start, end:81792, 81856
# start, end:81856, 81920
# start, end:81920, 81984
# start, end:81984, 82048
# start, end:82048, 82112
# start, end:82112, 82176
# start, end:82176, 82240
# start, end:82240, 82304
# start, end:82304, 82368
# start, end:82368, 82432
# start, end:82432, 82496
# start, end:82496, 82560
# start, end:82560, 82624
# start, end:82624, 82688
# start, end:82688, 82752
# start, end:82752, 82816
# start, end:82816, 82880
# start, end:82880, 82944
# start, end:82944, 83008
# start, end:83008, 83072
# start, end:83072, 83136
# start, end:83136, 83200
# Phase: train | Epoch: 0 | Count: 1300 \ Start Time: 21:21:14 | Loss: 245
# start, end:83200, 83264
# start, end:83264, 83328
# start, end:83328, 83392
# start, end:83392, 83456
# start, end:83456, 83520
# start, end:83520, 83584
# start, end:83584, 83648
# start, end:83648, 83712
# start, end:83712, 83776
# start, end:83776, 83840
# start, end:83840, 83904
# start, end:83904, 83968
# start, end:83968, 84032
# start, end:84032, 84096
# start, end:84096, 84160
# start, end:84160, 84224
# start, end:84224, 84288
# start, end:84288, 84352
# start, end:84352, 84416
# start, end:84416, 84480
# start, end:84480, 84544
# start, end:84544, 84608
# start, end:84608, 84672
# start, end:84672, 84736
# start, end:84736, 84800
# start, end:84800, 84864
# start, end:84864, 84928
# start, end:84928, 84992
# start, end:84992, 85056
# start, end:85056, 85120
# start, end:85120, 85184
# start, end:85184, 85248
# start, end:85248, 85312
# start, end:85312, 85376
# start, end:85376, 85440
# start, end:85440, 85504
# start, end:85504, 85568
# start, end:85568, 85632
# start, end:85632, 85696
# start, end:85696, 85760
# start, end:85760, 85824
# start, end:85824, 85888
# start, end:85888, 85952
# start, end:85952, 86016
# start, end:86016, 86080
# start, end:86080, 86144
# start, end:86144, 86208
# start, end:86208, 86272
# start, end:86272, 86336
# start, end:86336, 86400
# start, end:86400, 86464
# start, end:86464, 86528
# start, end:86528, 86592
# start, end:86592, 86656
# start, end:86656, 86720
# start, end:86720, 86784
# start, end:86784, 86848
# start, end:86848, 86912
# start, end:86912, 86976
# start, end:86976, 87040
# start, end:87040, 87104
# start, end:87104, 87168
# start, end:87168, 87232
# start, end:87232, 87296
# start, end:87296, 87360
# start, end:87360, 87424
# start, end:87424, 87488
# start, end:87488, 87552
# start, end:87552, 87616
# start, end:87616, 87680
# start, end:87680, 87744
# start, end:87744, 87808
# start, end:87808, 87872
# start, end:87872, 87936
# start, end:87936, 88000
# start, end:88000, 88064
# start, end:88064, 88128
# start, end:88128, 88192
# start, end:88192, 88256
# start, end:88256, 88320
# start, end:88320, 88384
# start, end:88384, 88448
# start, end:88448, 88512
# start, end:88512, 88576
# start, end:88576, 88640
# start, end:88640, 88704
# start, end:88704, 88768
# start, end:88768, 88832
# start, end:88832, 88896
# start, end:88896, 88960
# start, end:88960, 89024
# start, end:89024, 89088
# start, end:89088, 89152
# start, end:89152, 89216
# start, end:89216, 89280
# start, end:89280, 89344
# start, end:89344, 89408
# start, end:89408, 89472
# start, end:89472, 89536
# start, end:89536, 89600
# Phase: train | Epoch: 0 | Count: 1400 \ Start Time: 21:21:47 | Loss: 241
# start, end:89600, 89664
# start, end:89664, 89728
# start, end:89728, 89792
# start, end:89792, 89856
# start, end:89856, 89920
# start, end:89920, 89984
# start, end:89984, 90048
# start, end:90048, 90112
# start, end:90112, 90176
# start, end:90176, 90240
# start, end:90240, 90304
# start, end:90304, 90368
# start, end:90368, 90432
# start, end:90432, 90496
# start, end:90496, 90560
# start, end:90560, 90624
# start, end:90624, 90688
# start, end:90688, 90752
# start, end:90752, 90816
# start, end:90816, 90880
# start, end:90880, 90944
# start, end:90944, 91008
# start, end:91008, 91072
# start, end:91072, 91136
# start, end:91136, 91200
# start, end:91200, 91264
# start, end:91264, 91328
# start, end:91328, 91392
# start, end:91392, 91456
# start, end:91456, 91520
# start, end:91520, 91584
# start, end:91584, 91648
# start, end:91648, 91712
# start, end:91712, 91776
# start, end:91776, 91840
# start, end:91840, 91904
# start, end:91904, 91968
# start, end:91968, 92032
# start, end:92032, 92096
# start, end:92096, 92160
# start, end:92160, 92224
# start, end:92224, 92288
# start, end:92288, 92352
# start, end:92352, 92416
# start, end:92416, 92480
# start, end:92480, 92544
# start, end:92544, 92608
# start, end:92608, 92672
# start, end:92672, 92736
# start, end:92736, 92800
# start, end:92800, 92864
# start, end:92864, 92928
# start, end:92928, 92992
# start, end:92992, 93056
# start, end:93056, 93120
# start, end:93120, 93184
# start, end:93184, 93248
# start, end:93248, 93312
# start, end:93312, 93376
# start, end:93376, 93440
# start, end:93440, 93504
# start, end:93504, 93568
# start, end:93568, 93632
# start, end:93632, 93696
# start, end:93696, 93760
# start, end:93760, 93824
# start, end:93824, 93888
# start, end:93888, 93952
# start, end:93952, 94016
# start, end:94016, 94080
# start, end:94080, 94144
# start, end:94144, 94208
# start, end:94208, 94272
# start, end:94272, 94336
# start, end:94336, 94400
# start, end:94400, 94464
# start, end:94464, 94528
# start, end:94528, 94592
# start, end:94592, 94656
# start, end:94656, 94720
# start, end:94720, 94784
# start, end:94784, 94848
# start, end:94848, 94912
# start, end:94912, 94976
# start, end:94976, 95040
# start, end:95040, 95104
# start, end:95104, 95168
# start, end:95168, 95232
# start, end:95232, 95296
# start, end:95296, 95360
# start, end:95360, 95424
# start, end:95424, 95488
# start, end:95488, 95552
# start, end:95552, 95616
# start, end:95616, 95680
# start, end:95680, 95744
# start, end:95744, 95808
# start, end:95808, 95872
# start, end:95872, 95936
# start, end:95936, 96000
# Phase: train | Epoch: 0 | Count: 1500 \ Start Time: 21:22:20 | Loss: 239
# start, end:96000, 96064
# start, end:96064, 96128
# start, end:96128, 96192
# start, end:96192, 96256
# start, end:96256, 96320
# start, end:96320, 96384
# start, end:96384, 96448
# start, end:96448, 96512
# start, end:96512, 96576
# start, end:96576, 96640
# start, end:96640, 96704
# start, end:96704, 96768
# start, end:96768, 96832
# start, end:96832, 96896
# start, end:96896, 96960
# start, end:96960, 97024
# start, end:97024, 97088
# start, end:97088, 97152
# start, end:97152, 97216
# start, end:97216, 97280
# start, end:0, 16
# start, end:16, 80
# start, end:80, 144
# start, end:144, 208
# start, end:208, 272
# start, end:272, 336
# start, end:336, 400
# start, end:400, 464
# start, end:464, 528
# start, end:528, 592
# start, end:592, 656
# start, end:656, 720
# start, end:720, 784
# start, end:784, 848
# start, end:848, 912
# start, end:912, 976
# start, end:976, 1040
# start, end:1040, 1104
# start, end:1104, 1168
# start, end:1168, 1232
# start, end:1232, 1296
# start, end:1296, 1360
# start, end:1360, 1424
# start, end:1424, 1488
# start, end:1488, 1552
# start, end:1552, 1616
# start, end:1616, 1680
# start, end:1680, 1744
# start, end:1744, 1808
# start, end:1808, 1872
# start, end:1872, 1936
# start, end:1936, 2000
# start, end:2000, 2064
# start, end:2064, 2128
# start, end:2128, 2192
# start, end:2192, 2256
# start, end:2256, 2320
# start, end:2320, 2384
# start, end:2384, 2448
# start, end:2448, 2512
# start, end:2512, 2576
# start, end:2576, 2640
# start, end:2640, 2704
# start, end:2704, 2768
# start, end:2768, 2832
# start, end:2832, 2896
# start, end:2896, 2960
# start, end:2960, 3024
# start, end:3024, 3088
# start, end:3088, 3152
# start, end:3152, 3216
# start, end:3216, 3280
# start, end:3280, 3344
# start, end:3344, 3408
# start, end:3408, 3472
# start, end:3472, 3536
# start, end:3536, 3600
# start, end:3600, 3664
# start, end:3664, 3728
# start, end:3728, 3792
# start, end:3792, 3856
# start, end:3856, 3920
# start, end:3920, 3984
# start, end:3984, 4048
# start, end:4048, 4112
# start, end:4112, 4176
# start, end:4176, 4240
# start, end:4240, 4304
# start, end:4304, 4368
# start, end:4368, 4432
# start, end:4432, 4496
# start, end:4496, 4560
# start, end:4560, 4624
# start, end:4624, 4688
# start, end:4688, 4752
# start, end:4752, 4816
# start, end:4816, 4880
# start, end:4880, 4944
# start, end:4944, 5008
# start, end:5008, 5072
# Phase: train | Epoch: 1 | Count: 1600 \ Start Time: 21:22:53 | Loss: 238
# start, end:5072, 5136
# start, end:5136, 5200
# start, end:5200, 5264
# start, end:5264, 5328
# start, end:5328, 5392
# start, end:5392, 5456
# start, end:5456, 5520
# start, end:5520, 5584
# start, end:5584, 5648
# start, end:5648, 5712
# start, end:5712, 5776
# start, end:5776, 5840
# start, end:5840, 5904
# start, end:5904, 5968
# start, end:5968, 6032
# start, end:6032, 6096
# start, end:6096, 6160
# start, end:6160, 6224
# start, end:6224, 6288
# start, end:6288, 6352
# start, end:6352, 6416
# start, end:6416, 6480
# start, end:6480, 6544
# start, end:6544, 6608
# start, end:6608, 6672
# start, end:6672, 6736
# start, end:6736, 6800
# start, end:6800, 6864
# start, end:6864, 6928
# start, end:6928, 6992
# start, end:6992, 7056
# start, end:7056, 7120
# start, end:7120, 7184
# start, end:7184, 7248
# start, end:7248, 7312
# start, end:7312, 7376
# start, end:7376, 7440
# start, end:7440, 7504
# start, end:7504, 7568
# start, end:7568, 7632
# start, end:7632, 7696
# start, end:7696, 7760
# start, end:7760, 7824
# start, end:7824, 7888
# start, end:7888, 7952
# start, end:7952, 8016
# start, end:8016, 8080
# start, end:8080, 8144
# start, end:8144, 8208
# start, end:8208, 8272
# start, end:8272, 8336
# start, end:8336, 8400
# start, end:8400, 8464
# start, end:8464, 8528
# start, end:8528, 8592
# start, end:8592, 8656
# start, end:8656, 8720
# start, end:8720, 8784
# start, end:8784, 8848
# start, end:8848, 8912
# start, end:8912, 8976
# start, end:8976, 9040
# start, end:9040, 9104
# start, end:9104, 9168
# start, end:9168, 9232
# start, end:9232, 9296
# start, end:9296, 9360
# start, end:9360, 9424
# start, end:9424, 9488
# start, end:9488, 9552
# start, end:9552, 9616
# start, end:9616, 9680
# start, end:9680, 9744
# start, end:9744, 9808
# start, end:9808, 9872
# start, end:9872, 9936
# start, end:9936, 10000
# start, end:10000, 10064
# start, end:10064, 10128
# start, end:10128, 10192
# start, end:10192, 10256
# start, end:10256, 10320
# start, end:10320, 10384
# start, end:10384, 10448
# start, end:10448, 10512
# start, end:10512, 10576
# start, end:10576, 10640
# start, end:10640, 10704
# start, end:10704, 10768
# start, end:10768, 10832
# start, end:10832, 10896
# start, end:10896, 10960
# start, end:10960, 11024
# start, end:11024, 11088
# start, end:11088, 11152
# start, end:11152, 11216
# start, end:11216, 11280
# start, end:11280, 11344
# start, end:11344, 11408
# start, end:11408, 11472
# Phase: train | Epoch: 1 | Count: 1700 \ Start Time: 21:23:27 | Loss: 237
# start, end:11472, 11536
# start, end:11536, 11600
# start, end:11600, 11664
# start, end:11664, 11728
# start, end:11728, 11792
# start, end:11792, 11856
# start, end:11856, 11920
# start, end:11920, 11984
# start, end:11984, 12048
# start, end:12048, 12112
# start, end:12112, 12176
# start, end:12176, 12240
# start, end:12240, 12304
# start, end:12304, 12368
# start, end:12368, 12432
# start, end:12432, 12496
# start, end:12496, 12560
# start, end:12560, 12624
# start, end:12624, 12688
# start, end:12688, 12752
# start, end:12752, 12816
# start, end:12816, 12880
# start, end:12880, 12944
# start, end:12944, 13008
# start, end:13008, 13072
# start, end:13072, 13136
# start, end:13136, 13200
# start, end:13200, 13264
# start, end:13264, 13328
# start, end:13328, 13392
# start, end:13392, 13456
# start, end:13456, 13520
# start, end:13520, 13584
# start, end:13584, 13648
# start, end:13648, 13712
# start, end:13712, 13776
# start, end:13776, 13840
# start, end:13840, 13904
# start, end:13904, 13968
# start, end:13968, 14032
# start, end:14032, 14096
# start, end:14096, 14160
# start, end:14160, 14224
# start, end:14224, 14288
# start, end:14288, 14352
# start, end:14352, 14416
# start, end:14416, 14480
# start, end:14480, 14544
# start, end:14544, 14608
# start, end:14608, 14672
# start, end:14672, 14736
# start, end:14736, 14800
# start, end:14800, 14864
# start, end:14864, 14928
# start, end:14928, 14992
# start, end:14992, 15056
# start, end:15056, 15120
# start, end:15120, 15184
# start, end:15184, 15248
# start, end:15248, 15312
# start, end:15312, 15376
# start, end:15376, 15440
# start, end:15440, 15504
# start, end:15504, 15568
# start, end:15568, 15632
# start, end:15632, 15696
# start, end:15696, 15760
# start, end:15760, 15824
# start, end:15824, 15888
# start, end:15888, 15952
# start, end:15952, 16016
# start, end:16016, 16080
# start, end:16080, 16144
# start, end:16144, 16208
# start, end:16208, 16272
# start, end:16272, 16336
# start, end:16336, 16400
# start, end:16400, 16464
# start, end:16464, 16528
# start, end:16528, 16592
# start, end:16592, 16656
# start, end:16656, 16720
# start, end:16720, 16784
# start, end:16784, 16848
# start, end:16848, 16912
# start, end:16912, 16976
# start, end:16976, 17040
# start, end:17040, 17104
# start, end:17104, 17168
# start, end:17168, 17232
# start, end:17232, 17296
# start, end:17296, 17360
# start, end:17360, 17424
# start, end:17424, 17488
# start, end:17488, 17552
# start, end:17552, 17616
# start, end:17616, 17680
# start, end:17680, 17744
# start, end:17744, 17808
# start, end:17808, 17872
# Phase: train | Epoch: 1 | Count: 1800 \ Start Time: 21:24:00 | Loss: 236
# start, end:17872, 17936
# start, end:17936, 18000
# start, end:18000, 18064
# start, end:18064, 18128
# start, end:18128, 18192
# start, end:18192, 18256
# start, end:18256, 18320
# start, end:18320, 18384
# start, end:18384, 18448
# start, end:18448, 18512
# start, end:18512, 18576
# start, end:18576, 18640
# start, end:18640, 18704
# start, end:18704, 18768
# start, end:18768, 18832
# start, end:18832, 18896
# start, end:18896, 18960
# start, end:18960, 19024
# start, end:19024, 19088
# start, end:19088, 19152
# start, end:19152, 19216
# start, end:19216, 19280
# start, end:19280, 19344
# start, end:19344, 19408
# start, end:19408, 19472
# start, end:19472, 19536
# start, end:19536, 19600
# start, end:19600, 19664
# start, end:19664, 19728
# start, end:19728, 19792
# start, end:19792, 19856
# start, end:19856, 19920
# start, end:19920, 19984
# start, end:19984, 20048
# start, end:20048, 20112
# start, end:20112, 20176
# start, end:20176, 20240
# start, end:20240, 20304
# start, end:20304, 20368
# start, end:20368, 20432
# start, end:20432, 20496
# start, end:20496, 20560
# start, end:20560, 20624
# start, end:20624, 20688
# start, end:20688, 20752
# start, end:20752, 20816
# start, end:20816, 20880
# start, end:20880, 20944
# start, end:20944, 21008
# start, end:21008, 21072
# start, end:21072, 21136
# start, end:21136, 21200
# start, end:21200, 21264
# start, end:21264, 21328
# start, end:21328, 21392
# start, end:21392, 21456
# start, end:21456, 21520
# start, end:21520, 21584
# start, end:21584, 21648
# start, end:21648, 21712
# start, end:21712, 21776
# start, end:21776, 21840
# start, end:21840, 21904
# start, end:21904, 21968
# start, end:21968, 22032
# start, end:22032, 22096
# start, end:22096, 22160
# start, end:22160, 22224
# start, end:22224, 22288
# start, end:22288, 22352
# start, end:22352, 22416
# start, end:22416, 22480
# start, end:22480, 22544
# start, end:22544, 22608
# start, end:22608, 22672
# start, end:22672, 22736
# start, end:22736, 22800
# start, end:22800, 22864
# start, end:22864, 22928
# start, end:22928, 22992
# start, end:22992, 23056
# start, end:23056, 23120
# start, end:23120, 23184
# start, end:23184, 23248
# start, end:23248, 23312
# start, end:23312, 23376
# start, end:23376, 23440
# start, end:23440, 23504
# start, end:23504, 23568
# start, end:23568, 23632
# start, end:23632, 23696
# start, end:23696, 23760
# start, end:23760, 23824
# start, end:23824, 23888
# start, end:23888, 23952
# start, end:23952, 24016
# start, end:24016, 24080
# start, end:24080, 24144
# start, end:24144, 24208
# start, end:24208, 24272
# Phase: train | Epoch: 1 | Count: 1900 \ Start Time: 21:24:34 | Loss: 233
# start, end:24272, 24336
# start, end:24336, 24400
# start, end:24400, 24464
# start, end:24464, 24528
# start, end:24528, 24592
# start, end:24592, 24656
# start, end:24656, 24720
# start, end:24720, 24784
# start, end:24784, 24848
# start, end:24848, 24912
# start, end:24912, 24976
# start, end:24976, 25040
# start, end:25040, 25104
# start, end:25104, 25168
# start, end:25168, 25232
# start, end:25232, 25296
# start, end:25296, 25360
# start, end:25360, 25424
# start, end:25424, 25488
# start, end:25488, 25552
# start, end:25552, 25616
# start, end:25616, 25680
# start, end:25680, 25744
# start, end:25744, 25808
# start, end:25808, 25872
# start, end:25872, 25936
# start, end:25936, 26000
# start, end:26000, 26064
# start, end:26064, 26128
# start, end:26128, 26192
# start, end:26192, 26256
# start, end:26256, 26320
# start, end:26320, 26384
# start, end:26384, 26448
# start, end:26448, 26512
# start, end:26512, 26576
# start, end:26576, 26640
# start, end:26640, 26704
# start, end:26704, 26768
# start, end:26768, 26832
# start, end:26832, 26896
# start, end:26896, 26960
# start, end:26960, 27024
# start, end:27024, 27088
# start, end:27088, 27152
# start, end:27152, 27216
# start, end:27216, 27280
# start, end:27280, 27344
# start, end:27344, 27408
# start, end:27408, 27472
# start, end:27472, 27536
# start, end:27536, 27600
# start, end:27600, 27664
# start, end:27664, 27728
# start, end:27728, 27792
# start, end:27792, 27856
# start, end:27856, 27920
# start, end:27920, 27984
# start, end:27984, 28048
# start, end:28048, 28112
# start, end:28112, 28176
# ...
# start, end:60496, 60560
# start, end:60560, 60624
# start, end:60624, 60688
# start, end:60688, 60752
# start, end:60752, 60816
# start, end:60816, 60880
# start, end:60880, 60944
# start, end:60944, 61008
# start, end:61008, 61072
# start, end:61072, 61136
# start, end:61136, 61200
# start, end:61200, 61264
# start, end:61264, 61328
# start, end:61328, 61392
# start, end:61392, 61456
# start, end:61456, 61520
# start, end:61520, 61584
# start, end:61584, 61648
# start, end:61648, 61712
# start, end:61712, 61776
# start, end:61776, 61840
# start, end:61840, 61904
# start, end:61904, 61968
# start, end:61968, 62032
# start, end:62032, 62096
# start, end:62096, 62160
# start, end:62160, 62224
# start, end:62224, 62288
# start, end:62288, 62352
# start, end:62352, 62416
# start, end:62416, 62480
# start, end:62480, 62544
# start, end:62544, 62608
# start, end:62608, 62672
# start, end:62672, 62736
# start, end:62736, 62800
# start, end:62800, 62864
# start, end:62864, 62928
# start, end:62928, 62992
# start, end:62992, 63056
# start, end:63056, 63120
# start, end:63120, 63184
# start, end:63184, 63248
# start, end:63248, 63312
# start, end:63312, 63376
# start, end:63376, 63440
# start, end:63440, 63504
# start, end:63504, 63568
# start, end:63568, 63632
# start, end:63632, 63696
# start, end:63696, 63760
# start, end:63760, 63824
# start, end:63824, 63888
# start, end:63888, 63952
# start, end:63952, 64016
# start, end:64016, 64080
# start, end:64080, 64144
# start, end:64144, 64208
# start, end:64208, 64272
# start, end:64272, 64336
# start, end:64336, 64400
# start, end:64400, 64464
# start, end:64464, 64528
# start, end:64528, 64592
# start, end:64592, 64656
# start, end:64656, 64720
# start, end:64720, 64784
# start, end:64784, 64848
# Phase: train | Epoch: 9 | Count: 14700 \ Start Time: 23:01:27 | Loss: 175
# start, end:64848, 64912
# start, end:64912, 64976
# start, end:64976, 65040
# start, end:65040, 65104
# start, end:65104, 65168
# start, end:65168, 65232
# start, end:65232, 65296
# start, end:65296, 65360
# start, end:65360, 65424
# start, end:65424, 65488
# start, end:65488, 65552
# start, end:65552, 65616
# start, end:65616, 65680
# start, end:65680, 65744
# start, end:65744, 65808
# start, end:65808, 65872
# start, end:65872, 65936
# start, end:65936, 66000
# start, end:66000, 66064
# start, end:66064, 66128
# start, end:66128, 66192
# start, end:66192, 66256
# start, end:66256, 66320
# start, end:66320, 66384
# start, end:66384, 66448
# start, end:66448, 66512
# start, end:66512, 66576
# start, end:66576, 66640
# start, end:66640, 66704
# start, end:66704, 66768
# start, end:66768, 66832
# start, end:66832, 66896
# start, end:66896, 66960
# start, end:66960, 67024
# start, end:67024, 67088
# start, end:67088, 67152
# start, end:67152, 67216
# start, end:67216, 67280
# start, end:67280, 67344
# start, end:67344, 67408
# start, end:67408, 67472
# start, end:67472, 67536
# start, end:67536, 67600
# start, end:67600, 67664
# start, end:67664, 67728
# start, end:67728, 67792
# start, end:67792, 67856
# start, end:67856, 67920
# start, end:67920, 67984
# start, end:67984, 68048
# start, end:68048, 68112
# start, end:68112, 68176
# start, end:68176, 68240
# start, end:68240, 68304
# start, end:68304, 68368
# start, end:68368, 68432
# start, end:68432, 68496
# start, end:68496, 68560
# start, end:68560, 68624
# start, end:68624, 68688
# start, end:68688, 68752
# start, end:68752, 68816
# start, end:68816, 68880
# start, end:68880, 68944
# start, end:68944, 69008
# start, end:69008, 69072
# start, end:69072, 69136
# start, end:69136, 69200
# start, end:69200, 69264
# start, end:69264, 69328
# start, end:69328, 69392
# start, end:69392, 69456
# start, end:69456, 69520
# start, end:69520, 69584
# start, end:69584, 69648
# start, end:69648, 69712
# start, end:69712, 69776
# start, end:69776, 69840
# start, end:69840, 69904
# start, end:69904, 69968
# start, end:69968, 70032
# start, end:70032, 70096
# start, end:70096, 70160
# start, end:70160, 70224
# start, end:70224, 70288
# start, end:70288, 70352
# start, end:70352, 70416
# start, end:70416, 70480
# start, end:70480, 70544
# start, end:70544, 70608
# start, end:70608, 70672
# start, end:70672, 70736
# start, end:70736, 70800
# start, end:70800, 70864
# start, end:70864, 70928
# start, end:70928, 70992
# start, end:70992, 71056
# start, end:71056, 71120
# start, end:71120, 71184
# start, end:71184, 71248
# Phase: train | Epoch: 9 | Count: 14800 \ Start Time: 23:02:09 | Loss: 173
# start, end:71248, 71312
# start, end:71312, 71376
# start, end:71376, 71440
# start, end:71440, 71504
# start, end:71504, 71568
# start, end:71568, 71632
# start, end:71632, 71696
# start, end:71696, 71760
# start, end:71760, 71824
# start, end:71824, 71888
# start, end:71888, 71952
# start, end:71952, 72016
# start, end:72016, 72080
# start, end:72080, 72144
# start, end:72144, 72208
# start, end:72208, 72272
# start, end:72272, 72336
# start, end:72336, 72400
# start, end:72400, 72464
# start, end:72464, 72528
# start, end:72528, 72592
# start, end:72592, 72656
# start, end:72656, 72720
# start, end:72720, 72784
# start, end:72784, 72848
# start, end:72848, 72912
# start, end:72912, 72976
# start, end:72976, 73040
# start, end:73040, 73104
# start, end:73104, 73168
# start, end:73168, 73232
# start, end:73232, 73296
# start, end:73296, 73360
# start, end:73360, 73424
# start, end:73424, 73488
# start, end:73488, 73552
# start, end:73552, 73616
# start, end:73616, 73680
# start, end:73680, 73744
# start, end:73744, 73808
# start, end:73808, 73872
# start, end:73872, 73936
# start, end:73936, 74000
# start, end:74000, 74064
# start, end:74064, 74128
# start, end:74128, 74192
# start, end:74192, 74256
# start, end:74256, 74320
# start, end:74320, 74384
# start, end:74384, 74448
# start, end:74448, 74512
# start, end:74512, 74576
# start, end:74576, 74640
# start, end:74640, 74704
# start, end:74704, 74768
# start, end:74768, 74832
# start, end:74832, 74896
# start, end:74896, 74960
# start, end:74960, 75024
# start, end:75024, 75088
# start, end:75088, 75152
# start, end:75152, 75216
# start, end:75216, 75280
# start, end:75280, 75344
# start, end:75344, 75408
# start, end:75408, 75472
# start, end:75472, 75536
# start, end:75536, 75600
# start, end:75600, 75664
# start, end:75664, 75728
# start, end:75728, 75792
# start, end:75792, 75856
# start, end:75856, 75920
# start, end:75920, 75984
# start, end:75984, 76048
# start, end:76048, 76112
# start, end:76112, 76176
# start, end:76176, 76240
# start, end:76240, 76304
# start, end:76304, 76368
# start, end:76368, 76432
# start, end:76432, 76496
# start, end:76496, 76560
# start, end:76560, 76624
# start, end:76624, 76688
# start, end:76688, 76752
# start, end:76752, 76816
# start, end:76816, 76880
# start, end:76880, 76944
# start, end:76944, 77008
# start, end:77008, 77072
# start, end:77072, 77136
# start, end:77136, 77200
# start, end:77200, 77264
# start, end:77264, 77328
# start, end:77328, 77392
# start, end:77392, 77456
# start, end:77456, 77520
# start, end:77520, 77584
# start, end:77584, 77648
# Phase: train | Epoch: 9 | Count: 14900 \ Start Time: 23:02:50 | Loss: 174
# start, end:77648, 77712
# start, end:77712, 77776
# start, end:77776, 77840
# start, end:77840, 77904
# start, end:77904, 77968
# start, end:77968, 78032
# start, end:78032, 78096
# start, end:78096, 78160
# start, end:78160, 78224
# start, end:78224, 78288
# start, end:78288, 78352
# start, end:78352, 78416
# start, end:78416, 78480
# start, end:78480, 78544
# start, end:78544, 78608
# start, end:78608, 78672
# start, end:78672, 78736
# start, end:78736, 78800
# start, end:78800, 78864
# start, end:78864, 78928
# start, end:78928, 78992
# start, end:78992, 79056
# start, end:79056, 79120
# start, end:79120, 79184
# start, end:79184, 79248
# start, end:79248, 79312
# start, end:79312, 79376
# start, end:79376, 79440
# start, end:79440, 79504
# start, end:79504, 79568
# start, end:79568, 79632
# start, end:79632, 79696
# start, end:79696, 79760
# start, end:79760, 79824
# start, end:79824, 79888
# start, end:79888, 79952
# start, end:79952, 80016
# start, end:80016, 80080
# start, end:80080, 80144
# start, end:80144, 80208
# start, end:80208, 80272
# start, end:80272, 80336
# start, end:80336, 80400
# start, end:80400, 80464
# start, end:80464, 80528
# start, end:80528, 80592
# start, end:80592, 80656
# start, end:80656, 80720
# start, end:80720, 80784
# start, end:80784, 80848
# start, end:80848, 80912
# start, end:80912, 80976
# start, end:80976, 81040
# start, end:81040, 81104
# start, end:81104, 81168
# start, end:81168, 81232
# start, end:81232, 81296
# start, end:81296, 81360
# start, end:81360, 81424
# start, end:81424, 81488
# start, end:81488, 81552
# start, end:81552, 81616
# start, end:81616, 81680
# start, end:81680, 81744
# start, end:81744, 81808
# start, end:81808, 81872
# start, end:81872, 81936
# start, end:81936, 82000
# start, end:82000, 82064
# start, end:82064, 82128
# start, end:82128, 82192
# start, end:82192, 82256
# start, end:82256, 82320
# start, end:82320, 82384
# start, end:82384, 82448
# start, end:82448, 82512
# start, end:82512, 82576
# start, end:82576, 82640
# start, end:82640, 82704
# start, end:82704, 82768
# start, end:82768, 82832
# start, end:82832, 82896
# start, end:82896, 82960
# start, end:82960, 83024
# start, end:83024, 83088
# start, end:83088, 83152
# start, end:83152, 83216
# start, end:83216, 83280
# start, end:83280, 83344
# start, end:83344, 83408
# start, end:83408, 83472
# start, end:83472, 83536
# start, end:83536, 83600
# start, end:83600, 83664
# start, end:83664, 83728
# start, end:83728, 83792
# start, end:83792, 83856
# start, end:83856, 83920
# start, end:83920, 83984
# start, end:83984, 84048
# Phase: train | Epoch: 9 | Count: 15000 \ Start Time: 23:03:33 | Loss: 173
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15000_test_0.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15000_test_1.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15000_test_2.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15000_test_3.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15000_test_4.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15000_test_5.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15000_test_6.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15000_test_7.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15000_test_8.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15000_test_9.png
# start, end:84048, 84112
# start, end:84112, 84176
# start, end:84176, 84240
# start, end:84240, 84304
# start, end:84304, 84368
# start, end:84368, 84432
# start, end:84432, 84496
# start, end:84496, 84560
# start, end:84560, 84624
# start, end:84624, 84688
# start, end:84688, 84752
# start, end:84752, 84816
# start, end:84816, 84880
# start, end:84880, 84944
# start, end:84944, 85008
# start, end:85008, 85072
# start, end:85072, 85136
# start, end:85136, 85200
# start, end:85200, 85264
# start, end:85264, 85328
# start, end:85328, 85392
# start, end:85392, 85456
# start, end:85456, 85520
# start, end:85520, 85584
# start, end:85584, 85648
# start, end:85648, 85712
# start, end:85712, 85776
# start, end:85776, 85840
# start, end:85840, 85904
# start, end:85904, 85968
# start, end:85968, 86032
# start, end:86032, 86096
# start, end:86096, 86160
# start, end:86160, 86224
# start, end:86224, 86288
# start, end:86288, 86352
# start, end:86352, 86416
# start, end:86416, 86480
# start, end:86480, 86544
# start, end:86544, 86608
# start, end:86608, 86672
# start, end:86672, 86736
# start, end:86736, 86800
# start, end:86800, 86864
# start, end:86864, 86928
# start, end:86928, 86992
# start, end:86992, 87056
# start, end:87056, 87120
# start, end:87120, 87184
# start, end:87184, 87248
# start, end:87248, 87312
# start, end:87312, 87376
# start, end:87376, 87440
# start, end:87440, 87504
# start, end:87504, 87568
# start, end:87568, 87632
# start, end:87632, 87696
# start, end:87696, 87760
# start, end:87760, 87824
# start, end:87824, 87888
# start, end:87888, 87952
# start, end:87952, 88016
# start, end:88016, 88080
# start, end:88080, 88144
# start, end:88144, 88208
# start, end:88208, 88272
# start, end:88272, 88336
# start, end:88336, 88400
# start, end:88400, 88464
# start, end:88464, 88528
# start, end:88528, 88592
# start, end:88592, 88656
# start, end:88656, 88720
# start, end:88720, 88784
# start, end:88784, 88848
# start, end:88848, 88912
# start, end:88912, 88976
# start, end:88976, 89040
# start, end:89040, 89104
# start, end:89104, 89168
# start, end:89168, 89232
# start, end:89232, 89296
# start, end:89296, 89360
# start, end:89360, 89424
# start, end:89424, 89488
# start, end:89488, 89552
# start, end:89552, 89616
# start, end:89616, 89680
# start, end:89680, 89744
# start, end:89744, 89808
# start, end:89808, 89872
# start, end:89872, 89936
# start, end:89936, 90000
# start, end:90000, 90064
# start, end:90064, 90128
# start, end:90128, 90192
# start, end:90192, 90256
# start, end:90256, 90320
# start, end:90320, 90384
# start, end:90384, 90448
# Phase: train | Epoch: 9 | Count: 15100 \ Start Time: 23:04:18 | Loss: 174
# start, end:90448, 90512
# start, end:90512, 90576
# start, end:90576, 90640
# start, end:90640, 90704
# start, end:90704, 90768
# start, end:90768, 90832
# start, end:90832, 90896
# start, end:90896, 90960
# start, end:90960, 91024
# start, end:91024, 91088
# start, end:91088, 91152
# start, end:91152, 91216
# start, end:91216, 91280
# start, end:91280, 91344
# start, end:91344, 91408
# start, end:91408, 91472
# start, end:91472, 91536
# start, end:91536, 91600
# start, end:91600, 91664
# start, end:91664, 91728
# start, end:91728, 91792
# start, end:91792, 91856
# start, end:91856, 91920
# start, end:91920, 91984
# start, end:91984, 92048
# start, end:92048, 92112
# start, end:92112, 92176
# start, end:92176, 92240
# start, end:92240, 92304
# start, end:92304, 92368
# start, end:92368, 92432
# start, end:92432, 92496
# start, end:92496, 92560
# start, end:92560, 92624
# start, end:92624, 92688
# start, end:92688, 92752
# start, end:92752, 92816
# start, end:92816, 92880
# start, end:92880, 92944
# start, end:92944, 93008
# start, end:93008, 93072
# start, end:93072, 93136
# start, end:93136, 93200
# start, end:93200, 93264
# start, end:93264, 93328
# start, end:93328, 93392
# start, end:93392, 93456
# start, end:93456, 93520
# start, end:93520, 93584
# start, end:93584, 93648
# start, end:93648, 93712
# start, end:93712, 93776
# start, end:93776, 93840
# start, end:93840, 93904
# start, end:93904, 93968
# start, end:93968, 94032
# start, end:94032, 94096
# start, end:94096, 94160
# start, end:94160, 94224
# start, end:94224, 94288
# start, end:94288, 94352
# start, end:94352, 94416
# start, end:94416, 94480
# start, end:94480, 94544
# start, end:94544, 94608
# start, end:94608, 94672
# start, end:94672, 94736
# start, end:94736, 94800
# start, end:94800, 94864
# start, end:94864, 94928
# start, end:94928, 94992
# start, end:94992, 95056
# start, end:95056, 95120
# start, end:95120, 95184
# start, end:95184, 95248
# start, end:95248, 95312
# start, end:95312, 95376
# start, end:95376, 95440
# start, end:95440, 95504
# start, end:95504, 95568
# start, end:95568, 95632
# start, end:95632, 95696
# start, end:95696, 95760
# start, end:95760, 95824
# start, end:95824, 95888
# start, end:95888, 95952
# start, end:95952, 96016
# start, end:96016, 96080
# start, end:96080, 96144
# start, end:96144, 96208
# start, end:96208, 96272
# start, end:96272, 96336
# start, end:96336, 96400
# start, end:96400, 96464
# start, end:96464, 96528
# start, end:96528, 96592
# start, end:96592, 96656
# start, end:96656, 96720
# start, end:96720, 96784
# start, end:96784, 96848
# Phase: train | Epoch: 9 | Count: 15200 \ Start Time: 23:05:01 | Loss: 172
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15200_test_0.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15200_test_1.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15200_test_2.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15200_test_3.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15200_test_4.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15200_test_5.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15200_test_6.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15200_test_7.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15200_test_8.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_15200_test_9.png

# %%
# SAVING MODEL
model_path = os.path.join(root_path, "src", "save", category, '%s.pth' % category)
torch.save(model.state_dict(), model_path)

# %%
def load_model(T, A, B, batch_size, z_size, N, dec_size, enc_size, learning_rate, beta1, clip, path, category):
    torch.set_default_tensor_type('torch.FloatTensor')
    model = DRAW(T, A, B, batch_size, z_size, N, dec_size, enc_size, learning_rate, beta1, clip, path, category)
    base_path = os.getcwd().split("sliver-maestro")[0]
    model_path = os.path.join(base_path, "sliver-maestro", "src", "save", category, '%s.pth' % category)
    model.load_state_dict(torch.load(model_path))
    
    return model

def load_weights(T, A, B, batch_size, z_size, N, dec_size, enc_size, learning_rate, beta1, clip, path, category):
    torch.set_default_tensor_type('torch.FloatTensor')
    model = DRAW(T, A, B, batch_size, z_size, N, dec_size, enc_size, learning_rate, beta1, clip, path, category)
    if USE_CUDA:
        model.cuda()
    base_path = os.getcwd().split('sliver-maestro')[0]
    weights_file = os.path.join(base_path, "sliver-maestro", "src", "save", category, '%s_weights.tar' % category)
    state_dict = torch.load(weights_file, map_location=torch.device('cpu'))
    model.load_state_dict(state_dict)
    
    return model

# %% [markdown]
# ## Testing

# %%
# OPTION 1: LOADS MODEL WEIGHTS
model = load_weights(T, A, B, batch_size, z_size, N, dec_size, enc_size, learning_rate, beta1, clip, path, category)
model.eval()
# Out:
# DRAW(
#   (encoder): LSTMCell(306, 256)
#   (mu_linear): Linear(in_features=256, out_features=10, bias=True)
#   (sigma_linear): Linear(in_features=256, out_features=10, bias=True)
#   (decoder): LSTMCell(10, 256)
#   (dec_linear): Linear(in_features=256, out_features=5, bias=True)
#   (dec_w_linear): Linear(in_features=256, out_features=25, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
# OPTION 2: LOADS MODEL
model = load_model(T, A, B, batch_size, z_size, N, dec_size, enc_size, learning_rate, beta1, clip, path, category)
model.eval()
# Out:
# DRAW(
#   (encoder): LSTMCell(306, 256)
#   (mu_linear): Linear(in_features=256, out_features=10, bias=True)
#   (sigma_linear): Linear(in_features=256, out_features=10, bias=True)
#   (decoder): LSTMCell(10, 256)
#   (dec_linear): Linear(in_features=256, out_features=5, bias=True)
#   (dec_w_linear): Linear(in_features=256, out_features=25, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
test()
# Out:
# testing...
# start, end:0, 64
# start, end:64, 128
# start, end:128, 192
# start, end:192, 256
# start, end:256, 320
# start, end:320, 384
# start, end:384, 448
# start, end:448, 512
# start, end:512, 576
# start, end:576, 640
# start, end:640, 704
# start, end:704, 768
# start, end:768, 832
# start, end:832, 896
# start, end:896, 960
# start, end:960, 1024
# start, end:1024, 1088
# start, end:1088, 1152
# start, end:1152, 1216
# start, end:1216, 1280
# start, end:1280, 1344
# start, end:1344, 1408
# start, end:1408, 1472
# start, end:1472, 1536
# start, end:1536, 1600
# Phase: test | Epoch: 0 | Count: 25 \ Start Time: 23:06:26 | Loss: 43
# start, end:1600, 1664
# start, end:1664, 1728
# start, end:1728, 1792
# start, end:1792, 1856
# start, end:1856, 1920
# start, end:1920, 1984
# start, end:1984, 2048
# start, end:2048, 2112
# start, end:2112, 2176
# start, end:2176, 2240
# start, end:2240, 2304
# start, end:2304, 2368
# start, end:2368, 2432
# start, end:2432, 2496
# start, end:2496, 2560
# start, end:2560, 2624
# start, end:2624, 2688
# start, end:2688, 2752
# start, end:2752, 2816
# start, end:2816, 2880
# start, end:2880, 2944
# start, end:2944, 3008
# start, end:3008, 3072
# start, end:3072, 3136
# start, end:3136, 3200
# Phase: test | Epoch: 0 | Count: 50 \ Start Time: 23:06:30 | Loss: 43
# start, end:3200, 3264
# start, end:3264, 3328
# start, end:3328, 3392
# start, end:3392, 3456
# start, end:3456, 3520
# start, end:3520, 3584
# start, end:3584, 3648
# start, end:3648, 3712
# start, end:3712, 3776
# start, end:3776, 3840
# start, end:3840, 3904
# start, end:3904, 3968
# start, end:3968, 4032
# start, end:4032, 4096
# start, end:4096, 4160
# start, end:4160, 4224
# start, end:4224, 4288
# start, end:4288, 4352
# start, end:4352, 4416
# start, end:4416, 4480
# start, end:4480, 4544
# start, end:4544, 4608
# start, end:4608, 4672
# start, end:4672, 4736
# start, end:4736, 4800
# Phase: test | Epoch: 0 | Count: 75 \ Start Time: 23:06:34 | Loss: 43
# start, end:4800, 4864
# start, end:4864, 4928
# start, end:4928, 4992
# start, end:4992, 5056
# start, end:5056, 5120
# start, end:5120, 5184
# start, end:5184, 5248
# start, end:5248, 5312
# start, end:5312, 5376
# start, end:5376, 5440
# start, end:5440, 5504
# start, end:5504, 5568
# start, end:5568, 5632
# start, end:5632, 5696
# start, end:5696, 5760
# start, end:5760, 5824
# start, end:5824, 5888
# start, end:5888, 5952
# start, end:5952, 6016
# start, end:6016, 6080
# start, end:6080, 6144
# start, end:6144, 6208
# start, end:6208, 6272
# start, end:6272, 6336
# start, end:6336, 6400
# Phase: test | Epoch: 0 | Count: 100 \ Start Time: 23:06:37 | Loss: 43
# start, end:6400, 6464
# start, end:6464, 6528
# start, end:6528, 6592
# start, end:6592, 6656
# start, end:6656, 6720
# start, end:6720, 6784
# start, end:6784, 6848
# start, end:6848, 6912
# start, end:6912, 6976
# start, end:6976, 7040
# start, end:7040, 7104
# start, end:7104, 7168
# start, end:7168, 7232
# start, end:7232, 7296
# start, end:7296, 7360
# start, end:7360, 7424
# start, end:7424, 7488
# start, end:7488, 7552
# start, end:7552, 7616
# start, end:7616, 7680
# start, end:7680, 7744
# start, end:7744, 7808
# start, end:7808, 7872
# start, end:7872, 7936
# start, end:7936, 8000
# Phase: test | Epoch: 0 | Count: 125 \ Start Time: 23:06:41 | Loss: 43
# start, end:8000, 8064
# start, end:8064, 8128
# start, end:8128, 8192
# start, end:8192, 8256
# start, end:8256, 8320
# start, end:8320, 8384
# start, end:8384, 8448
# start, end:8448, 8512
# start, end:8512, 8576
# start, end:8576, 8640
# start, end:8640, 8704
# start, end:8704, 8768
# start, end:8768, 8832
# start, end:8832, 8896
# start, end:8896, 8960
# start, end:8960, 9024
# start, end:9024, 9088
# start, end:9088, 9152
# start, end:9152, 9216
# start, end:9216, 9280
# start, end:9280, 9344
# start, end:9344, 9408
# start, end:9408, 9472
# start, end:9472, 9536
# start, end:9536, 9600
# Phase: test | Epoch: 0 | Count: 150 \ Start Time: 23:06:45 | Loss: 43
# start, end:9600, 9664
# start, end:9664, 9728
# start, end:9728, 9792
# start, end:9792, 9856
# start, end:9856, 9920
# start, end:9920, 9984
# start, end:9984, 10048
# start, end:10048, 10112
# start, end:10112, 10176
# start, end:10176, 10240
# start, end:10240, 10304
# start, end:10304, 10368
# start, end:10368, 10432
# start, end:10432, 10496
# start, end:10496, 10560
# start, end:10560, 10624
# start, end:10624, 10688
# start, end:10688, 10752
# start, end:10752, 10816
# start, end:10816, 10880
# start, end:10880, 10944
# start, end:10944, 11008
# start, end:11008, 11072
# start, end:11072, 11136
# start, end:11136, 11200
# Phase: test | Epoch: 0 | Count: 175 \ Start Time: 23:06:48 | Loss: 43
# start, end:11200, 11264
# start, end:11264, 11328
# start, end:11328, 11392
# start, end:11392, 11456
# start, end:11456, 11520
# start, end:11520, 11584
# start, end:11584, 11648
# start, end:11648, 11712
# start, end:11712, 11776
# start, end:11776, 11840
# start, end:11840, 11904
# start, end:11904, 11968
# start, end:11968, 12032
# start, end:12032, 12096
# start, end:12096, 12160
# start, end:12160, 12224
# start, end:12224, 12288
# start, end:12288, 12352
# start, end:12352, 12416
# start, end:12416, 12480
# start, end:12480, 12544
# start, end:12544, 12608
# start, end:12608, 12672
# start, end:12672, 12736
# start, end:12736, 12800
# Phase: test | Epoch: 0 | Count: 200 \ Start Time: 23:06:52 | Loss: 42
# start, end:12800, 12864
# start, end:12864, 12928
# start, end:12928, 12992
# start, end:12992, 13056
# start, end:13056, 13120
# start, end:13120, 13184
# start, end:13184, 13248
# start, end:13248, 13312
# start, end:13312, 13376
# start, end:13376, 13440
# start, end:13440, 13504
# start, end:13504, 13568
# start, end:13568, 13632
# start, end:13632, 13696
# start, end:13696, 13760
# start, end:13760, 13824
# start, end:13824, 13888
# start, end:13888, 13952
# start, end:13952, 14016
# start, end:14016, 14080
# start, end:14080, 14144
# start, end:14144, 14208
# start, end:14208, 14272
# start, end:14272, 14336
# start, end:14336, 14400
# Phase: test | Epoch: 0 | Count: 225 \ Start Time: 23:06:55 | Loss: 42
# start, end:14400, 14464
# start, end:14464, 14528
# start, end:14528, 14592
# start, end:14592, 14656
# start, end:14656, 14720
# start, end:14720, 14784
# start, end:14784, 14848
# start, end:14848, 14912
# start, end:14912, 14976
# start, end:14976, 15040
# start, end:15040, 15104
# start, end:15104, 15168
# start, end:15168, 15232
# start, end:15232, 15296
# start, end:15296, 15360
# start, end:15360, 15424
# start, end:15424, 15488
# start, end:15488, 15552
# start, end:15552, 15616
# start, end:15616, 15680
# start, end:15680, 15744
# start, end:15744, 15808
# start, end:15808, 15872
# start, end:15872, 15936
# start, end:15936, 16000
# Phase: test | Epoch: 0 | Count: 250 \ Start Time: 23:06:59 | Loss: 43
# start, end:16000, 16064
# start, end:16064, 16128
# start, end:16128, 16192
# start, end:16192, 16256
# start, end:16256, 16320
# start, end:16320, 16384
# start, end:16384, 16448
# start, end:16448, 16512
# start, end:16512, 16576
# start, end:16576, 16640
# start, end:16640, 16704
# start, end:16704, 16768
# start, end:16768, 16832
# start, end:16832, 16896
# start, end:16896, 16960
# start, end:16960, 17024
# start, end:17024, 17088
# start, end:17088, 17152
# start, end:17152, 17216
# start, end:17216, 17280
# start, end:17280, 17344
# start, end:17344, 17408
# start, end:17408, 17472
# start, end:17472, 17536
# start, end:17536, 17600
# Phase: test | Epoch: 0 | Count: 275 \ Start Time: 23:07:03 | Loss: 43
# start, end:17600, 17664
# start, end:17664, 17728
# start, end:17728, 17792
# start, end:17792, 17856
# start, end:17856, 17920
# start, end:17920, 17984
# start, end:17984, 18048
# start, end:18048, 18112
# start, end:18112, 18176
# start, end:18176, 18240
# start, end:18240, 18304
# start, end:18304, 18368
# start, end:18368, 18432
# start, end:18432, 18496
# start, end:18496, 18560
# start, end:18560, 18624
# start, end:18624, 18688
# start, end:18688, 18752
# start, end:18752, 18816
# start, end:18816, 18880
# start, end:18880, 18944
# start, end:18944, 19008
# start, end:19008, 19072
# start, end:19072, 19136
# start, end:19136, 19200
# Phase: test | Epoch: 0 | Count: 300 \ Start Time: 23:07:06 | Loss: 42
# start, end:19200, 19264
# start, end:19264, 19328
# start, end:19328, 19392
# start, end:19392, 19456
# start, end:19456, 19520
# start, end:19520, 19584
# start, end:19584, 19648
# start, end:19648, 19712
# start, end:19712, 19776
# start, end:19776, 19840
# start, end:19840, 19904
# start, end:19904, 19968
# start, end:19968, 20032
# start, end:20032, 20096
# start, end:20096, 20160
# start, end:20160, 20224
# start, end:20224, 20288
# start, end:20288, 20352
# start, end:20352, 20416
# start, end:20416, 20480
# start, end:20480, 20544
# start, end:20544, 20608
# start, end:20608, 20672
# start, end:20672, 20736
# start, end:20736, 20800
# Phase: test | Epoch: 0 | Count: 325 \ Start Time: 23:07:11 | Loss: 43
# start, end:20800, 20864
# start, end:20864, 20928
# start, end:20928, 20992
# start, end:20992, 21056
# start, end:21056, 21120
# start, end:21120, 21184
# start, end:21184, 21248
# start, end:21248, 21312
# start, end:21312, 21376
# start, end:21376, 21440
# start, end:21440, 21504
# start, end:21504, 21568
# start, end:21568, 21632
# start, end:21632, 21696
# start, end:21696, 21760
# start, end:21760, 21824
# start, end:21824, 21888
# start, end:21888, 21952
# start, end:21952, 22016
# start, end:22016, 22080
# start, end:22080, 22144
# start, end:22144, 22208
# start, end:22208, 22272
# start, end:22272, 22336
# start, end:22336, 22400
# Phase: test | Epoch: 0 | Count: 350 \ Start Time: 23:07:16 | Loss: 43
# start, end:22400, 22464
# start, end:22464, 22528
# start, end:22528, 22592
# start, end:22592, 22656
# start, end:22656, 22720
# start, end:22720, 22784
# start, end:22784, 22848
# start, end:22848, 22912
# start, end:22912, 22976
# start, end:22976, 23040
# start, end:23040, 23104
# start, end:23104, 23168
# start, end:23168, 23232
# start, end:23232, 23296
# start, end:23296, 23360
# start, end:23360, 23424
# start, end:23424, 23488
# start, end:23488, 23552
# start, end:23552, 23616
# start, end:23616, 23680
# start, end:23680, 23744
# start, end:23744, 23808
# start, end:23808, 23872
# start, end:23872, 23936
# start, end:23936, 24000
# Phase: test | Epoch: 0 | Count: 375 \ Start Time: 23:07:21 | Loss: 43
# start, end:24000, 24064
# start, end:24064, 24128
# start, end:24128, 24192
# start, end:24192, 24256
# start, end:24256, 24320
# start, end:0, 51
# start, end:51, 115
# start, end:115, 179
# start, end:179, 243
# start, end:243, 307
# start, end:307, 371
# start, end:371, 435
# start, end:435, 499
# start, end:499, 563
# start, end:563, 627
# start, end:627, 691
# start, end:691, 755
# start, end:755, 819
# start, end:819, 883
# start, end:883, 947
# start, end:947, 1011
# start, end:1011, 1075
# start, end:1075, 1139
# start, end:1139, 1203
# start, end:1203, 1267
# Phase: test | Epoch: 1 | Count: 400 \ Start Time: 23:07:26 | Loss: 43
# start, end:1267, 1331
# start, end:1331, 1395
# start, end:1395, 1459
# start, end:1459, 1523
# start, end:1523, 1587
# start, end:1587, 1651
# start, end:1651, 1715
# start, end:1715, 1779
# start, end:1779, 1843
# start, end:1843, 1907
# start, end:1907, 1971
# start, end:1971, 2035
# start, end:2035, 2099
# start, end:2099, 2163
# start, end:2163, 2227
# start, end:2227, 2291
# start, end:2291, 2355
# start, end:2355, 2419
# start, end:2419, 2483
# start, end:2483, 2547
# start, end:2547, 2611
# start, end:2611, 2675
# start, end:2675, 2739
# start, end:2739, 2803
# start, end:2803, 2867
# Phase: test | Epoch: 1 | Count: 425 \ Start Time: 23:07:30 | Loss: 42
# start, end:2867, 2931
# start, end:2931, 2995
# start, end:2995, 3059
# start, end:3059, 3123
# start, end:3123, 3187
# start, end:3187, 3251
# start, end:3251, 3315
# start, end:3315, 3379
# start, end:3379, 3443
# start, end:3443, 3507
# start, end:3507, 3571
# start, end:3571, 3635
# start, end:3635, 3699
# start, end:3699, 3763
# start, end:3763, 3827
# start, end:3827, 3891
# start, end:3891, 3955
# start, end:3955, 4019
# start, end:4019, 4083
# start, end:4083, 4147
# start, end:4147, 4211
# start, end:4211, 4275
# start, end:4275, 4339
# start, end:4339, 4403
# start, end:4403, 4467
# Phase: test | Epoch: 1 | Count: 450 \ Start Time: 23:07:37 | Loss: 43
# start, end:4467, 4531
# start, end:4531, 4595
# start, end:4595, 4659
# start, end:4659, 4723
# start, end:4723, 4787
# start, end:4787, 4851
# start, end:4851, 4915
# start, end:4915, 4979
# start, end:4979, 5043
# start, end:5043, 5107
# start, end:5107, 5171
# start, end:5171, 5235
# start, end:5235, 5299
# start, end:5299, 5363
# start, end:5363, 5427
# start, end:5427, 5491
# start, end:5491, 5555
# start, end:5555, 5619
# start, end:5619, 5683
# start, end:5683, 5747
# start, end:5747, 5811
# start, end:5811, 5875
# start, end:5875, 5939
# start, end:5939, 6003
# start, end:6003, 6067
# Phase: test | Epoch: 1 | Count: 475 \ Start Time: 23:07:44 | Loss: 43
# start, end:6067, 6131
# start, end:6131, 6195
# start, end:6195, 6259
# start, end:6259, 6323
# start, end:6323, 6387
# start, end:6387, 6451
# start, end:6451, 6515
# start, end:6515, 6579
# start, end:6579, 6643
# start, end:6643, 6707
# start, end:6707, 6771
# start, end:6771, 6835
# start, end:6835, 6899
# start, end:6899, 6963
# start, end:6963, 7027
# start, end:7027, 7091
# start, end:7091, 7155
# start, end:7155, 7219
# start, end:7219, 7283
# start, end:7283, 7347
# start, end:7347, 7411
# start, end:7411, 7475
# start, end:7475, 7539
# start, end:7539, 7603
# start, end:7603, 7667
# Phase: test | Epoch: 1 | Count: 500 \ Start Time: 23:07:49 | Loss: 43
# start, end:7667, 7731
# start, end:7731, 7795
# start, end:7795, 7859
# start, end:7859, 7923
# start, end:7923, 7987
# start, end:7987, 8051
# start, end:8051, 8115
# start, end:8115, 8179
# start, end:8179, 8243
# start, end:8243, 8307
# start, end:8307, 8371
# start, end:8371, 8435
# start, end:8435, 8499
# start, end:8499, 8563
# start, end:8563, 8627
# start, end:8627, 8691
# start, end:8691, 8755
# start, end:8755, 8819
# start, end:8819, 8883
# start, end:8883, 8947
# start, end:8947, 9011
# start, end:9011, 9075
# start, end:9075, 9139
# start, end:9139, 9203
# start, end:9203, 9267
# Phase: test | Epoch: 1 | Count: 525 \ Start Time: 23:07:54 | Loss: 43
# start, end:9267, 9331
# start, end:9331, 9395
# start, end:9395, 9459
# start, end:9459, 9523
# start, end:9523, 9587
# start, end:9587, 9651
# start, end:9651, 9715
# start, end:9715, 9779
# start, end:9779, 9843
# start, end:9843, 9907
# start, end:9907, 9971
# start, end:9971, 10035
# start, end:10035, 10099
# start, end:10099, 10163
# start, end:10163, 10227
# start, end:10227, 10291
# start, end:10291, 10355
# start, end:10355, 10419
# start, end:10419, 10483
# start, end:10483, 10547
# start, end:10547, 10611
# start, end:10611, 10675
# start, end:10675, 10739
# start, end:10739, 10803
# start, end:10803, 10867
# Phase: test | Epoch: 1 | Count: 550 \ Start Time: 23:07:59 | Loss: 43
# start, end:10867, 10931
# start, end:10931, 10995
# start, end:10995, 11059
# start, end:11059, 11123
# start, end:11123, 11187
# start, end:11187, 11251
# start, end:11251, 11315
# start, end:11315, 11379
# start, end:11379, 11443
# start, end:11443, 11507
# start, end:11507, 11571
# start, end:11571, 11635
# start, end:11635, 11699
# start, end:11699, 11763
# start, end:11763, 11827
# start, end:11827, 11891
# start, end:11891, 11955
# start, end:11955, 12019
# start, end:12019, 12083
# start, end:12083, 12147
# start, end:12147, 12211
# start, end:12211, 12275
# start, end:12275, 12339
# start, end:12339, 12403
# start, end:12403, 12467
# Phase: test | Epoch: 1 | Count: 575 \ Start Time: 23:08:05 | Loss: 43
# start, end:12467, 12531
# start, end:12531, 12595
# start, end:12595, 12659
# start, end:12659, 12723
# start, end:12723, 12787
# start, end:12787, 12851
# start, end:12851, 12915
# start, end:12915, 12979
# start, end:12979, 13043
# start, end:13043, 13107
# start, end:13107, 13171
# start, end:13171, 13235
# start, end:13235, 13299
# start, end:13299, 13363
# start, end:13363, 13427
# start, end:13427, 13491
# start, end:13491, 13555
# start, end:13555, 13619
# start, end:13619, 13683
# start, end:13683, 13747
# start, end:13747, 13811
# start, end:13811, 13875
# start, end:13875, 13939
# start, end:13939, 14003
# start, end:14003, 14067
# Phase: test | Epoch: 1 | Count: 600 \ Start Time: 23:08:10 | Loss: 42
# start, end:14067, 14131
# start, end:14131, 14195
# start, end:14195, 14259
# start, end:14259, 14323
# start, end:14323, 14387
# start, end:14387, 14451
# start, end:14451, 14515
# start, end:14515, 14579
# start, end:14579, 14643
# start, end:14643, 14707
# start, end:14707, 14771
# start, end:14771, 14835
# start, end:14835, 14899
# start, end:14899, 14963
# start, end:14963, 15027
# start, end:15027, 15091
# start, end:15091, 15155
# start, end:15155, 15219
# start, end:15219, 15283
# start, end:15283, 15347
# start, end:15347, 15411
# start, end:15411, 15475
# start, end:15475, 15539
# start, end:15539, 15603
# start, end:15603, 15667
# Phase: test | Epoch: 1 | Count: 625 \ Start Time: 23:08:15 | Loss: 43
# start, end:15667, 15731
# start, end:15731, 15795
# start, end:15795, 15859
# start, end:15859, 15923
# start, end:15923, 15987
# start, end:15987, 16051
# start, end:16051, 16115
# start, end:16115, 16179
# start, end:16179, 16243
# start, end:16243, 16307
# start, end:16307, 16371
# start, end:16371, 16435
# start, end:16435, 16499
# start, end:16499, 16563
# start, end:16563, 16627
# start, end:16627, 16691
# start, end:16691, 16755
# start, end:16755, 16819
# start, end:16819, 16883
# start, end:16883, 16947
# start, end:16947, 17011
# start, end:17011, 17075
# start, end:17075, 17139
# start, end:17139, 17203
# start, end:17203, 17267
# Phase: test | Epoch: 1 | Count: 650 \ Start Time: 23:08:22 | Loss: 43
# start, end:17267, 17331
# start, end:17331, 17395
# start, end:17395, 17459
# start, end:17459, 17523
# start, end:17523, 17587
# start, end:17587, 17651
# start, end:17651, 17715
# start, end:17715, 17779
# start, end:17779, 17843
# start, end:17843, 17907
# start, end:17907, 17971
# start, end:17971, 18035
# start, end:18035, 18099
# start, end:18099, 18163
# start, end:18163, 18227
# start, end:18227, 18291
# start, end:18291, 18355
# start, end:18355, 18419
# start, end:18419, 18483
# start, end:18483, 18547
# start, end:18547, 18611
# start, end:18611, 18675
# start, end:18675, 18739
# start, end:18739, 18803
# start, end:18803, 18867
# Phase: test | Epoch: 1 | Count: 675 \ Start Time: 23:08:28 | Loss: 42
# start, end:18867, 18931
# start, end:18931, 18995
# start, end:18995, 19059
# start, end:19059, 19123
# start, end:19123, 19187
# start, end:19187, 19251
# start, end:19251, 19315
# start, end:19315, 19379
# start, end:19379, 19443
# start, end:19443, 19507
# start, end:19507, 19571
# start, end:19571, 19635
# start, end:19635, 19699
# start, end:19699, 19763
# start, end:19763, 19827
# start, end:19827, 19891
# start, end:19891, 19955
# start, end:19955, 20019
# start, end:20019, 20083
# start, end:20083, 20147
# start, end:20147, 20211
# start, end:20211, 20275
# start, end:20275, 20339
# start, end:20339, 20403
# start, end:20403, 20467
# Phase: test | Epoch: 1 | Count: 700 \ Start Time: 23:08:34 | Loss: 43
# start, end:20467, 20531
# start, end:20531, 20595
# start, end:20595, 20659
# start, end:20659, 20723
# start, end:20723, 20787
# start, end:20787, 20851
# start, end:20851, 20915
# start, end:20915, 20979
# start, end:20979, 21043
# start, end:21043, 21107
# start, end:21107, 21171
# start, end:21171, 21235
# start, end:21235, 21299
# start, end:21299, 21363
# start, end:21363, 21427
# start, end:21427, 21491
# start, end:21491, 21555
# start, end:21555, 21619
# start, end:21619, 21683
# start, end:21683, 21747
# start, end:21747, 21811
# start, end:21811, 21875
# start, end:21875, 21939
# start, end:21939, 22003
# start, end:22003, 22067
# Phase: test | Epoch: 1 | Count: 725 \ Start Time: 23:08:39 | Loss: 43
# start, end:22067, 22131
# start, end:22131, 22195
# start, end:22195, 22259
# start, end:22259, 22323
# start, end:22323, 22387
# start, end:22387, 22451
# start, end:22451, 22515
# start, end:22515, 22579
# start, end:22579, 22643
# start, end:22643, 22707
# start, end:22707, 22771
# start, end:22771, 22835
# start, end:22835, 22899
# start, end:22899, 22963
# start, end:22963, 23027
# start, end:23027, 23091
# start, end:23091, 23155
# start, end:23155, 23219
# start, end:23219, 23283
# start, end:23283, 23347
# start, end:23347, 23411
# start, end:23411, 23475
# start, end:23475, 23539
# start, end:23539, 23603
# start, end:23603, 23667
# Phase: test | Epoch: 1 | Count: 750 \ Start Time: 23:08:44 | Loss: 43
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_750_test_0.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_750_test_1.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_750_test_2.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_750_test_3.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_750_test_4.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_750_test_5.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_750_test_6.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_750_test_7.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_750_test_8.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_750_test_9.png
# start, end:23667, 23731
# start, end:23731, 23795
# start, end:23795, 23859
# start, end:23859, 23923
# start, end:23923, 23987
# start, end:23987, 24051
# start, end:24051, 24115
# start, end:24115, 24179
# start, end:24179, 24243
# start, end:24243, 24307
# start, end:0, 38
# start, end:38, 102
# start, end:102, 166
# start, end:166, 230
# start, end:230, 294
# start, end:294, 358
# start, end:358, 422
# start, end:422, 486
# start, end:486, 550
# start, end:550, 614
# start, end:614, 678
# start, end:678, 742
# start, end:742, 806
# start, end:806, 870
# start, end:870, 934
# Phase: test | Epoch: 2 | Count: 775 \ Start Time: 23:08:52 | Loss: 43
# start, end:934, 998
# start, end:998, 1062
# start, end:1062, 1126
# start, end:1126, 1190
# start, end:1190, 1254
# start, end:1254, 1318
# start, end:1318, 1382
# start, end:1382, 1446
# start, end:1446, 1510
# start, end:1510, 1574
# start, end:1574, 1638
# start, end:1638, 1702
# start, end:1702, 1766
# start, end:1766, 1830
# start, end:1830, 1894
# start, end:1894, 1958
# start, end:1958, 2022
# start, end:2022, 2086
# start, end:2086, 2150
# start, end:2150, 2214
# start, end:2214, 2278
# start, end:2278, 2342
# start, end:2342, 2406
# start, end:2406, 2470
# start, end:2470, 2534
# Phase: test | Epoch: 2 | Count: 800 \ Start Time: 23:08:57 | Loss: 43
# start, end:2534, 2598
# start, end:2598, 2662
# start, end:2662, 2726
# start, end:2726, 2790
# start, end:2790, 2854
# start, end:2854, 2918
# start, end:2918, 2982
# start, end:2982, 3046
# start, end:3046, 3110
# start, end:3110, 3174
# start, end:3174, 3238
# start, end:3238, 3302
# start, end:3302, 3366
# start, end:3366, 3430
# start, end:3430, 3494
# start, end:3494, 3558
# start, end:3558, 3622
# start, end:3622, 3686
# start, end:3686, 3750
# start, end:3750, 3814
# start, end:3814, 3878
# start, end:3878, 3942
# start, end:3942, 4006
# start, end:4006, 4070
# start, end:4070, 4134
# Phase: test | Epoch: 2 | Count: 825 \ Start Time: 23:09:02 | Loss: 43
# start, end:4134, 4198
# start, end:4198, 4262
# start, end:4262, 4326
# start, end:4326, 4390
# start, end:4390, 4454
# start, end:4454, 4518
# start, end:4518, 4582
# start, end:4582, 4646
# start, end:4646, 4710
# start, end:4710, 4774
# start, end:4774, 4838
# start, end:4838, 4902
# start, end:4902, 4966
# start, end:4966, 5030
# start, end:5030, 5094
# start, end:5094, 5158
# start, end:5158, 5222
# start, end:5222, 5286
# start, end:5286, 5350
# start, end:5350, 5414
# start, end:5414, 5478
# start, end:5478, 5542
# start, end:5542, 5606
# start, end:5606, 5670
# start, end:5670, 5734
# Phase: test | Epoch: 2 | Count: 850 \ Start Time: 23:09:08 | Loss: 43
# start, end:5734, 5798
# start, end:5798, 5862
# start, end:5862, 5926
# start, end:5926, 5990
# start, end:5990, 6054
# start, end:6054, 6118
# start, end:6118, 6182
# start, end:6182, 6246
# start, end:6246, 6310
# start, end:6310, 6374
# start, end:6374, 6438
# start, end:6438, 6502
# start, end:6502, 6566
# start, end:6566, 6630
# start, end:6630, 6694
# start, end:6694, 6758
# start, end:6758, 6822
# start, end:6822, 6886
# start, end:6886, 6950
# start, end:6950, 7014
# start, end:7014, 7078
# start, end:7078, 7142
# start, end:7142, 7206
# start, end:7206, 7270
# start, end:7270, 7334
# Phase: test | Epoch: 2 | Count: 875 \ Start Time: 23:09:14 | Loss: 43
# start, end:7334, 7398
# start, end:7398, 7462
# start, end:7462, 7526
# start, end:7526, 7590
# start, end:7590, 7654
# start, end:7654, 7718
# start, end:7718, 7782
# start, end:7782, 7846
# start, end:7846, 7910
# start, end:7910, 7974
# start, end:7974, 8038
# start, end:8038, 8102
# start, end:8102, 8166
# start, end:8166, 8230
# start, end:8230, 8294
# start, end:8294, 8358
# start, end:8358, 8422
# start, end:8422, 8486
# start, end:8486, 8550
# start, end:8550, 8614
# start, end:8614, 8678
# start, end:8678, 8742
# start, end:8742, 8806
# start, end:8806, 8870
# start, end:8870, 8934
# Phase: test | Epoch: 2 | Count: 900 \ Start Time: 23:09:20 | Loss: 43
# start, end:8934, 8998
# start, end:8998, 9062
# start, end:9062, 9126
# start, end:9126, 9190
# start, end:9190, 9254
# start, end:9254, 9318
# start, end:9318, 9382
# start, end:9382, 9446
# start, end:9446, 9510
# start, end:9510, 9574
# start, end:9574, 9638
# start, end:9638, 9702
# start, end:9702, 9766
# start, end:9766, 9830
# start, end:9830, 9894
# start, end:9894, 9958
# start, end:9958, 10022
# start, end:10022, 10086
# start, end:10086, 10150
# start, end:10150, 10214
# start, end:10214, 10278
# start, end:10278, 10342
# start, end:10342, 10406
# start, end:10406, 10470
# start, end:10470, 10534
# Phase: test | Epoch: 2 | Count: 925 \ Start Time: 23:09:25 | Loss: 43
# start, end:10534, 10598
# start, end:10598, 10662
# start, end:10662, 10726
# start, end:10726, 10790
# start, end:10790, 10854
# start, end:10854, 10918
# start, end:10918, 10982
# start, end:10982, 11046
# start, end:11046, 11110
# start, end:11110, 11174
# start, end:11174, 11238
# start, end:11238, 11302
# start, end:11302, 11366
# start, end:11366, 11430
# start, end:11430, 11494
# start, end:11494, 11558
# start, end:11558, 11622
# start, end:11622, 11686
# start, end:11686, 11750
# start, end:11750, 11814
# start, end:11814, 11878
# start, end:11878, 11942
# start, end:11942, 12006
# start, end:12006, 12070
# start, end:12070, 12134
# Phase: test | Epoch: 2 | Count: 950 \ Start Time: 23:09:31 | Loss: 43
# start, end:12134, 12198
# start, end:12198, 12262
# start, end:12262, 12326
# start, end:12326, 12390
# start, end:12390, 12454
# start, end:12454, 12518
# start, end:12518, 12582
# start, end:12582, 12646
# start, end:12646, 12710
# start, end:12710, 12774
# start, end:12774, 12838
# start, end:12838, 12902
# start, end:12902, 12966
# start, end:12966, 13030
# start, end:13030, 13094
# start, end:13094, 13158
# start, end:13158, 13222
# start, end:13222, 13286
# start, end:13286, 13350
# start, end:13350, 13414
# start, end:13414, 13478
# start, end:13478, 13542
# start, end:13542, 13606
# start, end:13606, 13670
# start, end:13670, 13734
# Phase: test | Epoch: 2 | Count: 975 \ Start Time: 23:09:37 | Loss: 42
# start, end:13734, 13798
# start, end:13798, 13862
# start, end:13862, 13926
# start, end:13926, 13990
# start, end:13990, 14054
# start, end:14054, 14118
# start, end:14118, 14182
# start, end:14182, 14246
# start, end:14246, 14310
# start, end:14310, 14374
# start, end:14374, 14438
# start, end:14438, 14502
# start, end:14502, 14566
# start, end:14566, 14630
# start, end:14630, 14694
# start, end:14694, 14758
# start, end:14758, 14822
# start, end:14822, 14886
# start, end:14886, 14950
# start, end:14950, 15014
# start, end:15014, 15078
# start, end:15078, 15142
# start, end:15142, 15206
# start, end:15206, 15270
# start, end:15270, 15334
# Phase: test | Epoch: 2 | Count: 1000 \ Start Time: 23:09:43 | Loss: 43
# start, end:15334, 15398
# start, end:15398, 15462
# start, end:15462, 15526
# start, end:15526, 15590
# start, end:15590, 15654
# start, end:15654, 15718
# start, end:15718, 15782
# start, end:15782, 15846
# start, end:15846, 15910
# start, end:15910, 15974
# start, end:15974, 16038
# start, end:16038, 16102
# start, end:16102, 16166
# start, end:16166, 16230
# start, end:16230, 16294
# start, end:16294, 16358
# start, end:16358, 16422
# start, end:16422, 16486
# start, end:16486, 16550
# start, end:16550, 16614
# start, end:16614, 16678
# start, end:16678, 16742
# start, end:16742, 16806
# start, end:16806, 16870
# start, end:16870, 16934
# Phase: test | Epoch: 2 | Count: 1025 \ Start Time: 23:09:48 | Loss: 43
# start, end:16934, 16998
# start, end:16998, 17062
# start, end:17062, 17126
# start, end:17126, 17190
# start, end:17190, 17254
# start, end:17254, 17318
# start, end:17318, 17382
# start, end:17382, 17446
# start, end:17446, 17510
# start, end:17510, 17574
# start, end:17574, 17638
# start, end:17638, 17702
# start, end:17702, 17766
# start, end:17766, 17830
# start, end:17830, 17894
# start, end:17894, 17958
# start, end:17958, 18022
# start, end:18022, 18086
# start, end:18086, 18150
# start, end:18150, 18214
# start, end:18214, 18278
# start, end:18278, 18342
# start, end:18342, 18406
# start, end:18406, 18470
# start, end:18470, 18534
# Phase: test | Epoch: 2 | Count: 1050 \ Start Time: 23:09:53 | Loss: 42
# start, end:18534, 18598
# start, end:18598, 18662
# start, end:18662, 18726
# start, end:18726, 18790
# start, end:18790, 18854
# start, end:18854, 18918
# start, end:18918, 18982
# start, end:18982, 19046
# start, end:19046, 19110
# start, end:19110, 19174
# start, end:19174, 19238
# start, end:19238, 19302
# start, end:19302, 19366
# start, end:19366, 19430
# start, end:19430, 19494
# start, end:19494, 19558
# start, end:19558, 19622
# start, end:19622, 19686
# start, end:19686, 19750
# start, end:19750, 19814
# start, end:19814, 19878
# start, end:19878, 19942
# start, end:19942, 20006
# start, end:20006, 20070
# start, end:20070, 20134
# Phase: test | Epoch: 2 | Count: 1075 \ Start Time: 23:09:58 | Loss: 43
# start, end:20134, 20198
# start, end:20198, 20262
# start, end:20262, 20326
# start, end:20326, 20390
# start, end:20390, 20454
# start, end:20454, 20518
# start, end:20518, 20582
# start, end:20582, 20646
# start, end:20646, 20710
# start, end:20710, 20774
# start, end:20774, 20838
# start, end:20838, 20902
# start, end:20902, 20966
# start, end:20966, 21030
# start, end:21030, 21094
# start, end:21094, 21158
# start, end:21158, 21222
# start, end:21222, 21286
# start, end:21286, 21350
# start, end:21350, 21414
# start, end:21414, 21478
# start, end:21478, 21542
# start, end:21542, 21606
# start, end:21606, 21670
# start, end:21670, 21734
# Phase: test | Epoch: 2 | Count: 1100 \ Start Time: 23:10:03 | Loss: 43
# start, end:21734, 21798
# start, end:21798, 21862
# start, end:21862, 21926
# start, end:21926, 21990
# start, end:21990, 22054
# start, end:22054, 22118
# start, end:22118, 22182
# start, end:22182, 22246
# start, end:22246, 22310
# start, end:22310, 22374
# start, end:22374, 22438
# start, end:22438, 22502
# start, end:22502, 22566
# start, end:22566, 22630
# start, end:22630, 22694
# start, end:22694, 22758
# start, end:22758, 22822
# start, end:22822, 22886
# start, end:22886, 22950
# start, end:22950, 23014
# start, end:23014, 23078
# start, end:23078, 23142
# start, end:23142, 23206
# start, end:23206, 23270
# start, end:23270, 23334
# Phase: test | Epoch: 2 | Count: 1125 \ Start Time: 23:10:09 | Loss: 43
# start, end:23334, 23398
# start, end:23398, 23462
# start, end:23462, 23526
# start, end:23526, 23590
# start, end:23590, 23654
# start, end:23654, 23718
# start, end:23718, 23782
# start, end:23782, 23846
# start, end:23846, 23910
# start, end:23910, 23974
# start, end:23974, 24038
# start, end:24038, 24102
# start, end:24102, 24166
# start, end:24166, 24230
# start, end:24230, 24294
# start, end:0, 25
# start, end:25, 89
# start, end:89, 153
# start, end:153, 217
# start, end:217, 281
# start, end:281, 345
# start, end:345, 409
# start, end:409, 473
# start, end:473, 537
# start, end:537, 601
# Phase: test | Epoch: 3 | Count: 1150 \ Start Time: 23:10:15 | Loss: 43
# start, end:601, 665
# start, end:665, 729
# start, end:729, 793
# start, end:793, 857
# start, end:857, 921
# start, end:921, 985
# start, end:985, 1049
# start, end:1049, 1113
# start, end:1113, 1177
# start, end:1177, 1241
# start, end:1241, 1305
# start, end:1305, 1369
# start, end:1369, 1433
# start, end:1433, 1497
# start, end:1497, 1561
# start, end:1561, 1625
# start, end:1625, 1689
# start, end:1689, 1753
# start, end:1753, 1817
# start, end:1817, 1881
# start, end:1881, 1945
# start, end:1945, 2009
# start, end:2009, 2073
# start, end:2073, 2137
# start, end:2137, 2201
# Phase: test | Epoch: 3 | Count: 1175 \ Start Time: 23:10:20 | Loss: 42
# start, end:2201, 2265
# start, end:2265, 2329
# start, end:2329, 2393
# start, end:2393, 2457
# start, end:2457, 2521
# start, end:2521, 2585
# start, end:2585, 2649
# start, end:2649, 2713
# start, end:2713, 2777
# start, end:2777, 2841
# start, end:2841, 2905
# start, end:2905, 2969
# start, end:2969, 3033
# start, end:3033, 3097
# start, end:3097, 3161
# start, end:3161, 3225
# start, end:3225, 3289
# start, end:3289, 3353
# start, end:3353, 3417
# start, end:3417, 3481
# start, end:3481, 3545
# start, end:3545, 3609
# start, end:3609, 3673
# start, end:3673, 3737
# start, end:3737, 3801
# Phase: test | Epoch: 3 | Count: 1200 \ Start Time: 23:10:27 | Loss: 43
# start, end:3801, 3865
# start, end:3865, 3929
# start, end:3929, 3993
# start, end:3993, 4057
# start, end:4057, 4121
# start, end:4121, 4185
# start, end:4185, 4249
# start, end:4249, 4313
# start, end:4313, 4377
# start, end:4377, 4441
# start, end:4441, 4505
# start, end:4505, 4569
# start, end:4569, 4633
# start, end:4633, 4697
# start, end:4697, 4761
# start, end:4761, 4825
# start, end:4825, 4889
# start, end:4889, 4953
# start, end:4953, 5017
# start, end:5017, 5081
# start, end:5081, 5145
# start, end:5145, 5209
# start, end:5209, 5273
# start, end:5273, 5337
# start, end:5337, 5401
# Phase: test | Epoch: 3 | Count: 1225 \ Start Time: 23:10:33 | Loss: 43
# start, end:5401, 5465
# start, end:5465, 5529
# start, end:5529, 5593
# start, end:5593, 5657
# start, end:5657, 5721
# start, end:5721, 5785
# start, end:5785, 5849
# start, end:5849, 5913
# start, end:5913, 5977
# start, end:5977, 6041
# start, end:6041, 6105
# start, end:6105, 6169
# start, end:6169, 6233
# start, end:6233, 6297
# start, end:6297, 6361
# start, end:6361, 6425
# start, end:6425, 6489
# start, end:6489, 6553
# start, end:6553, 6617
# start, end:6617, 6681
# start, end:6681, 6745
# start, end:6745, 6809
# start, end:6809, 6873
# start, end:6873, 6937
# start, end:6937, 7001
# Phase: test | Epoch: 3 | Count: 1250 \ Start Time: 23:10:39 | Loss: 43
# start, end:7001, 7065
# start, end:7065, 7129
# start, end:7129, 7193
# start, end:7193, 7257
# start, end:7257, 7321
# start, end:7321, 7385
# start, end:7385, 7449
# start, end:7449, 7513
# start, end:7513, 7577
# start, end:7577, 7641
# start, end:7641, 7705
# start, end:7705, 7769
# start, end:7769, 7833
# start, end:7833, 7897
# start, end:7897, 7961
# start, end:7961, 8025
# start, end:8025, 8089
# start, end:8089, 8153
# start, end:8153, 8217
# start, end:8217, 8281
# start, end:8281, 8345
# start, end:8345, 8409
# start, end:8409, 8473
# start, end:8473, 8537
# start, end:8537, 8601
# Phase: test | Epoch: 3 | Count: 1275 \ Start Time: 23:10:44 | Loss: 43
# start, end:8601, 8665
# start, end:8665, 8729
# start, end:8729, 8793
# start, end:8793, 8857
# start, end:8857, 8921
# start, end:8921, 8985
# start, end:8985, 9049
# start, end:9049, 9113
# start, end:9113, 9177
# start, end:9177, 9241
# start, end:9241, 9305
# start, end:9305, 9369
# start, end:9369, 9433
# start, end:9433, 9497
# start, end:9497, 9561
# start, end:9561, 9625
# start, end:9625, 9689
# start, end:9689, 9753
# start, end:9753, 9817
# start, end:9817, 9881
# start, end:9881, 9945
# start, end:9945, 10009
# start, end:10009, 10073
# start, end:10073, 10137
# start, end:10137, 10201
# Phase: test | Epoch: 3 | Count: 1300 \ Start Time: 23:10:50 | Loss: 43
# start, end:10201, 10265
# start, end:10265, 10329
# start, end:10329, 10393
# start, end:10393, 10457
# start, end:10457, 10521
# start, end:10521, 10585
# start, end:10585, 10649
# start, end:10649, 10713
# start, end:10713, 10777
# start, end:10777, 10841
# start, end:10841, 10905
# start, end:10905, 10969
# start, end:10969, 11033
# start, end:11033, 11097
# start, end:11097, 11161
# start, end:11161, 11225
# start, end:11225, 11289
# start, end:11289, 11353
# start, end:11353, 11417
# start, end:11417, 11481
# start, end:11481, 11545
# start, end:11545, 11609
# start, end:11609, 11673
# start, end:11673, 11737
# start, end:11737, 11801
# Phase: test | Epoch: 3 | Count: 1325 \ Start Time: 23:10:55 | Loss: 43
# start, end:11801, 11865
# start, end:11865, 11929
# start, end:11929, 11993
# start, end:11993, 12057
# start, end:12057, 12121
# start, end:12121, 12185
# start, end:12185, 12249
# start, end:12249, 12313
# start, end:12313, 12377
# start, end:12377, 12441
# start, end:12441, 12505
# start, end:12505, 12569
# start, end:12569, 12633
# start, end:12633, 12697
# start, end:12697, 12761
# start, end:12761, 12825
# start, end:12825, 12889
# start, end:12889, 12953
# start, end:12953, 13017
# start, end:13017, 13081
# start, end:13081, 13145
# start, end:13145, 13209
# start, end:13209, 13273
# start, end:13273, 13337
# start, end:13337, 13401
# Phase: test | Epoch: 3 | Count: 1350 \ Start Time: 23:11:00 | Loss: 43
# start, end:13401, 13465
# start, end:13465, 13529
# start, end:13529, 13593
# start, end:13593, 13657
# start, end:13657, 13721
# start, end:13721, 13785
# start, end:13785, 13849
# start, end:13849, 13913
# start, end:13913, 13977
# start, end:13977, 14041
# start, end:14041, 14105
# start, end:14105, 14169
# start, end:14169, 14233
# start, end:14233, 14297
# start, end:14297, 14361
# start, end:14361, 14425
# start, end:14425, 14489
# start, end:14489, 14553
# start, end:14553, 14617
# start, end:14617, 14681
# start, end:14681, 14745
# start, end:14745, 14809
# start, end:14809, 14873
# start, end:14873, 14937
# start, end:14937, 15001
# Phase: test | Epoch: 3 | Count: 1375 \ Start Time: 23:11:05 | Loss: 42
# start, end:15001, 15065
# start, end:15065, 15129
# start, end:15129, 15193
# start, end:15193, 15257
# start, end:15257, 15321
# start, end:15321, 15385
# start, end:15385, 15449
# start, end:15449, 15513
# start, end:15513, 15577
# start, end:15577, 15641
# start, end:15641, 15705
# start, end:15705, 15769
# start, end:15769, 15833
# start, end:15833, 15897
# start, end:15897, 15961
# start, end:15961, 16025
# start, end:16025, 16089
# start, end:16089, 16153
# start, end:16153, 16217
# start, end:16217, 16281
# start, end:16281, 16345
# start, end:16345, 16409
# start, end:16409, 16473
# start, end:16473, 16537
# start, end:16537, 16601
# Phase: test | Epoch: 3 | Count: 1400 \ Start Time: 23:11:10 | Loss: 43
# start, end:16601, 16665
# start, end:16665, 16729
# start, end:16729, 16793
# start, end:16793, 16857
# start, end:16857, 16921
# start, end:16921, 16985
# start, end:16985, 17049
# start, end:17049, 17113
# start, end:17113, 17177
# start, end:17177, 17241
# start, end:17241, 17305
# start, end:17305, 17369
# start, end:17369, 17433
# start, end:17433, 17497
# start, end:17497, 17561
# start, end:17561, 17625
# start, end:17625, 17689
# start, end:17689, 17753
# start, end:17753, 17817
# start, end:17817, 17881
# start, end:17881, 17945
# start, end:17945, 18009
# start, end:18009, 18073
# start, end:18073, 18137
# start, end:18137, 18201
# Phase: test | Epoch: 3 | Count: 1425 \ Start Time: 23:11:15 | Loss: 42
# start, end:18201, 18265
# start, end:18265, 18329
# start, end:18329, 18393
# start, end:18393, 18457
# start, end:18457, 18521
# start, end:18521, 18585
# start, end:18585, 18649
# start, end:18649, 18713
# start, end:18713, 18777
# start, end:18777, 18841
# start, end:18841, 18905
# start, end:18905, 18969
# start, end:18969, 19033
# start, end:19033, 19097
# start, end:19097, 19161
# start, end:19161, 19225
# start, end:19225, 19289
# start, end:19289, 19353
# start, end:19353, 19417
# start, end:19417, 19481
# start, end:19481, 19545
# start, end:19545, 19609
# start, end:19609, 19673
# start, end:19673, 19737
# start, end:19737, 19801
# Phase: test | Epoch: 3 | Count: 1450 \ Start Time: 23:11:20 | Loss: 43
# start, end:19801, 19865
# start, end:19865, 19929
# start, end:19929, 19993
# start, end:19993, 20057
# start, end:20057, 20121
# start, end:20121, 20185
# start, end:20185, 20249
# start, end:20249, 20313
# start, end:20313, 20377
# start, end:20377, 20441
# start, end:20441, 20505
# start, end:20505, 20569
# start, end:20569, 20633
# start, end:20633, 20697
# start, end:20697, 20761
# start, end:20761, 20825
# start, end:20825, 20889
# start, end:20889, 20953
# start, end:20953, 21017
# start, end:21017, 21081
# start, end:21081, 21145
# start, end:21145, 21209
# start, end:21209, 21273
# start, end:21273, 21337
# start, end:21337, 21401
# Phase: test | Epoch: 3 | Count: 1475 \ Start Time: 23:11:25 | Loss: 43
# start, end:21401, 21465
# start, end:21465, 21529
# start, end:21529, 21593
# start, end:21593, 21657
# start, end:21657, 21721
# start, end:21721, 21785
# start, end:21785, 21849
# start, end:21849, 21913
# start, end:21913, 21977
# start, end:21977, 22041
# start, end:22041, 22105
# start, end:22105, 22169
# start, end:22169, 22233
# start, end:22233, 22297
# start, end:22297, 22361
# start, end:22361, 22425
# start, end:22425, 22489
# start, end:22489, 22553
# start, end:22553, 22617
# start, end:22617, 22681
# start, end:22681, 22745
# start, end:22745, 22809
# start, end:22809, 22873
# start, end:22873, 22937
# start, end:22937, 23001
# Phase: test | Epoch: 3 | Count: 1500 \ Start Time: 23:11:30 | Loss: 42
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_1500_test_0.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_1500_test_1.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_1500_test_2.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_1500_test_3.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_1500_test_4.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_1500_test_5.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_1500_test_6.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_1500_test_7.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_1500_test_8.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_1500_test_9.png
# start, end:23001, 23065
# start, end:23065, 23129
# start, end:23129, 23193
# start, end:23193, 23257
# start, end:23257, 23321
# start, end:23321, 23385
# start, end:23385, 23449
# start, end:23449, 23513
# start, end:23513, 23577
# start, end:23577, 23641
# start, end:23641, 23705
# start, end:23705, 23769
# start, end:23769, 23833
# start, end:23833, 23897
# start, end:23897, 23961
# start, end:23961, 24025
# start, end:24025, 24089
# start, end:24089, 24153
# start, end:24153, 24217
# start, end:24217, 24281
# start, end:0, 12
# start, end:12, 76
# start, end:76, 140
# start, end:140, 204
# start, end:204, 268
# Phase: test | Epoch: 4 | Count: 1525 \ Start Time: 23:11:37 | Loss: 43
# start, end:268, 332
# start, end:332, 396
# start, end:396, 460
# start, end:460, 524
# start, end:524, 588
# start, end:588, 652
# start, end:652, 716
# start, end:716, 780
# start, end:780, 844
# start, end:844, 908
# start, end:908, 972
# start, end:972, 1036
# start, end:1036, 1100
# start, end:1100, 1164
# start, end:1164, 1228
# start, end:1228, 1292
# start, end:1292, 1356
# start, end:1356, 1420
# start, end:1420, 1484
# start, end:1484, 1548
# start, end:1548, 1612
# start, end:1612, 1676
# start, end:1676, 1740
# start, end:1740, 1804
# start, end:1804, 1868
# Phase: test | Epoch: 4 | Count: 1550 \ Start Time: 23:11:43 | Loss: 42
# start, end:1868, 1932
# start, end:1932, 1996
# start, end:1996, 2060
# start, end:2060, 2124
# start, end:2124, 2188
# start, end:2188, 2252
# start, end:2252, 2316
# start, end:2316, 2380
# start, end:2380, 2444
# start, end:2444, 2508
# start, end:2508, 2572
# start, end:2572, 2636
# start, end:2636, 2700
# start, end:2700, 2764
# start, end:2764, 2828
# start, end:2828, 2892
# start, end:2892, 2956
# start, end:2956, 3020
# start, end:3020, 3084
# start, end:3084, 3148
# start, end:3148, 3212
# start, end:3212, 3276
# start, end:3276, 3340
# start, end:3340, 3404
# start, end:3404, 3468
# Phase: test | Epoch: 4 | Count: 1575 \ Start Time: 23:11:49 | Loss: 43
# start, end:3468, 3532
# start, end:3532, 3596
# start, end:3596, 3660
# start, end:3660, 3724
# start, end:3724, 3788
# start, end:3788, 3852
# start, end:3852, 3916
# start, end:3916, 3980
# start, end:3980, 4044
# start, end:4044, 4108
# start, end:4108, 4172
# start, end:4172, 4236
# start, end:4236, 4300
# start, end:4300, 4364
# start, end:4364, 4428
# start, end:4428, 4492
# start, end:4492, 4556
# start, end:4556, 4620
# start, end:4620, 4684
# start, end:4684, 4748
# start, end:4748, 4812
# start, end:4812, 4876
# start, end:4876, 4940
# start, end:4940, 5004
# start, end:5004, 5068
# Phase: test | Epoch: 4 | Count: 1600 \ Start Time: 23:11:57 | Loss: 43
# start, end:5068, 5132
# start, end:5132, 5196
# start, end:5196, 5260
# start, end:5260, 5324
# start, end:5324, 5388
# start, end:5388, 5452
# start, end:5452, 5516
# start, end:5516, 5580
# start, end:5580, 5644
# start, end:5644, 5708
# start, end:5708, 5772
# start, end:5772, 5836
# start, end:5836, 5900
# start, end:5900, 5964
# start, end:5964, 6028
# start, end:6028, 6092
# start, end:6092, 6156
# start, end:6156, 6220
# start, end:6220, 6284
# start, end:6284, 6348
# start, end:6348, 6412
# start, end:6412, 6476
# start, end:6476, 6540
# start, end:6540, 6604
# start, end:6604, 6668
# Phase: test | Epoch: 4 | Count: 1625 \ Start Time: 23:12:06 | Loss: 43
# start, end:6668, 6732
# start, end:6732, 6796
# start, end:6796, 6860
# start, end:6860, 6924
# start, end:6924, 6988
# start, end:6988, 7052
# start, end:7052, 7116
# start, end:7116, 7180
# start, end:7180, 7244
# start, end:7244, 7308
# start, end:7308, 7372
# start, end:7372, 7436
# start, end:7436, 7500
# start, end:7500, 7564
# start, end:7564, 7628
# start, end:7628, 7692
# start, end:7692, 7756
# start, end:7756, 7820
# start, end:7820, 7884
# start, end:7884, 7948
# start, end:7948, 8012
# start, end:8012, 8076
# start, end:8076, 8140
# start, end:8140, 8204
# start, end:8204, 8268
# Phase: test | Epoch: 4 | Count: 1650 \ Start Time: 23:12:13 | Loss: 43
# start, end:8268, 8332
# start, end:8332, 8396
# start, end:8396, 8460
# start, end:8460, 8524
# start, end:8524, 8588
# start, end:8588, 8652
# start, end:8652, 8716
# start, end:8716, 8780
# start, end:8780, 8844
# start, end:8844, 8908
# start, end:8908, 8972
# start, end:8972, 9036
# start, end:9036, 9100
# start, end:9100, 9164
# start, end:9164, 9228
# start, end:9228, 9292
# start, end:9292, 9356
# start, end:9356, 9420
# start, end:9420, 9484
# start, end:9484, 9548
# start, end:9548, 9612
# start, end:9612, 9676
# start, end:9676, 9740
# start, end:9740, 9804
# start, end:9804, 9868
# Phase: test | Epoch: 4 | Count: 1675 \ Start Time: 23:12:19 | Loss: 43
# start, end:9868, 9932
# start, end:9932, 9996
# start, end:9996, 10060
# start, end:10060, 10124
# start, end:10124, 10188
# start, end:10188, 10252
# start, end:10252, 10316
# start, end:10316, 10380
# start, end:10380, 10444
# start, end:10444, 10508
# start, end:10508, 10572
# start, end:10572, 10636
# start, end:10636, 10700
# start, end:10700, 10764
# start, end:10764, 10828
# start, end:10828, 10892
# start, end:10892, 10956
# start, end:10956, 11020
# start, end:11020, 11084
# start, end:11084, 11148
# start, end:11148, 11212
# start, end:11212, 11276
# start, end:11276, 11340
# start, end:11340, 11404
# start, end:11404, 11468
# Phase: test | Epoch: 4 | Count: 1700 \ Start Time: 23:12:25 | Loss: 42
# start, end:11468, 11532
# start, end:11532, 11596
# start, end:11596, 11660
# start, end:11660, 11724
# start, end:11724, 11788
# start, end:11788, 11852
# start, end:11852, 11916
# start, end:11916, 11980
# start, end:11980, 12044
# start, end:12044, 12108
# start, end:12108, 12172
# start, end:12172, 12236
# start, end:12236, 12300
# start, end:12300, 12364
# start, end:12364, 12428
# start, end:12428, 12492
# start, end:12492, 12556
# start, end:12556, 12620
# start, end:12620, 12684
# start, end:12684, 12748
# start, end:12748, 12812
# start, end:12812, 12876
# start, end:12876, 12940
# start, end:12940, 13004
# start, end:13004, 13068
# Phase: test | Epoch: 4 | Count: 1725 \ Start Time: 23:12:31 | Loss: 42
# start, end:13068, 13132
# start, end:13132, 13196
# start, end:13196, 13260
# start, end:13260, 13324
# start, end:13324, 13388
# start, end:13388, 13452
# start, end:13452, 13516
# start, end:13516, 13580
# start, end:13580, 13644
# start, end:13644, 13708
# start, end:13708, 13772
# start, end:13772, 13836
# start, end:13836, 13900
# start, end:13900, 13964
# start, end:13964, 14028
# start, end:14028, 14092
# start, end:14092, 14156
# start, end:14156, 14220
# start, end:14220, 14284
# start, end:14284, 14348
# start, end:14348, 14412
# start, end:14412, 14476
# start, end:14476, 14540
# start, end:14540, 14604
# start, end:14604, 14668
# Phase: test | Epoch: 4 | Count: 1750 \ Start Time: 23:12:36 | Loss: 42
# start, end:14668, 14732
# start, end:14732, 14796
# start, end:14796, 14860
# start, end:14860, 14924
# start, end:14924, 14988
# start, end:14988, 15052
# start, end:15052, 15116
# start, end:15116, 15180
# start, end:15180, 15244
# start, end:15244, 15308
# start, end:15308, 15372
# start, end:15372, 15436
# start, end:15436, 15500
# start, end:15500, 15564
# start, end:15564, 15628
# start, end:15628, 15692
# start, end:15692, 15756
# start, end:15756, 15820
# start, end:15820, 15884
# start, end:15884, 15948
# start, end:15948, 16012
# start, end:16012, 16076
# start, end:16076, 16140
# start, end:16140, 16204
# start, end:16204, 16268
# Phase: test | Epoch: 4 | Count: 1775 \ Start Time: 23:12:42 | Loss: 43
# start, end:16268, 16332
# start, end:16332, 16396
# start, end:16396, 16460
# start, end:16460, 16524
# start, end:16524, 16588
# start, end:16588, 16652
# start, end:16652, 16716
# start, end:16716, 16780
# start, end:16780, 16844
# start, end:16844, 16908
# ...
# start, end:14168, 14232
# start, end:14232, 14296
# start, end:14296, 14360
# start, end:14360, 14424
# start, end:14424, 14488
# start, end:14488, 14552
# start, end:14552, 14616
# start, end:14616, 14680
# start, end:14680, 14744
# start, end:14744, 14808
# start, end:14808, 14872
# start, end:14872, 14936
# Phase: test | Epoch: 8 | Count: 3275 \ Start Time: 23:16:59 | Loss: 42
# start, end:14936, 15000
# start, end:15000, 15064
# start, end:15064, 15128
# start, end:15128, 15192
# start, end:15192, 15256
# start, end:15256, 15320
# start, end:15320, 15384
# start, end:15384, 15448
# start, end:15448, 15512
# start, end:15512, 15576
# start, end:15576, 15640
# start, end:15640, 15704
# start, end:15704, 15768
# start, end:15768, 15832
# start, end:15832, 15896
# start, end:15896, 15960
# start, end:15960, 16024
# start, end:16024, 16088
# start, end:16088, 16152
# start, end:16152, 16216
# start, end:16216, 16280
# start, end:16280, 16344
# start, end:16344, 16408
# start, end:16408, 16472
# start, end:16472, 16536
# Phase: test | Epoch: 8 | Count: 3300 \ Start Time: 23:17:03 | Loss: 43
# start, end:16536, 16600
# start, end:16600, 16664
# start, end:16664, 16728
# start, end:16728, 16792
# start, end:16792, 16856
# start, end:16856, 16920
# start, end:16920, 16984
# start, end:16984, 17048
# start, end:17048, 17112
# start, end:17112, 17176
# start, end:17176, 17240
# start, end:17240, 17304
# start, end:17304, 17368
# start, end:17368, 17432
# start, end:17432, 17496
# start, end:17496, 17560
# start, end:17560, 17624
# start, end:17624, 17688
# start, end:17688, 17752
# start, end:17752, 17816
# start, end:17816, 17880
# start, end:17880, 17944
# start, end:17944, 18008
# start, end:18008, 18072
# start, end:18072, 18136
# Phase: test | Epoch: 8 | Count: 3325 \ Start Time: 23:17:06 | Loss: 42
# start, end:18136, 18200
# start, end:18200, 18264
# start, end:18264, 18328
# start, end:18328, 18392
# start, end:18392, 18456
# start, end:18456, 18520
# start, end:18520, 18584
# start, end:18584, 18648
# start, end:18648, 18712
# start, end:18712, 18776
# start, end:18776, 18840
# start, end:18840, 18904
# start, end:18904, 18968
# start, end:18968, 19032
# start, end:19032, 19096
# start, end:19096, 19160
# start, end:19160, 19224
# start, end:19224, 19288
# start, end:19288, 19352
# start, end:19352, 19416
# start, end:19416, 19480
# start, end:19480, 19544
# start, end:19544, 19608
# start, end:19608, 19672
# start, end:19672, 19736
# Phase: test | Epoch: 8 | Count: 3350 \ Start Time: 23:17:10 | Loss: 43
# start, end:19736, 19800
# start, end:19800, 19864
# start, end:19864, 19928
# start, end:19928, 19992
# start, end:19992, 20056
# start, end:20056, 20120
# start, end:20120, 20184
# start, end:20184, 20248
# start, end:20248, 20312
# start, end:20312, 20376
# start, end:20376, 20440
# start, end:20440, 20504
# start, end:20504, 20568
# start, end:20568, 20632
# start, end:20632, 20696
# start, end:20696, 20760
# start, end:20760, 20824
# start, end:20824, 20888
# start, end:20888, 20952
# start, end:20952, 21016
# start, end:21016, 21080
# start, end:21080, 21144
# start, end:21144, 21208
# start, end:21208, 21272
# start, end:21272, 21336
# Phase: test | Epoch: 8 | Count: 3375 \ Start Time: 23:17:14 | Loss: 43
# start, end:21336, 21400
# start, end:21400, 21464
# start, end:21464, 21528
# start, end:21528, 21592
# start, end:21592, 21656
# start, end:21656, 21720
# start, end:21720, 21784
# start, end:21784, 21848
# start, end:21848, 21912
# start, end:21912, 21976
# start, end:21976, 22040
# start, end:22040, 22104
# start, end:22104, 22168
# start, end:22168, 22232
# start, end:22232, 22296
# start, end:22296, 22360
# start, end:22360, 22424
# start, end:22424, 22488
# start, end:22488, 22552
# start, end:22552, 22616
# start, end:22616, 22680
# start, end:22680, 22744
# start, end:22744, 22808
# start, end:22808, 22872
# start, end:22872, 22936
# Phase: test | Epoch: 8 | Count: 3400 \ Start Time: 23:17:18 | Loss: 42
# start, end:22936, 23000
# start, end:23000, 23064
# start, end:23064, 23128
# start, end:23128, 23192
# start, end:23192, 23256
# start, end:23256, 23320
# start, end:23320, 23384
# start, end:23384, 23448
# start, end:23448, 23512
# start, end:23512, 23576
# start, end:23576, 23640
# start, end:23640, 23704
# start, end:23704, 23768
# start, end:23768, 23832
# start, end:23832, 23896
# start, end:23896, 23960
# start, end:23960, 24024
# start, end:24024, 24088
# start, end:24088, 24152
# start, end:24152, 24216
# start, end:24216, 24280
# start, end:0, 11
# start, end:11, 75
# start, end:75, 139
# start, end:139, 203
# Phase: test | Epoch: 9 | Count: 3425 \ Start Time: 23:17:22 | Loss: 43
# start, end:203, 267
# start, end:267, 331
# start, end:331, 395
# start, end:395, 459
# start, end:459, 523
# start, end:523, 587
# start, end:587, 651
# start, end:651, 715
# start, end:715, 779
# start, end:779, 843
# start, end:843, 907
# start, end:907, 971
# start, end:971, 1035
# start, end:1035, 1099
# start, end:1099, 1163
# start, end:1163, 1227
# start, end:1227, 1291
# start, end:1291, 1355
# start, end:1355, 1419
# start, end:1419, 1483
# start, end:1483, 1547
# start, end:1547, 1611
# start, end:1611, 1675
# start, end:1675, 1739
# start, end:1739, 1803
# Phase: test | Epoch: 9 | Count: 3450 \ Start Time: 23:17:26 | Loss: 42
# start, end:1803, 1867
# start, end:1867, 1931
# start, end:1931, 1995
# start, end:1995, 2059
# start, end:2059, 2123
# start, end:2123, 2187
# start, end:2187, 2251
# start, end:2251, 2315
# start, end:2315, 2379
# start, end:2379, 2443
# start, end:2443, 2507
# start, end:2507, 2571
# start, end:2571, 2635
# start, end:2635, 2699
# start, end:2699, 2763
# start, end:2763, 2827
# start, end:2827, 2891
# start, end:2891, 2955
# start, end:2955, 3019
# start, end:3019, 3083
# start, end:3083, 3147
# start, end:3147, 3211
# start, end:3211, 3275
# start, end:3275, 3339
# start, end:3339, 3403
# Phase: test | Epoch: 9 | Count: 3475 \ Start Time: 23:17:30 | Loss: 43
# start, end:3403, 3467
# start, end:3467, 3531
# start, end:3531, 3595
# start, end:3595, 3659
# start, end:3659, 3723
# start, end:3723, 3787
# start, end:3787, 3851
# start, end:3851, 3915
# start, end:3915, 3979
# start, end:3979, 4043
# start, end:4043, 4107
# start, end:4107, 4171
# start, end:4171, 4235
# start, end:4235, 4299
# start, end:4299, 4363
# start, end:4363, 4427
# start, end:4427, 4491
# start, end:4491, 4555
# start, end:4555, 4619
# start, end:4619, 4683
# start, end:4683, 4747
# start, end:4747, 4811
# start, end:4811, 4875
# start, end:4875, 4939
# start, end:4939, 5003
# Phase: test | Epoch: 9 | Count: 3500 \ Start Time: 23:17:35 | Loss: 43
# start, end:5003, 5067
# start, end:5067, 5131
# start, end:5131, 5195
# start, end:5195, 5259
# start, end:5259, 5323
# start, end:5323, 5387
# start, end:5387, 5451
# start, end:5451, 5515
# start, end:5515, 5579
# start, end:5579, 5643
# start, end:5643, 5707
# start, end:5707, 5771
# start, end:5771, 5835
# start, end:5835, 5899
# start, end:5899, 5963
# start, end:5963, 6027
# start, end:6027, 6091
# start, end:6091, 6155
# start, end:6155, 6219
# start, end:6219, 6283
# start, end:6283, 6347
# start, end:6347, 6411
# start, end:6411, 6475
# start, end:6475, 6539
# start, end:6539, 6603
# Phase: test | Epoch: 9 | Count: 3525 \ Start Time: 23:17:39 | Loss: 43
# start, end:6603, 6667
# start, end:6667, 6731
# start, end:6731, 6795
# start, end:6795, 6859
# start, end:6859, 6923
# start, end:6923, 6987
# start, end:6987, 7051
# start, end:7051, 7115
# start, end:7115, 7179
# start, end:7179, 7243
# start, end:7243, 7307
# start, end:7307, 7371
# start, end:7371, 7435
# start, end:7435, 7499
# start, end:7499, 7563
# start, end:7563, 7627
# start, end:7627, 7691
# start, end:7691, 7755
# start, end:7755, 7819
# start, end:7819, 7883
# start, end:7883, 7947
# start, end:7947, 8011
# start, end:8011, 8075
# start, end:8075, 8139
# start, end:8139, 8203
# Phase: test | Epoch: 9 | Count: 3550 \ Start Time: 23:17:43 | Loss: 43
# start, end:8203, 8267
# start, end:8267, 8331
# start, end:8331, 8395
# start, end:8395, 8459
# start, end:8459, 8523
# start, end:8523, 8587
# start, end:8587, 8651
# start, end:8651, 8715
# start, end:8715, 8779
# start, end:8779, 8843
# start, end:8843, 8907
# start, end:8907, 8971
# start, end:8971, 9035
# start, end:9035, 9099
# start, end:9099, 9163
# start, end:9163, 9227
# start, end:9227, 9291
# start, end:9291, 9355
# start, end:9355, 9419
# start, end:9419, 9483
# start, end:9483, 9547
# start, end:9547, 9611
# start, end:9611, 9675
# start, end:9675, 9739
# start, end:9739, 9803
# Phase: test | Epoch: 9 | Count: 3575 \ Start Time: 23:17:47 | Loss: 43
# start, end:9803, 9867
# start, end:9867, 9931
# start, end:9931, 9995
# start, end:9995, 10059
# start, end:10059, 10123
# start, end:10123, 10187
# start, end:10187, 10251
# start, end:10251, 10315
# start, end:10315, 10379
# start, end:10379, 10443
# start, end:10443, 10507
# start, end:10507, 10571
# start, end:10571, 10635
# start, end:10635, 10699
# start, end:10699, 10763
# start, end:10763, 10827
# start, end:10827, 10891
# start, end:10891, 10955
# start, end:10955, 11019
# start, end:11019, 11083
# start, end:11083, 11147
# start, end:11147, 11211
# start, end:11211, 11275
# start, end:11275, 11339
# start, end:11339, 11403
# Phase: test | Epoch: 9 | Count: 3600 \ Start Time: 23:17:51 | Loss: 42
# start, end:11403, 11467
# start, end:11467, 11531
# start, end:11531, 11595
# start, end:11595, 11659
# start, end:11659, 11723
# start, end:11723, 11787
# start, end:11787, 11851
# start, end:11851, 11915
# start, end:11915, 11979
# start, end:11979, 12043
# start, end:12043, 12107
# start, end:12107, 12171
# start, end:12171, 12235
# start, end:12235, 12299
# start, end:12299, 12363
# start, end:12363, 12427
# start, end:12427, 12491
# start, end:12491, 12555
# start, end:12555, 12619
# start, end:12619, 12683
# start, end:12683, 12747
# start, end:12747, 12811
# start, end:12811, 12875
# start, end:12875, 12939
# start, end:12939, 13003
# Phase: test | Epoch: 9 | Count: 3625 \ Start Time: 23:17:54 | Loss: 43
# start, end:13003, 13067
# start, end:13067, 13131
# start, end:13131, 13195
# start, end:13195, 13259
# start, end:13259, 13323
# start, end:13323, 13387
# start, end:13387, 13451
# start, end:13451, 13515
# start, end:13515, 13579
# start, end:13579, 13643
# start, end:13643, 13707
# start, end:13707, 13771
# start, end:13771, 13835
# start, end:13835, 13899
# start, end:13899, 13963
# start, end:13963, 14027
# start, end:14027, 14091
# start, end:14091, 14155
# start, end:14155, 14219
# start, end:14219, 14283
# start, end:14283, 14347
# start, end:14347, 14411
# start, end:14411, 14475
# start, end:14475, 14539
# start, end:14539, 14603
# Phase: test | Epoch: 9 | Count: 3650 \ Start Time: 23:17:58 | Loss: 42
# start, end:14603, 14667
# start, end:14667, 14731
# start, end:14731, 14795
# start, end:14795, 14859
# start, end:14859, 14923
# start, end:14923, 14987
# start, end:14987, 15051
# start, end:15051, 15115
# start, end:15115, 15179
# start, end:15179, 15243
# start, end:15243, 15307
# start, end:15307, 15371
# start, end:15371, 15435
# start, end:15435, 15499
# start, end:15499, 15563
# start, end:15563, 15627
# start, end:15627, 15691
# start, end:15691, 15755
# start, end:15755, 15819
# start, end:15819, 15883
# start, end:15883, 15947
# start, end:15947, 16011
# start, end:16011, 16075
# start, end:16075, 16139
# start, end:16139, 16203
# Phase: test | Epoch: 9 | Count: 3675 \ Start Time: 23:18:02 | Loss: 43
# start, end:16203, 16267
# start, end:16267, 16331
# start, end:16331, 16395
# start, end:16395, 16459
# start, end:16459, 16523
# start, end:16523, 16587
# start, end:16587, 16651
# start, end:16651, 16715
# start, end:16715, 16779
# start, end:16779, 16843
# start, end:16843, 16907
# start, end:16907, 16971
# start, end:16971, 17035
# start, end:17035, 17099
# start, end:17099, 17163
# start, end:17163, 17227
# start, end:17227, 17291
# start, end:17291, 17355
# start, end:17355, 17419
# start, end:17419, 17483
# start, end:17483, 17547
# start, end:17547, 17611
# start, end:17611, 17675
# start, end:17675, 17739
# start, end:17739, 17803
# Phase: test | Epoch: 9 | Count: 3700 \ Start Time: 23:18:06 | Loss: 42
# start, end:17803, 17867
# start, end:17867, 17931
# start, end:17931, 17995
# start, end:17995, 18059
# start, end:18059, 18123
# start, end:18123, 18187
# start, end:18187, 18251
# start, end:18251, 18315
# start, end:18315, 18379
# start, end:18379, 18443
# start, end:18443, 18507
# start, end:18507, 18571
# start, end:18571, 18635
# start, end:18635, 18699
# start, end:18699, 18763
# start, end:18763, 18827
# start, end:18827, 18891
# start, end:18891, 18955
# start, end:18955, 19019
# start, end:19019, 19083
# start, end:19083, 19147
# start, end:19147, 19211
# start, end:19211, 19275
# start, end:19275, 19339
# start, end:19339, 19403
# Phase: test | Epoch: 9 | Count: 3725 \ Start Time: 23:18:10 | Loss: 43
# start, end:19403, 19467
# start, end:19467, 19531
# start, end:19531, 19595
# start, end:19595, 19659
# start, end:19659, 19723
# start, end:19723, 19787
# start, end:19787, 19851
# start, end:19851, 19915
# start, end:19915, 19979
# start, end:19979, 20043
# start, end:20043, 20107
# start, end:20107, 20171
# start, end:20171, 20235
# start, end:20235, 20299
# start, end:20299, 20363
# start, end:20363, 20427
# start, end:20427, 20491
# start, end:20491, 20555
# start, end:20555, 20619
# start, end:20619, 20683
# start, end:20683, 20747
# start, end:20747, 20811
# start, end:20811, 20875
# start, end:20875, 20939
# start, end:20939, 21003
# Phase: test | Epoch: 9 | Count: 3750 \ Start Time: 23:18:14 | Loss: 43
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3750_test_0.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3750_test_1.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3750_test_2.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3750_test_3.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3750_test_4.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3750_test_5.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3750_test_6.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3750_test_7.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3750_test_8.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3750_test_9.png
# start, end:21003, 21067
# start, end:21067, 21131
# start, end:21131, 21195
# start, end:21195, 21259
# start, end:21259, 21323
# start, end:21323, 21387
# start, end:21387, 21451
# start, end:21451, 21515
# start, end:21515, 21579
# start, end:21579, 21643
# start, end:21643, 21707
# start, end:21707, 21771
# start, end:21771, 21835
# start, end:21835, 21899
# start, end:21899, 21963
# start, end:21963, 22027
# start, end:22027, 22091
# start, end:22091, 22155
# start, end:22155, 22219
# start, end:22219, 22283
# start, end:22283, 22347
# start, end:22347, 22411
# start, end:22411, 22475
# start, end:22475, 22539
# start, end:22539, 22603
# Phase: test | Epoch: 9 | Count: 3775 \ Start Time: 23:18:21 | Loss: 43
# start, end:22603, 22667
# start, end:22667, 22731
# start, end:22731, 22795
# start, end:22795, 22859
# start, end:22859, 22923
# start, end:22923, 22987
# start, end:22987, 23051
# start, end:23051, 23115
# start, end:23115, 23179
# start, end:23179, 23243
# start, end:23243, 23307
# start, end:23307, 23371
# start, end:23371, 23435
# start, end:23435, 23499
# start, end:23499, 23563
# start, end:23563, 23627
# start, end:23627, 23691
# start, end:23691, 23755
# start, end:23755, 23819
# start, end:23819, 23883
# start, end:23883, 23947
# start, end:23947, 24011
# start, end:24011, 24075
# start, end:24075, 24139
# start, end:24139, 24203
# Phase: test | Epoch: 9 | Count: 3800 \ Start Time: 23:18:25 | Loss: 43
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3800_test_0.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3800_test_1.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3800_test_2.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3800_test_3.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3800_test_4.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3800_test_5.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3800_test_6.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3800_test_7.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3800_test_8.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\moon\moon_3800_test_9.png
