# %%
import csv
import ndjson
import os
import sys

# %%
root_path = os.getcwd().split('notebook')[0]

# %%
sys.path.insert(1, root_path)
from src.utils.model_utils import *
from src.draw_model import *

# %%
config = ConfigParser()
config_file = "config.cfg"
config_path = os.path.join(root_path + "src" + "\\" + config_file)
config.read_file(open(config_path))

# %%
categories_file = os.path.join(root_path, 'src\\data\\categories.csv')

# %%
with open(categories_file, newline='') as f:
    reader = csv.reader(f)
    categories = {rows[0]:rows[0] for rows in reader}

# %% [markdown]
# #### Select a category to download images from

# %%
for key, value in categories.items():
    #print(key)
    pass

# %%
print("Selected category from the list above:")
#category=input()
category='cat'
print(category)
# Out:
# Selected category from the list above:
# cat

# %%
print("Creating directories to save images, weights and the model ...")
src_list, dst_list, paths_dict = create_folders(root_path, categories, category)

for (src_file, dst_file) in zip(src_list, dst_list): 
    print('src_file: {}, dst_file: {}'.format(src_file, dst_file))
# Out:
# Creating directories to save images, weights and the model ...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\save folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\input folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\positions folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\raw folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\save\cat folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\input\cat folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\raw\cat folder exists...
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat folder exists...
# src_file: gs://quickdraw_dataset/full/numpy_bitmap/cat.npy, dst_file: C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\input\cat\cat.npy
# src_file: gs://quickdraw_dataset/full/raw/cat.ndjson, dst_file: C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\raw\cat\cat.ndjson

# %%
for (src_file, dst_file) in zip(src_list, dst_list): 
    # !gsutil -m cp {src_file} {dst_file}
# Out:
# Copying gs://quickdraw_dataset/full/numpy_bitmap/cat.npy...
# / [0/1 files][    0.0 B/ 92.1 MiB]   0% Done
# -
# - [0/1 files][792.0 KiB/ 92.1 MiB]   0% Done
# \
# \ [0/1 files][  3.4 MiB/ 92.1 MiB]   3% Done
# |
# /
# / [0/1 files][  4.9 MiB/ 92.1 MiB]   5% Done
# -
# \
# \ [0/1 files][  7.5 MiB/ 92.1 MiB]   8% Done
# |
# | [0/1 files][  9.5 MiB/ 92.1 MiB]  10% Done
# /
# -
# - [0/1 files][ 11.1 MiB/ 92.1 MiB]  12% Done
# \
# \ [0/1 files][ 12.6 MiB/ 92.1 MiB]  13% Done
# |
# /
# / [0/1 files][ 14.7 MiB/ 92.1 MiB]  15% Done
# -
# - [0/1 files][ 17.0 MiB/ 92.1 MiB]  18% Done
# \
# |
# | [0/1 files][ 20.4 MiB/ 92.1 MiB]  22% Done
# /
# -
# - [0/1 files][ 23.5 MiB/ 92.1 MiB]  25% Done   2.4 MiB/s ETA 00:00:28
# \
# \ [0/1 files][ 26.0 MiB/ 92.1 MiB]  28% Done   2.6 MiB/s ETA 00:00:26
# |
# /
# / [0/1 files][ 28.9 MiB/ 92.1 MiB]  31% Done   2.7 MiB/s ETA 00:00:23
# -
# - [0/1 files][ 31.2 MiB/ 92.1 MiB]  33% Done   2.6 MiB/s ETA 00:00:23
# \
# |
# | [0/1 files][ 33.0 MiB/ 92.1 MiB]  35% Done   2.3 MiB/s ETA 00:00:25
# /
# / [0/1 files][ 35.1 MiB/ 92.1 MiB]  38% Done   2.2 MiB/s ETA 00:00:26
# -
# \
# \ [0/1 files][ 37.4 MiB/ 92.1 MiB]  40% Done   2.1 MiB/s ETA 00:00:26
# |
# | [0/1 files][ 40.2 MiB/ 92.1 MiB]  43% Done   2.2 MiB/s ETA 00:00:24
# /
# -
# - [0/1 files][ 43.0 MiB/ 92.1 MiB]  46% Done   2.3 MiB/s ETA 00:00:22
# \
# |
# | [0/1 files][ 46.4 MiB/ 92.1 MiB]  50% Done   2.6 MiB/s ETA 00:00:18
# /
# -
# - [0/1 files][ 50.0 MiB/ 92.1 MiB]  54% Done   2.8 MiB/s ETA 00:00:15
# \
# \ [0/1 files][ 53.6 MiB/ 92.1 MiB]  58% Done   3.0 MiB/s ETA 00:00:13
# |
# /
# / [0/1 files][ 56.5 MiB/ 92.1 MiB]  61% Done   3.0 MiB/s ETA 00:00:12
# -
# \
# \ [0/1 files][ 59.0 MiB/ 92.1 MiB]  64% Done   3.0 MiB/s ETA 00:00:11
# |
# | [0/1 files][ 62.4 MiB/ 92.1 MiB]  67% Done   3.0 MiB/s ETA 00:00:10
# /
# -
# - [0/1 files][ 65.2 MiB/ 92.1 MiB]  70% Done   2.9 MiB/s ETA 00:00:09
# \
# \ [0/1 files][ 67.6 MiB/ 92.1 MiB]  73% Done   2.7 MiB/s ETA 00:00:09
# |
# /
# / [0/1 files][ 69.9 MiB/ 92.1 MiB]  75% Done   2.5 MiB/s ETA 00:00:09
# -
# \
# \ [0/1 files][ 71.4 MiB/ 92.1 MiB]  77% Done   2.3 MiB/s ETA 00:00:09
# |
# | [0/1 files][ 72.7 MiB/ 92.1 MiB]  78% Done   1.8 MiB/s ETA 00:00:11
# /
# / [0/1 files][ 74.0 MiB/ 92.1 MiB]  80% Done   1.6 MiB/s ETA 00:00:11
# -
# \
# \ [0/1 files][ 75.3 MiB/ 92.1 MiB]  81% Done   1.3 MiB/s ETA 00:00:13
# |
# /
# / [0/1 files][ 76.6 MiB/ 92.1 MiB]  83% Done   1.2 MiB/s ETA 00:00:13
# -
# - [0/1 files][ 77.9 MiB/ 92.1 MiB]  84% Done   1.1 MiB/s ETA 00:00:13
# \
# |
# | [0/1 files][ 78.9 MiB/ 92.1 MiB]  85% Done   1.0 MiB/s ETA 00:00:13
# /
# / [0/1 files][ 79.7 MiB/ 92.1 MiB]  86% Done 957.8 KiB/s ETA 00:00:13
# -
# - [0/1 files][ 80.7 MiB/ 92.1 MiB]  87% Done 884.5 KiB/s ETA 00:00:13
# \
# |
# | [0/1 files][ 81.7 MiB/ 92.1 MiB]  88% Done 866.2 KiB/s ETA 00:00:12
# /
# -
# - [0/1 files][ 84.8 MiB/ 92.1 MiB]  92% Done   1.3 MiB/s ETA 00:00:06
# \
# \ [0/1 files][ 88.7 MiB/ 92.1 MiB]  96% Done   2.0 MiB/s ETA 00:00:02
# |
# /
# / [0/1 files][ 91.8 MiB/ 92.1 MiB]  99% Done   2.4 MiB/s ETA 00:00:00
# / [1/1 files][ 92.1 MiB/ 92.1 MiB] 100% Done   2.5 MiB/s ETA 00:00:00
#
# Operation completed over 1 objects/92.1 MiB.
# Copying gs://quickdraw_dataset/full/raw/cat.ndjson...
# / [0/1 files][    0.0 B/496.9 MiB]   0% Done
# / [0/1 files][    0.0 B/496.9 MiB]   0% Done
# -
# \
# \ [0/1 files][264.0 KiB/496.9 MiB]   0% Done
# |
# | [0/1 files][  3.1 MiB/496.9 MiB]   0% Done
# /
# -
# - [0/1 files][  6.2 MiB/496.9 MiB]   1% Done
# \
# \ [0/1 files][  9.5 MiB/496.9 MiB]   1% Done
# |
# /
# / [0/1 files][ 13.4 MiB/496.9 MiB]   2% Done
# -
# - [0/1 files][ 17.3 MiB/496.9 MiB]   3% Done
# \
# |
# | [0/1 files][ 21.1 MiB/496.9 MiB]   4% Done   3.4 MiB/s ETA 00:02:19
# /
# -
# - [0/1 files][ 24.5 MiB/496.9 MiB]   4% Done   3.5 MiB/s ETA 00:02:15
# \
# \ [0/1 files][ 27.3 MiB/496.9 MiB]   5% Done   3.3 MiB/s ETA 00:02:21
# |
# /
# / [0/1 files][ 31.2 MiB/496.9 MiB]   6% Done   3.3 MiB/s ETA 00:02:20
# -
# - [0/1 files][ 34.3 MiB/496.9 MiB]   6% Done   3.1 MiB/s ETA 00:02:28
# \
# |
# | [0/1 files][ 36.1 MiB/496.9 MiB]   7% Done   2.8 MiB/s ETA 00:02:45
# /
# -
# - [0/1 files][ 38.4 MiB/496.9 MiB]   7% Done   2.6 MiB/s ETA 00:02:56
# \
# \ [0/1 files][ 40.5 MiB/496.9 MiB]   8% Done   2.4 MiB/s ETA 00:03:07
# |
# /
# / [0/1 files][ 42.8 MiB/496.9 MiB]   8% Done   2.2 MiB/s ETA 00:03:27
# -
# - [0/1 files][ 45.6 MiB/496.9 MiB]   9% Done   2.3 MiB/s ETA 00:03:20
# \
# |
# | [0/1 files][ 48.2 MiB/496.9 MiB]   9% Done   2.3 MiB/s ETA 00:03:18
# /
# / [0/1 files][ 50.0 MiB/496.9 MiB]  10% Done   2.1 MiB/s ETA 00:03:30
# -
# \
# \ [0/1 files][ 51.6 MiB/496.9 MiB]  10% Done   1.9 MiB/s ETA 00:03:54
# |
# | [0/1 files][ 53.9 MiB/496.9 MiB]  10% Done   1.8 MiB/s ETA 00:04:03
# /
# -
# - [0/1 files][ 56.5 MiB/496.9 MiB]  11% Done   1.9 MiB/s ETA 00:03:55
# \
# \ [0/1 files][ 58.3 MiB/496.9 MiB]  11% Done   1.9 MiB/s ETA 00:03:47
# |
# /
# / [0/1 files][ 60.3 MiB/496.9 MiB]  12% Done   2.0 MiB/s ETA 00:03:41
# -
# - [0/1 files][ 62.4 MiB/496.9 MiB]  12% Done   1.9 MiB/s ETA 00:03:45
# \
# |
# | [0/1 files][ 64.2 MiB/496.9 MiB]  12% Done   1.8 MiB/s ETA 00:04:04
# /
# / [0/1 files][ 66.0 MiB/496.9 MiB]  13% Done   1.7 MiB/s ETA 00:04:09
# -
# \
# \ [0/1 files][ 67.8 MiB/496.9 MiB]  13% Done   1.7 MiB/s ETA 00:04:16
# |
# | [0/1 files][ 69.6 MiB/496.9 MiB]  14% Done   1.6 MiB/s ETA 00:04:26
# /
# -
# - [0/1 files][ 71.9 MiB/496.9 MiB]  14% Done   1.7 MiB/s ETA 00:04:07
# \
# |
# | [0/1 files][ 74.2 MiB/496.9 MiB]  14% Done   1.9 MiB/s ETA 00:03:47
# /
# -
# - [0/1 files][ 76.3 MiB/496.9 MiB]  15% Done   1.8 MiB/s ETA 00:03:53
# \
# |
# | [0/1 files][ 78.4 MiB/496.9 MiB]  15% Done   1.9 MiB/s ETA 00:03:45
# /
# / [0/1 files][ 80.4 MiB/496.9 MiB]  16% Done   1.8 MiB/s ETA 00:03:52
# -
# \
# \ [0/1 files][ 82.8 MiB/496.9 MiB]  16% Done   1.8 MiB/s ETA 00:03:54
# |
# /
# / [0/1 files][ 84.8 MiB/496.9 MiB]  17% Done   1.8 MiB/s ETA 00:03:47
# -
# - [0/1 files][ 87.1 MiB/496.9 MiB]  17% Done   1.9 MiB/s ETA 00:03:34
# \
# |
# | [0/1 files][ 89.2 MiB/496.9 MiB]  17% Done   1.9 MiB/s ETA 00:03:38
# /
# -
# - [0/1 files][ 90.5 MiB/496.9 MiB]  18% Done   1.6 MiB/s ETA 00:04:07
# \
# \ [0/1 files][ 91.8 MiB/496.9 MiB]  18% Done   1.6 MiB/s ETA 00:04:20
# |
# /
# / [0/1 files][ 93.6 MiB/496.9 MiB]  18% Done   1.4 MiB/s ETA 00:04:43
# -
# - [0/1 files][ 95.6 MiB/496.9 MiB]  19% Done   1.3 MiB/s ETA 00:04:58
# \
# |
# | [0/1 files][ 97.4 MiB/496.9 MiB]  19% Done   1.6 MiB/s ETA 00:04:15
# /
# / [0/1 files][ 99.0 MiB/496.9 MiB]  19% Done   1.6 MiB/s ETA 00:04:15
# -
# \
# \ [0/1 files][100.3 MiB/496.9 MiB]  20% Done   1.5 MiB/s ETA 00:04:23
# |
# /
# / [0/1 files][102.6 MiB/496.9 MiB]  20% Done   1.6 MiB/s ETA 00:04:14
# -
# \
# \ [0/1 files][104.7 MiB/496.9 MiB]  21% Done   1.7 MiB/s ETA 00:03:57
# |
# | [0/1 files][106.7 MiB/496.9 MiB]  21% Done   1.7 MiB/s ETA 00:03:51
# /
# -
# - [0/1 files][108.8 MiB/496.9 MiB]  21% Done   1.8 MiB/s ETA 00:03:35
# \
# \ [0/1 files][111.6 MiB/496.9 MiB]  22% Done   2.0 MiB/s ETA 00:03:17
# |
# /
# / [0/1 files][115.2 MiB/496.9 MiB]  23% Done   2.3 MiB/s ETA 00:02:47
# -
# \
# \ [0/1 files][119.1 MiB/496.9 MiB]  23% Done   2.7 MiB/s ETA 00:02:20
# |
# | [0/1 files][123.2 MiB/496.9 MiB]  24% Done   3.2 MiB/s ETA 00:01:55
# /
# -
# - [0/1 files][126.8 MiB/496.9 MiB]  25% Done   3.5 MiB/s ETA 00:01:45
# \
# |
# | [0/1 files][131.0 MiB/496.9 MiB]  26% Done   3.8 MiB/s ETA 00:01:37
# /
# / [0/1 files][134.6 MiB/496.9 MiB]  27% Done   3.7 MiB/s ETA 00:01:38
# -
# \
# \ [0/1 files][139.5 MiB/496.9 MiB]  28% Done   3.9 MiB/s ETA 00:01:32
# |
# /
# / [0/1 files][144.4 MiB/496.9 MiB]  29% Done   4.1 MiB/s ETA 00:01:25
# -
# - [0/1 files][148.8 MiB/496.9 MiB]  29% Done   4.3 MiB/s ETA 00:01:21
# \
# |
# | [0/1 files][153.4 MiB/496.9 MiB]  30% Done   4.3 MiB/s ETA 00:01:19
# /

# %%
npy_data = np.load(paths_dict['base_input'] + '.npy', allow_pickle=True)
# Out:
# / [0/1 files][157.3 MiB/496.9 MiB]  31% Done   4.3 MiB/s ETA 00:01:19
# -
# \
# \ [0/1 files][162.7 MiB/496.9 MiB]  32% Done   4.4 MiB/s ETA 00:01:15
# |
# /
# / [0/1 files][167.6 MiB/496.9 MiB]  33% Done   4.5 MiB/s ETA 00:01:14
# -
# - [0/1 files][172.2 MiB/496.9 MiB]  34% Done   4.4 MiB/s ETA 00:01:13
# \
# |
# | [0/1 files][176.1 MiB/496.9 MiB]  35% Done   4.4 MiB/s ETA 00:01:13
# /
# -
# - [0/1 files][180.2 MiB/496.9 MiB]  36% Done   4.4 MiB/s ETA 00:01:13
# \
# \ [0/1 files][183.3 MiB/496.9 MiB]  36% Done   3.8 MiB/s ETA 00:01:22
# |
# /
# / [0/1 files][187.4 MiB/496.9 MiB]  37% Done   3.7 MiB/s ETA 00:01:24
# -
# - [0/1 files][191.6 MiB/496.9 MiB]  38% Done   3.7 MiB/s ETA 00:01:23
# \
# |
# | [0/1 files][195.2 MiB/496.9 MiB]  39% Done   3.6 MiB/s ETA 00:01:23
# /
# -
# - [0/1 files][198.8 MiB/496.9 MiB]  39% Done   3.6 MiB/s ETA 00:01:24
# \
# \ [0/1 files][202.6 MiB/496.9 MiB]  40% Done   3.6 MiB/s ETA 00:01:21
# |
# /
# / [0/1 files][206.5 MiB/496.9 MiB]  41% Done   3.7 MiB/s ETA 00:01:19
# -
# \
# \ [0/1 files][210.4 MiB/496.9 MiB]  42% Done   3.6 MiB/s ETA 00:01:20
# |
# | [0/1 files][213.2 MiB/496.9 MiB]  42% Done   3.4 MiB/s ETA 00:01:23
# /
# -
# - [0/1 files][217.8 MiB/496.9 MiB]  43% Done   3.6 MiB/s ETA 00:01:17
# \
# |
# | [0/1 files][222.5 MiB/496.9 MiB]  44% Done   3.7 MiB/s ETA 00:01:14
# /
# / [0/1 files][226.1 MiB/496.9 MiB]  45% Done   3.6 MiB/s ETA 00:01:16
# -
# \
# \ [0/1 files][230.7 MiB/496.9 MiB]  46% Done   3.9 MiB/s ETA 00:01:08
# |
# | [0/1 files][233.4 MiB/496.9 MiB]  46% Done   3.7 MiB/s ETA 00:01:11
# /
# -
# - [0/1 files][236.6 MiB/496.9 MiB]  47% Done   3.4 MiB/s ETA 00:01:18
# \
# \ [0/1 files][239.9 MiB/496.9 MiB]  48% Done   3.2 MiB/s ETA 00:01:19
# |
# /
# / [0/1 files][243.5 MiB/496.9 MiB]  49% Done   3.3 MiB/s ETA 00:01:17
# -
# - [0/1 files][247.4 MiB/496.9 MiB]  49% Done   3.2 MiB/s ETA 00:01:17
# \
# |
# | [0/1 files][251.0 MiB/496.9 MiB]  50% Done   3.5 MiB/s ETA 00:01:10
# /
# / [0/1 files][254.8 MiB/496.9 MiB]  51% Done   3.6 MiB/s ETA 00:01:07
# -
# \
# \ [0/1 files][258.7 MiB/496.9 MiB]  52% Done   3.6 MiB/s ETA 00:01:05
# |
# /
# / [0/1 files][262.6 MiB/496.9 MiB]  52% Done   3.7 MiB/s ETA 00:01:04
# -
# - [0/1 files][266.7 MiB/496.9 MiB]  53% Done   3.7 MiB/s ETA 00:01:03
# \
# |
# | [0/1 files][271.1 MiB/496.9 MiB]  54% Done   3.8 MiB/s ETA 00:00:59
# /
# -
# - [0/1 files][275.7 MiB/496.9 MiB]  55% Done   4.0 MiB/s ETA 00:00:56
# \
# \ [0/1 files][280.6 MiB/496.9 MiB]  56% Done   4.2 MiB/s ETA 00:00:52
# |
# /
# / [0/1 files][285.8 MiB/496.9 MiB]  57% Done   4.4 MiB/s ETA 00:00:47
# -
# \
# \ [0/1 files][290.4 MiB/496.9 MiB]  58% Done   4.6 MiB/s ETA 00:00:45
# |
# | [0/1 files][294.6 MiB/496.9 MiB]  59% Done   4.6 MiB/s ETA 00:00:44
# /
# -
# - [0/1 files][298.2 MiB/496.9 MiB]  59% Done   4.4 MiB/s ETA 00:00:45
# \
# \ [0/1 files][302.0 MiB/496.9 MiB]  60% Done   4.2 MiB/s ETA 00:00:47
# |
# /
# / [0/1 files][305.6 MiB/496.9 MiB]  61% Done   3.9 MiB/s ETA 00:00:49
# -
# \
# \ [0/1 files][309.5 MiB/496.9 MiB]  62% Done   3.7 MiB/s ETA 00:00:51
# |
# | [0/1 files][312.9 MiB/496.9 MiB]  62% Done   3.5 MiB/s ETA 00:00:53
# /
# -
# - [0/1 files][316.5 MiB/496.9 MiB]  63% Done   3.5 MiB/s ETA 00:00:52
# \
# \ [0/1 files][319.6 MiB/496.9 MiB]  64% Done   3.4 MiB/s ETA 00:00:53
# |
# /
# / [0/1 files][322.7 MiB/496.9 MiB]  64% Done   3.3 MiB/s ETA 00:00:53
# -
# \
# \ [0/1 files][326.8 MiB/496.9 MiB]  65% Done   3.4 MiB/s ETA 00:00:51
# |
# | [0/1 files][330.6 MiB/496.9 MiB]  66% Done   3.5 MiB/s ETA 00:00:47
# /
# -
# - [0/1 files][334.5 MiB/496.9 MiB]  67% Done   3.5 MiB/s ETA 00:00:46
# \
# \ [0/1 files][338.6 MiB/496.9 MiB]  68% Done   3.8 MiB/s ETA 00:00:42
# |
# /
# / [0/1 files][342.5 MiB/496.9 MiB]  68% Done   3.8 MiB/s ETA 00:00:40
# -
# \
# \ [0/1 files][346.1 MiB/496.9 MiB]  69% Done   3.8 MiB/s ETA 00:00:40
# |
# | [0/1 files][350.0 MiB/496.9 MiB]  70% Done   3.8 MiB/s ETA 00:00:39
# /
# -
# - [0/1 files][353.3 MiB/496.9 MiB]  71% Done   3.6 MiB/s ETA 00:00:39
# \
# \ [0/1 files][357.2 MiB/496.9 MiB]  71% Done   3.6 MiB/s ETA 00:00:39
# |
# /
# / [0/1 files][361.3 MiB/496.9 MiB]  72% Done   3.6 MiB/s ETA 00:00:38
# -
# \
# \ [0/1 files][365.4 MiB/496.9 MiB]  73% Done   3.6 MiB/s ETA 00:00:36
# |
# | [0/1 files][369.6 MiB/496.9 MiB]  74% Done   3.8 MiB/s ETA 00:00:34
# /
# -
# - [0/1 files][373.4 MiB/496.9 MiB]  75% Done   3.8 MiB/s ETA 00:00:33
# \
# |
# | [0/1 files][377.6 MiB/496.9 MiB]  75% Done   3.8 MiB/s ETA 00:00:31
# /
# / [0/1 files][381.4 MiB/496.9 MiB]  76% Done   3.8 MiB/s ETA 00:00:31
# -
# \
# \ [0/1 files][385.3 MiB/496.9 MiB]  77% Done   3.8 MiB/s ETA 00:00:30
# |
# /
# / [0/1 files][389.2 MiB/496.9 MiB]  78% Done   3.6 MiB/s ETA 00:00:30
# -
# \
# \ [0/1 files][393.3 MiB/496.9 MiB]  79% Done   3.6 MiB/s ETA 00:00:29
# |
# | [0/1 files][397.2 MiB/496.9 MiB]  79% Done   3.6 MiB/s ETA 00:00:28
# /
# -
# - [0/1 files][401.3 MiB/496.9 MiB]  80% Done   3.7 MiB/s ETA 00:00:26
# \
# |
# | [0/1 files][405.2 MiB/496.9 MiB]  81% Done   3.6 MiB/s ETA 00:00:25
# /
# / [0/1 files][408.8 MiB/496.9 MiB]  82% Done   3.6 MiB/s ETA 00:00:24
# -
# \
# \ [0/1 files][411.3 MiB/496.9 MiB]  82% Done   3.3 MiB/s ETA 00:00:26
# |
# /
# / [0/1 files][415.0 MiB/496.9 MiB]  83% Done   3.2 MiB/s ETA 00:00:25
# -
# - [0/1 files][418.8 MiB/496.9 MiB]  84% Done   3.2 MiB/s ETA 00:00:24
# \
# |
# | [0/1 files][422.2 MiB/496.9 MiB]  84% Done   3.1 MiB/s ETA 00:00:24
# /
# -
# - [0/1 files][425.8 MiB/496.9 MiB]  85% Done   3.3 MiB/s ETA 00:00:22
# \
# \ [0/1 files][429.6 MiB/496.9 MiB]  86% Done   3.5 MiB/s ETA 00:00:19
# |
# /
# / [0/1 files][433.3 MiB/496.9 MiB]  87% Done   3.5 MiB/s ETA 00:00:18
# -
# - [0/1 files][436.7 MiB/496.9 MiB]  87% Done   3.5 MiB/s ETA 00:00:17
# \
# |
# | [0/1 files][440.6 MiB/496.9 MiB]  88% Done   3.6 MiB/s ETA 00:00:16
# /
# -
# - [0/1 files][445.0 MiB/496.9 MiB]  89% Done   3.8 MiB/s ETA 00:00:14
# \
# \ [0/1 files][449.6 MiB/496.9 MiB]  90% Done   3.9 MiB/s ETA 00:00:12
# |
# /
# / [0/1 files][453.8 MiB/496.9 MiB]  91% Done   4.0 MiB/s ETA 00:00:11
# -
# - [0/1 files][457.9 MiB/496.9 MiB]  92% Done   4.1 MiB/s ETA 00:00:09
# \
# |
# | [0/1 files][461.8 MiB/496.9 MiB]  92% Done   4.1 MiB/s ETA 00:00:09
# /
# -
# - [0/1 files][466.4 MiB/496.9 MiB]  93% Done   4.1 MiB/s ETA 00:00:07
# \
# \ [0/1 files][471.0 MiB/496.9 MiB]  94% Done   4.1 MiB/s ETA 00:00:06
# |
# /
# / [0/1 files][476.2 MiB/496.9 MiB]  95% Done   4.4 MiB/s ETA 00:00:05
# -
# \
# \ [0/1 files][479.3 MiB/496.9 MiB]  96% Done   4.2 MiB/s ETA 00:00:04
# |
# | [0/1 files][483.4 MiB/496.9 MiB]  97% Done   4.2 MiB/s ETA 00:00:03
# /
# -
# - [0/1 files][487.5 MiB/496.9 MiB]  98% Done   4.0 MiB/s ETA 00:00:02
# \
# \ [0/1 files][491.6 MiB/496.9 MiB]  98% Done   3.8 MiB/s ETA 00:00:01
# |
# /
# / [0/1 files][495.5 MiB/496.9 MiB]  99% Done   3.7 MiB/s ETA 00:00:00
# -
# - [1/1 files][496.9 MiB/496.9 MiB] 100% Done   4.0 MiB/s ETA 00:00:00
#
# Operation completed over 1 objects/496.9 MiB.

# %%
# load from file-like objects
with open(paths_dict['base_raw'] + '.ndjson') as f:
    ndjson_data = ndjson.load(f)

# %%
def plot_bitmap():
    print("Bitmap image:")
    plt.imshow(npy_data[int(index)].reshape(28,28))

# %%
def plot_raw():
    print("Raw image:")
    i = 0
    for stroke in ndjson_data[int(index)]['drawing']:
        stroke = np.array(stroke)
        plt.plot(stroke[0], stroke[1]*-1)
        i += 1
    print('There are', i, 'number of strokes in this raw image file!')

# %%
print('There are ', len(npy_data)+1, ' images in selected category', categories[category])
print("Select an index value from 0 to", len(npy_data), "to display and compare bitmap and raw images:")
#index=input()
index='0'
plot_bitmap()
plt.show()
plot_raw()
# Out:
# There are  123203  images in selected category cat
# Select an index value from 0 to 123202 to display and compare bitmap and raw images:
# Bitmap image:
# Raw image:
# There are 9 number of strokes in this raw image file!

# %%
# TRAIN TEST SPLIT
filepath = paths_dict['input_path']
x_train, x_test, y_train, y_test = split_data(filepath, categories[category], shuffle=False)

# %%
T = int(config['DRAW']['T'])
batch_size = int(config['DRAW']['batch_size'])
A = int(config['DRAW']['A'])
B = int(config['DRAW']['B'])
z_size = int(config['DRAW']['z_size'])
N = int(config['DRAW']['N'])
dec_size = int(config['DRAW']['dec_size'])
enc_size = int(config['DRAW']['enc_size'])
epoch_num = int(config['DRAW']['epoch_num'])
learning_rate = float(config['DRAW']['learning_rate'])
beta1 = float(config['DRAW']['beta1'])
USE_CUDA = eval(config['DRAW']['USE_CUDA'])
clip = float(config['DRAW']['clip'])
path = os.path.join(root_path, "src", config['DRAW']['path'])
image_output_file=os.path.join(root_path, "src", config['DRAW']['image_output_file'])
base_img_name=os.path.join(root_path, "src", config['DRAW']['base_img_name'])

# %%
# TRAINING AND TESTING

train_data = Dataset(x_train)
print('training data length:', int(len(train_data.data)/batch_size))

test_data = Dataset(x_test)
print('test data length:', int(len(test_data.data)/batch_size))

model = DRAW(T, A, B, batch_size, z_size, N, dec_size, enc_size, learning_rate, beta1, clip, path, category)

if USE_CUDA:
    model.cuda()

def train():
    print("training...")
    img_loc = {'startr':150,
               'endr':180,
               'startc':120,
               'endc':150}
    model.start(epoch_num, img_loc, phase='train') 

def test():    
    print("testing...")
    img_loc = {'startr':150,
               'endr':180,
               'startc':120,
               'endc':150}    
    model.start(epoch_num, img_loc, phase='test')
# Out:
# training data length: 1540
# test data length: 385

# %%
#epoch_num = 1

# %%
# TRAINING
train()
# Out:
# training...
# start, end:0, 64
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\draw_model.py:216: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(self.parameters(), self.clip)
# start, end:64, 128
# start, end:128, 192
# start, end:192, 256
# start, end:256, 320
# start, end:320, 384
# start, end:384, 448
# start, end:448, 512
# start, end:512, 576
# start, end:576, 640
# start, end:640, 704
# start, end:704, 768
# start, end:768, 832
# start, end:832, 896
# start, end:896, 960
# start, end:960, 1024
# start, end:1024, 1088
# start, end:1088, 1152
# start, end:1152, 1216
# start, end:1216, 1280
# start, end:1280, 1344
# start, end:1344, 1408
# start, end:1408, 1472
# start, end:1472, 1536
# start, end:1536, 1600
# start, end:1600, 1664
# start, end:1664, 1728
# start, end:1728, 1792
# start, end:1792, 1856
# start, end:1856, 1920
# start, end:1920, 1984
# start, end:1984, 2048
# start, end:2048, 2112
# start, end:2112, 2176
# start, end:2176, 2240
# start, end:2240, 2304
# start, end:2304, 2368
# start, end:2368, 2432
# start, end:2432, 2496
# start, end:2496, 2560
# start, end:2560, 2624
# start, end:2624, 2688
# start, end:2688, 2752
# start, end:2752, 2816
# start, end:2816, 2880
# start, end:2880, 2944
# start, end:2944, 3008
# start, end:3008, 3072
# start, end:3072, 3136
# start, end:3136, 3200
# start, end:3200, 3264
# start, end:3264, 3328
# start, end:3328, 3392
# start, end:3392, 3456
# start, end:3456, 3520
# start, end:3520, 3584
# start, end:3584, 3648
# start, end:3648, 3712
# start, end:3712, 3776
# start, end:3776, 3840
# start, end:3840, 3904
# start, end:3904, 3968
# start, end:3968, 4032
# start, end:4032, 4096
# start, end:4096, 4160
# start, end:4160, 4224
# start, end:4224, 4288
# start, end:4288, 4352
# start, end:4352, 4416
# start, end:4416, 4480
# start, end:4480, 4544
# start, end:4544, 4608
# start, end:4608, 4672
# start, end:4672, 4736
# start, end:4736, 4800
# start, end:4800, 4864
# start, end:4864, 4928
# start, end:4928, 4992
# start, end:4992, 5056
# start, end:5056, 5120
# start, end:5120, 5184
# start, end:5184, 5248
# start, end:5248, 5312
# start, end:5312, 5376
# start, end:5376, 5440
# start, end:5440, 5504
# start, end:5504, 5568
# start, end:5568, 5632
# start, end:5632, 5696
# start, end:5696, 5760
# start, end:5760, 5824
# start, end:5824, 5888
# start, end:5888, 5952
# start, end:5952, 6016
# start, end:6016, 6080
# start, end:6080, 6144
# start, end:6144, 6208
# start, end:6208, 6272
# start, end:6272, 6336
# start, end:6336, 6400
# Phase: train | Epoch: 0 | Count: 100 \ Start Time: 00:35:12 | Loss: 355
# start, end:6400, 6464
# start, end:6464, 6528
# start, end:6528, 6592
# start, end:6592, 6656
# start, end:6656, 6720
# start, end:6720, 6784
# start, end:6784, 6848
# start, end:6848, 6912
# start, end:6912, 6976
# start, end:6976, 7040
# start, end:7040, 7104
# start, end:7104, 7168
# start, end:7168, 7232
# start, end:7232, 7296
# start, end:7296, 7360
# start, end:7360, 7424
# start, end:7424, 7488
# start, end:7488, 7552
# start, end:7552, 7616
# start, end:7616, 7680
# start, end:7680, 7744
# start, end:7744, 7808
# start, end:7808, 7872
# start, end:7872, 7936
# start, end:7936, 8000
# start, end:8000, 8064
# start, end:8064, 8128
# start, end:8128, 8192
# start, end:8192, 8256
# start, end:8256, 8320
# start, end:8320, 8384
# start, end:8384, 8448
# start, end:8448, 8512
# start, end:8512, 8576
# start, end:8576, 8640
# start, end:8640, 8704
# start, end:8704, 8768
# start, end:8768, 8832
# start, end:8832, 8896
# start, end:8896, 8960
# start, end:8960, 9024
# start, end:9024, 9088
# start, end:9088, 9152
# start, end:9152, 9216
# start, end:9216, 9280
# start, end:9280, 9344
# start, end:9344, 9408
# start, end:9408, 9472
# start, end:9472, 9536
# start, end:9536, 9600
# start, end:9600, 9664
# start, end:9664, 9728
# start, end:9728, 9792
# start, end:9792, 9856
# start, end:9856, 9920
# start, end:9920, 9984
# start, end:9984, 10048
# start, end:10048, 10112
# start, end:10112, 10176
# start, end:10176, 10240
# start, end:10240, 10304
# start, end:10304, 10368
# start, end:10368, 10432
# start, end:10432, 10496
# start, end:10496, 10560
# start, end:10560, 10624
# start, end:10624, 10688
# start, end:10688, 10752
# start, end:10752, 10816
# start, end:10816, 10880
# start, end:10880, 10944
# start, end:10944, 11008
# start, end:11008, 11072
# start, end:11072, 11136
# start, end:11136, 11200
# start, end:11200, 11264
# start, end:11264, 11328
# start, end:11328, 11392
# start, end:11392, 11456
# start, end:11456, 11520
# start, end:11520, 11584
# start, end:11584, 11648
# start, end:11648, 11712
# start, end:11712, 11776
# start, end:11776, 11840
# start, end:11840, 11904
# start, end:11904, 11968
# start, end:11968, 12032
# start, end:12032, 12096
# start, end:12096, 12160
# start, end:12160, 12224
# start, end:12224, 12288
# start, end:12288, 12352
# start, end:12352, 12416
# start, end:12416, 12480
# start, end:12480, 12544
# start, end:12544, 12608
# start, end:12608, 12672
# start, end:12672, 12736
# start, end:12736, 12800
# Phase: train | Epoch: 0 | Count: 200 \ Start Time: 00:35:55 | Loss: 324
# start, end:12800, 12864
# start, end:12864, 12928
# start, end:12928, 12992
# start, end:12992, 13056
# start, end:13056, 13120
# start, end:13120, 13184
# start, end:13184, 13248
# start, end:13248, 13312
# start, end:13312, 13376
# start, end:13376, 13440
# start, end:13440, 13504
# start, end:13504, 13568
# start, end:13568, 13632
# start, end:13632, 13696
# start, end:13696, 13760
# start, end:13760, 13824
# start, end:13824, 13888
# start, end:13888, 13952
# start, end:13952, 14016
# start, end:14016, 14080
# start, end:14080, 14144
# start, end:14144, 14208
# start, end:14208, 14272
# start, end:14272, 14336
# start, end:14336, 14400
# start, end:14400, 14464
# start, end:14464, 14528
# start, end:14528, 14592
# start, end:14592, 14656
# start, end:14656, 14720
# start, end:14720, 14784
# start, end:14784, 14848
# start, end:14848, 14912
# start, end:14912, 14976
# start, end:14976, 15040
# start, end:15040, 15104
# start, end:15104, 15168
# start, end:15168, 15232
# start, end:15232, 15296
# start, end:15296, 15360
# start, end:15360, 15424
# start, end:15424, 15488
# start, end:15488, 15552
# start, end:15552, 15616
# start, end:15616, 15680
# start, end:15680, 15744
# start, end:15744, 15808
# start, end:15808, 15872
# start, end:15872, 15936
# start, end:15936, 16000
# start, end:16000, 16064
# start, end:16064, 16128
# start, end:16128, 16192
# start, end:16192, 16256
# start, end:16256, 16320
# start, end:16320, 16384
# start, end:16384, 16448
# start, end:16448, 16512
# start, end:16512, 16576
# start, end:16576, 16640
# start, end:16640, 16704
# start, end:16704, 16768
# start, end:16768, 16832
# start, end:16832, 16896
# start, end:16896, 16960
# start, end:16960, 17024
# start, end:17024, 17088
# start, end:17088, 17152
# start, end:17152, 17216
# start, end:17216, 17280
# start, end:17280, 17344
# start, end:17344, 17408
# start, end:17408, 17472
# start, end:17472, 17536
# start, end:17536, 17600
# start, end:17600, 17664
# start, end:17664, 17728
# start, end:17728, 17792
# start, end:17792, 17856
# start, end:17856, 17920
# start, end:17920, 17984
# start, end:17984, 18048
# start, end:18048, 18112
# start, end:18112, 18176
# start, end:18176, 18240
# start, end:18240, 18304
# start, end:18304, 18368
# start, end:18368, 18432
# start, end:18432, 18496
# start, end:18496, 18560
# start, end:18560, 18624
# start, end:18624, 18688
# start, end:18688, 18752
# start, end:18752, 18816
# start, end:18816, 18880
# start, end:18880, 18944
# start, end:18944, 19008
# start, end:19008, 19072
# start, end:19072, 19136
# start, end:19136, 19200
# Phase: train | Epoch: 0 | Count: 300 \ Start Time: 00:36:38 | Loss: 316
# start, end:19200, 19264
# start, end:19264, 19328
# start, end:19328, 19392
# start, end:19392, 19456
# start, end:19456, 19520
# start, end:19520, 19584
# start, end:19584, 19648
# start, end:19648, 19712
# start, end:19712, 19776
# start, end:19776, 19840
# start, end:19840, 19904
# start, end:19904, 19968
# start, end:19968, 20032
# start, end:20032, 20096
# start, end:20096, 20160
# start, end:20160, 20224
# start, end:20224, 20288
# start, end:20288, 20352
# start, end:20352, 20416
# start, end:20416, 20480
# start, end:20480, 20544
# start, end:20544, 20608
# start, end:20608, 20672
# start, end:20672, 20736
# start, end:20736, 20800
# start, end:20800, 20864
# start, end:20864, 20928
# start, end:20928, 20992
# start, end:20992, 21056
# start, end:21056, 21120
# start, end:21120, 21184
# start, end:21184, 21248
# start, end:21248, 21312
# start, end:21312, 21376
# start, end:21376, 21440
# start, end:21440, 21504
# start, end:21504, 21568
# start, end:21568, 21632
# start, end:21632, 21696
# start, end:21696, 21760
# start, end:21760, 21824
# start, end:21824, 21888
# start, end:21888, 21952
# start, end:21952, 22016
# start, end:22016, 22080
# start, end:22080, 22144
# start, end:22144, 22208
# start, end:22208, 22272
# start, end:22272, 22336
# start, end:22336, 22400
# start, end:22400, 22464
# start, end:22464, 22528
# start, end:22528, 22592
# start, end:22592, 22656
# start, end:22656, 22720
# start, end:22720, 22784
# start, end:22784, 22848
# start, end:22848, 22912
# start, end:22912, 22976
# start, end:22976, 23040
# start, end:23040, 23104
# start, end:23104, 23168
# start, end:23168, 23232
# start, end:23232, 23296
# start, end:23296, 23360
# start, end:23360, 23424
# start, end:23424, 23488
# start, end:23488, 23552
# start, end:23552, 23616
# start, end:23616, 23680
# start, end:23680, 23744
# start, end:23744, 23808
# start, end:23808, 23872
# start, end:23872, 23936
# start, end:23936, 24000
# start, end:24000, 24064
# start, end:24064, 24128
# start, end:24128, 24192
# start, end:24192, 24256
# start, end:24256, 24320
# start, end:24320, 24384
# start, end:24384, 24448
# start, end:24448, 24512
# start, end:24512, 24576
# start, end:24576, 24640
# start, end:24640, 24704
# start, end:24704, 24768
# start, end:24768, 24832
# start, end:24832, 24896
# start, end:24896, 24960
# start, end:24960, 25024
# start, end:25024, 25088
# start, end:25088, 25152
# start, end:25152, 25216
# start, end:25216, 25280
# start, end:25280, 25344
# start, end:25344, 25408
# start, end:25408, 25472
# start, end:25472, 25536
# start, end:25536, 25600
# Phase: train | Epoch: 0 | Count: 400 \ Start Time: 00:37:18 | Loss: 311
# start, end:25600, 25664
# start, end:25664, 25728
# start, end:25728, 25792
# start, end:25792, 25856
# start, end:25856, 25920
# start, end:25920, 25984
# start, end:25984, 26048
# start, end:26048, 26112
# start, end:26112, 26176
# start, end:26176, 26240
# start, end:26240, 26304
# start, end:26304, 26368
# start, end:26368, 26432
# start, end:26432, 26496
# start, end:26496, 26560
# start, end:26560, 26624
# start, end:26624, 26688
# start, end:26688, 26752
# start, end:26752, 26816
# start, end:26816, 26880
# start, end:26880, 26944
# start, end:26944, 27008
# start, end:27008, 27072
# start, end:27072, 27136
# start, end:27136, 27200
# start, end:27200, 27264
# start, end:27264, 27328
# start, end:27328, 27392
# start, end:27392, 27456
# start, end:27456, 27520
# start, end:27520, 27584
# start, end:27584, 27648
# start, end:27648, 27712
# start, end:27712, 27776
# start, end:27776, 27840
# start, end:27840, 27904
# start, end:27904, 27968
# start, end:27968, 28032
# start, end:28032, 28096
# start, end:28096, 28160
# start, end:28160, 28224
# start, end:28224, 28288
# start, end:28288, 28352
# start, end:28352, 28416
# start, end:28416, 28480
# start, end:28480, 28544
# start, end:28544, 28608
# start, end:28608, 28672
# start, end:28672, 28736
# start, end:28736, 28800
# start, end:28800, 28864
# start, end:28864, 28928
# start, end:28928, 28992
# start, end:28992, 29056
# start, end:29056, 29120
# start, end:29120, 29184
# start, end:29184, 29248
# start, end:29248, 29312
# start, end:29312, 29376
# start, end:29376, 29440
# start, end:29440, 29504
# start, end:29504, 29568
# start, end:29568, 29632
# start, end:29632, 29696
# start, end:29696, 29760
# start, end:29760, 29824
# start, end:29824, 29888
# start, end:29888, 29952
# start, end:29952, 30016
# start, end:30016, 30080
# start, end:30080, 30144
# start, end:30144, 30208
# start, end:30208, 30272
# start, end:30272, 30336
# start, end:30336, 30400
# start, end:30400, 30464
# start, end:30464, 30528
# start, end:30528, 30592
# start, end:30592, 30656
# start, end:30656, 30720
# start, end:30720, 30784
# start, end:30784, 30848
# start, end:30848, 30912
# start, end:30912, 30976
# start, end:30976, 31040
# start, end:31040, 31104
# start, end:31104, 31168
# start, end:31168, 31232
# start, end:31232, 31296
# start, end:31296, 31360
# start, end:31360, 31424
# start, end:31424, 31488
# start, end:31488, 31552
# start, end:31552, 31616
# start, end:31616, 31680
# start, end:31680, 31744
# start, end:31744, 31808
# start, end:31808, 31872
# start, end:31872, 31936
# start, end:31936, 32000
# Phase: train | Epoch: 0 | Count: 500 \ Start Time: 00:37:57 | Loss: 306
# start, end:32000, 32064
# start, end:32064, 32128
# start, end:32128, 32192
# start, end:32192, 32256
# start, end:32256, 32320
# start, end:32320, 32384
# start, end:32384, 32448
# start, end:32448, 32512
# start, end:32512, 32576
# start, end:32576, 32640
# start, end:32640, 32704
# start, end:32704, 32768
# start, end:32768, 32832
# start, end:32832, 32896
# start, end:32896, 32960
# start, end:32960, 33024
# start, end:33024, 33088
# start, end:33088, 33152
# start, end:33152, 33216
# start, end:33216, 33280
# start, end:33280, 33344
# start, end:33344, 33408
# start, end:33408, 33472
# start, end:33472, 33536
# start, end:33536, 33600
# start, end:33600, 33664
# start, end:33664, 33728
# start, end:33728, 33792
# start, end:33792, 33856
# start, end:33856, 33920
# start, end:33920, 33984
# start, end:33984, 34048
# start, end:34048, 34112
# start, end:34112, 34176
# start, end:34176, 34240
# start, end:34240, 34304
# start, end:34304, 34368
# start, end:34368, 34432
# start, end:34432, 34496
# start, end:34496, 34560
# start, end:34560, 34624
# start, end:34624, 34688
# start, end:34688, 34752
# start, end:34752, 34816
# start, end:34816, 34880
# start, end:34880, 34944
# start, end:34944, 35008
# start, end:35008, 35072
# start, end:35072, 35136
# start, end:35136, 35200
# start, end:35200, 35264
# start, end:35264, 35328
# start, end:35328, 35392
# start, end:35392, 35456
# start, end:35456, 35520
# start, end:35520, 35584
# start, end:35584, 35648
# start, end:35648, 35712
# start, end:35712, 35776
# start, end:35776, 35840
# start, end:35840, 35904
# start, end:35904, 35968
# start, end:35968, 36032
# start, end:36032, 36096
# start, end:36096, 36160
# start, end:36160, 36224
# start, end:36224, 36288
# start, end:36288, 36352
# start, end:36352, 36416
# start, end:36416, 36480
# start, end:36480, 36544
# start, end:36544, 36608
# start, end:36608, 36672
# start, end:36672, 36736
# start, end:36736, 36800
# start, end:36800, 36864
# start, end:36864, 36928
# start, end:36928, 36992
# start, end:36992, 37056
# start, end:37056, 37120
# start, end:37120, 37184
# start, end:37184, 37248
# start, end:37248, 37312
# start, end:37312, 37376
# start, end:37376, 37440
# start, end:37440, 37504
# start, end:37504, 37568
# start, end:37568, 37632
# start, end:37632, 37696
# start, end:37696, 37760
# start, end:37760, 37824
# start, end:37824, 37888
# start, end:37888, 37952
# start, end:37952, 38016
# start, end:38016, 38080
# start, end:38080, 38144
# start, end:38144, 38208
# start, end:38208, 38272
# start, end:38272, 38336
# start, end:38336, 38400
# Phase: train | Epoch: 0 | Count: 600 \ Start Time: 00:38:38 | Loss: 308
# start, end:38400, 38464
# start, end:38464, 38528
# start, end:38528, 38592
# start, end:38592, 38656
# start, end:38656, 38720
# start, end:38720, 38784
# start, end:38784, 38848
# start, end:38848, 38912
# start, end:38912, 38976
# start, end:38976, 39040
# start, end:39040, 39104
# start, end:39104, 39168
# start, end:39168, 39232
# start, end:39232, 39296
# start, end:39296, 39360
# start, end:39360, 39424
# start, end:39424, 39488
# start, end:39488, 39552
# start, end:39552, 39616
# start, end:39616, 39680
# start, end:39680, 39744
# start, end:39744, 39808
# start, end:39808, 39872
# start, end:39872, 39936
# start, end:39936, 40000
# start, end:40000, 40064
# start, end:40064, 40128
# start, end:40128, 40192
# start, end:40192, 40256
# start, end:40256, 40320
# start, end:40320, 40384
# start, end:40384, 40448
# start, end:40448, 40512
# start, end:40512, 40576
# start, end:40576, 40640
# start, end:40640, 40704
# start, end:40704, 40768
# start, end:40768, 40832
# start, end:40832, 40896
# start, end:40896, 40960
# start, end:40960, 41024
# start, end:41024, 41088
# start, end:41088, 41152
# start, end:41152, 41216
# start, end:41216, 41280
# start, end:41280, 41344
# start, end:41344, 41408
# start, end:41408, 41472
# start, end:41472, 41536
# start, end:41536, 41600
# start, end:41600, 41664
# start, end:41664, 41728
# start, end:41728, 41792
# start, end:41792, 41856
# start, end:41856, 41920
# start, end:41920, 41984
# start, end:41984, 42048
# start, end:42048, 42112
# start, end:42112, 42176
# start, end:42176, 42240
# start, end:42240, 42304
# start, end:42304, 42368
# start, end:42368, 42432
# start, end:42432, 42496
# start, end:42496, 42560
# start, end:42560, 42624
# start, end:42624, 42688
# start, end:42688, 42752
# start, end:42752, 42816
# start, end:42816, 42880
# start, end:42880, 42944
# start, end:42944, 43008
# start, end:43008, 43072
# start, end:43072, 43136
# start, end:43136, 43200
# start, end:43200, 43264
# start, end:43264, 43328
# start, end:43328, 43392
# start, end:43392, 43456
# start, end:43456, 43520
# start, end:43520, 43584
# start, end:43584, 43648
# start, end:43648, 43712
# start, end:43712, 43776
# start, end:43776, 43840
# start, end:43840, 43904
# start, end:43904, 43968
# start, end:43968, 44032
# start, end:44032, 44096
# start, end:44096, 44160
# start, end:44160, 44224
# start, end:44224, 44288
# start, end:44288, 44352
# start, end:44352, 44416
# start, end:44416, 44480
# start, end:44480, 44544
# start, end:44544, 44608
# start, end:44608, 44672
# start, end:44672, 44736
# start, end:44736, 44800
# Phase: train | Epoch: 0 | Count: 700 \ Start Time: 00:39:18 | Loss: 305
# start, end:44800, 44864
# start, end:44864, 44928
# start, end:44928, 44992
# start, end:44992, 45056
# start, end:45056, 45120
# start, end:45120, 45184
# start, end:45184, 45248
# start, end:45248, 45312
# start, end:45312, 45376
# start, end:45376, 45440
# start, end:45440, 45504
# start, end:45504, 45568
# start, end:45568, 45632
# start, end:45632, 45696
# start, end:45696, 45760
# start, end:45760, 45824
# start, end:45824, 45888
# start, end:45888, 45952
# start, end:45952, 46016
# start, end:46016, 46080
# start, end:46080, 46144
# start, end:46144, 46208
# start, end:46208, 46272
# start, end:46272, 46336
# start, end:46336, 46400
# start, end:46400, 46464
# start, end:46464, 46528
# start, end:46528, 46592
# start, end:46592, 46656
# start, end:46656, 46720
# start, end:46720, 46784
# start, end:46784, 46848
# start, end:46848, 46912
# start, end:46912, 46976
# start, end:46976, 47040
# start, end:47040, 47104
# start, end:47104, 47168
# start, end:47168, 47232
# start, end:47232, 47296
# start, end:47296, 47360
# start, end:47360, 47424
# start, end:47424, 47488
# start, end:47488, 47552
# start, end:47552, 47616
# start, end:47616, 47680
# start, end:47680, 47744
# start, end:47744, 47808
# start, end:47808, 47872
# start, end:47872, 47936
# start, end:47936, 48000
# start, end:48000, 48064
# start, end:48064, 48128
# start, end:48128, 48192
# start, end:48192, 48256
# start, end:48256, 48320
# start, end:48320, 48384
# start, end:48384, 48448
# start, end:48448, 48512
# start, end:48512, 48576
# start, end:48576, 48640
# start, end:48640, 48704
# start, end:48704, 48768
# start, end:48768, 48832
# start, end:48832, 48896
# start, end:48896, 48960
# start, end:48960, 49024
# start, end:49024, 49088
# start, end:49088, 49152
# start, end:49152, 49216
# start, end:49216, 49280
# start, end:49280, 49344
# start, end:49344, 49408
# start, end:49408, 49472
# start, end:49472, 49536
# start, end:49536, 49600
# start, end:49600, 49664
# start, end:49664, 49728
# start, end:49728, 49792
# start, end:49792, 49856
# start, end:49856, 49920
# start, end:49920, 49984
# start, end:49984, 50048
# start, end:50048, 50112
# start, end:50112, 50176
# start, end:50176, 50240
# start, end:50240, 50304
# start, end:50304, 50368
# start, end:50368, 50432
# start, end:50432, 50496
# start, end:50496, 50560
# start, end:50560, 50624
# start, end:50624, 50688
# start, end:50688, 50752
# start, end:50752, 50816
# start, end:50816, 50880
# start, end:50880, 50944
# start, end:50944, 51008
# start, end:51008, 51072
# start, end:51072, 51136
# start, end:51136, 51200
# Phase: train | Epoch: 0 | Count: 800 \ Start Time: 00:39:56 | Loss: 300
# start, end:51200, 51264
# start, end:51264, 51328
# start, end:51328, 51392
# start, end:51392, 51456
# start, end:51456, 51520
# start, end:51520, 51584
# start, end:51584, 51648
# start, end:51648, 51712
# start, end:51712, 51776
# start, end:51776, 51840
# start, end:51840, 51904
# start, end:51904, 51968
# start, end:51968, 52032
# start, end:52032, 52096
# start, end:52096, 52160
# start, end:52160, 52224
# start, end:52224, 52288
# start, end:52288, 52352
# start, end:52352, 52416
# start, end:52416, 52480
# start, end:52480, 52544
# start, end:52544, 52608
# start, end:52608, 52672
# start, end:52672, 52736
# start, end:52736, 52800
# start, end:52800, 52864
# start, end:52864, 52928
# start, end:52928, 52992
# start, end:52992, 53056
# start, end:53056, 53120
# start, end:53120, 53184
# start, end:53184, 53248
# start, end:53248, 53312
# start, end:53312, 53376
# start, end:53376, 53440
# start, end:53440, 53504
# start, end:53504, 53568
# start, end:53568, 53632
# start, end:53632, 53696
# start, end:53696, 53760
# start, end:53760, 53824
# start, end:53824, 53888
# start, end:53888, 53952
# start, end:53952, 54016
# start, end:54016, 54080
# start, end:54080, 54144
# start, end:54144, 54208
# start, end:54208, 54272
# start, end:54272, 54336
# start, end:54336, 54400
# start, end:54400, 54464
# start, end:54464, 54528
# start, end:54528, 54592
# start, end:54592, 54656
# start, end:54656, 54720
# start, end:54720, 54784
# start, end:54784, 54848
# start, end:54848, 54912
# start, end:54912, 54976
# start, end:54976, 55040
# start, end:55040, 55104
# start, end:55104, 55168
# start, end:55168, 55232
# start, end:55232, 55296
# start, end:55296, 55360
# start, end:55360, 55424
# start, end:55424, 55488
# start, end:55488, 55552
# start, end:55552, 55616
# start, end:55616, 55680
# start, end:55680, 55744
# start, end:55744, 55808
# start, end:55808, 55872
# start, end:55872, 55936
# start, end:55936, 56000
# start, end:56000, 56064
# start, end:56064, 56128
# start, end:56128, 56192
# start, end:56192, 56256
# start, end:56256, 56320
# start, end:56320, 56384
# start, end:56384, 56448
# start, end:56448, 56512
# start, end:56512, 56576
# start, end:56576, 56640
# start, end:56640, 56704
# start, end:56704, 56768
# start, end:56768, 56832
# start, end:56832, 56896
# start, end:56896, 56960
# start, end:56960, 57024
# start, end:57024, 57088
# start, end:57088, 57152
# start, end:57152, 57216
# start, end:57216, 57280
# start, end:57280, 57344
# start, end:57344, 57408
# start, end:57408, 57472
# start, end:57472, 57536
# start, end:57536, 57600
# Phase: train | Epoch: 0 | Count: 900 \ Start Time: 00:40:36 | Loss: 301
# start, end:57600, 57664
# start, end:57664, 57728
# start, end:57728, 57792
# start, end:57792, 57856
# start, end:57856, 57920
# start, end:57920, 57984
# start, end:57984, 58048
# start, end:58048, 58112
# start, end:58112, 58176
# start, end:58176, 58240
# start, end:58240, 58304
# start, end:58304, 58368
# start, end:58368, 58432
# start, end:58432, 58496
# start, end:58496, 58560
# start, end:58560, 58624
# start, end:58624, 58688
# start, end:58688, 58752
# start, end:58752, 58816
# start, end:58816, 58880
# start, end:58880, 58944
# start, end:58944, 59008
# start, end:59008, 59072
# start, end:59072, 59136
# start, end:59136, 59200
# start, end:59200, 59264
# start, end:59264, 59328
# start, end:59328, 59392
# start, end:59392, 59456
# start, end:59456, 59520
# start, end:59520, 59584
# start, end:59584, 59648
# start, end:59648, 59712
# start, end:59712, 59776
# start, end:59776, 59840
# start, end:59840, 59904
# start, end:59904, 59968
# start, end:59968, 60032
# start, end:60032, 60096
# start, end:60096, 60160
# start, end:60160, 60224
# start, end:60224, 60288
# start, end:60288, 60352
# start, end:60352, 60416
# start, end:60416, 60480
# start, end:60480, 60544
# start, end:60544, 60608
# start, end:60608, 60672
# start, end:60672, 60736
# start, end:60736, 60800
# start, end:60800, 60864
# start, end:60864, 60928
# start, end:60928, 60992
# start, end:60992, 61056
# start, end:61056, 61120
# start, end:61120, 61184
# start, end:61184, 61248
# start, end:61248, 61312
# start, end:61312, 61376
# start, end:61376, 61440
# start, end:61440, 61504
# start, end:61504, 61568
# start, end:61568, 61632
# start, end:61632, 61696
# start, end:61696, 61760
# start, end:61760, 61824
# start, end:61824, 61888
# start, end:61888, 61952
# start, end:61952, 62016
# start, end:62016, 62080
# start, end:62080, 62144
# start, end:62144, 62208
# start, end:62208, 62272
# start, end:62272, 62336
# start, end:62336, 62400
# start, end:62400, 62464
# start, end:62464, 62528
# start, end:62528, 62592
# start, end:62592, 62656
# start, end:62656, 62720
# start, end:62720, 62784
# start, end:62784, 62848
# start, end:62848, 62912
# start, end:62912, 62976
# start, end:62976, 63040
# start, end:63040, 63104
# start, end:63104, 63168
# start, end:63168, 63232
# start, end:63232, 63296
# start, end:63296, 63360
# start, end:63360, 63424
# start, end:63424, 63488
# start, end:63488, 63552
# start, end:63552, 63616
# start, end:63616, 63680
# start, end:63680, 63744
# start, end:63744, 63808
# start, end:63808, 63872
# start, end:63872, 63936
# start, end:63936, 64000
# Phase: train | Epoch: 0 | Count: 1000 \ Start Time: 00:41:14 | Loss: 297
# start, end:64000, 64064
# start, end:64064, 64128
# start, end:64128, 64192
# start, end:64192, 64256
# start, end:64256, 64320
# start, end:64320, 64384
# start, end:64384, 64448
# start, end:64448, 64512
# start, end:64512, 64576
# start, end:64576, 64640
# start, end:64640, 64704
# start, end:64704, 64768
# start, end:64768, 64832
# start, end:64832, 64896
# start, end:64896, 64960
# start, end:64960, 65024
# start, end:65024, 65088
# start, end:65088, 65152
# start, end:65152, 65216
# start, end:65216, 65280
# start, end:65280, 65344
# start, end:65344, 65408
# start, end:65408, 65472
# start, end:65472, 65536
# start, end:65536, 65600
# start, end:65600, 65664
# start, end:65664, 65728
# start, end:65728, 65792
# start, end:65792, 65856
# start, end:65856, 65920
# start, end:65920, 65984
# start, end:65984, 66048
# start, end:66048, 66112
# start, end:66112, 66176
# start, end:66176, 66240
# start, end:66240, 66304
# start, end:66304, 66368
# start, end:66368, 66432
# start, end:66432, 66496
# start, end:66496, 66560
# start, end:66560, 66624
# start, end:66624, 66688
# start, end:66688, 66752
# start, end:66752, 66816
# start, end:66816, 66880
# start, end:66880, 66944
# start, end:66944, 67008
# start, end:67008, 67072
# start, end:67072, 67136
# start, end:67136, 67200
# start, end:67200, 67264
# start, end:67264, 67328
# start, end:67328, 67392
# start, end:67392, 67456
# start, end:67456, 67520
# start, end:67520, 67584
# start, end:67584, 67648
# start, end:67648, 67712
# start, end:67712, 67776
# start, end:67776, 67840
# start, end:67840, 67904
# start, end:67904, 67968
# start, end:67968, 68032
# start, end:68032, 68096
# start, end:68096, 68160
# start, end:68160, 68224
# start, end:68224, 68288
# start, end:68288, 68352
# start, end:68352, 68416
# start, end:68416, 68480
# start, end:68480, 68544
# start, end:68544, 68608
# start, end:68608, 68672
# start, end:68672, 68736
# start, end:68736, 68800
# start, end:68800, 68864
# start, end:68864, 68928
# start, end:68928, 68992
# start, end:68992, 69056
# start, end:69056, 69120
# start, end:69120, 69184
# start, end:69184, 69248
# start, end:69248, 69312
# start, end:69312, 69376
# start, end:69376, 69440
# start, end:69440, 69504
# start, end:69504, 69568
# start, end:69568, 69632
# start, end:69632, 69696
# start, end:69696, 69760
# start, end:69760, 69824
# start, end:69824, 69888
# start, end:69888, 69952
# start, end:69952, 70016
# start, end:70016, 70080
# start, end:70080, 70144
# start, end:70144, 70208
# start, end:70208, 70272
# start, end:70272, 70336
# start, end:70336, 70400
# Phase: train | Epoch: 0 | Count: 1100 \ Start Time: 00:41:55 | Loss: 294
# start, end:70400, 70464
# start, end:70464, 70528
# start, end:70528, 70592
# start, end:70592, 70656
# start, end:70656, 70720
# start, end:70720, 70784
# start, end:70784, 70848
# start, end:70848, 70912
# start, end:70912, 70976
# start, end:70976, 71040
# start, end:71040, 71104
# start, end:71104, 71168
# start, end:71168, 71232
# start, end:71232, 71296
# start, end:71296, 71360
# start, end:71360, 71424
# start, end:71424, 71488
# start, end:71488, 71552
# start, end:71552, 71616
# start, end:71616, 71680
# start, end:71680, 71744
# start, end:71744, 71808
# start, end:71808, 71872
# start, end:71872, 71936
# start, end:71936, 72000
# start, end:72000, 72064
# start, end:72064, 72128
# start, end:72128, 72192
# start, end:72192, 72256
# start, end:72256, 72320
# start, end:72320, 72384
# start, end:72384, 72448
# start, end:72448, 72512
# start, end:72512, 72576
# start, end:72576, 72640
# start, end:72640, 72704
# start, end:72704, 72768
# start, end:72768, 72832
# start, end:72832, 72896
# start, end:72896, 72960
# start, end:72960, 73024
# start, end:73024, 73088
# start, end:73088, 73152
# start, end:73152, 73216
# start, end:73216, 73280
# start, end:73280, 73344
# start, end:73344, 73408
# start, end:73408, 73472
# start, end:73472, 73536
# start, end:73536, 73600
# start, end:73600, 73664
# start, end:73664, 73728
# start, end:73728, 73792
# start, end:73792, 73856
# start, end:73856, 73920
# start, end:73920, 73984
# start, end:73984, 74048
# start, end:74048, 74112
# start, end:74112, 74176
# start, end:74176, 74240
# start, end:74240, 74304
# start, end:74304, 74368
# start, end:74368, 74432
# start, end:74432, 74496
# start, end:74496, 74560
# start, end:74560, 74624
# start, end:74624, 74688
# start, end:74688, 74752
# start, end:74752, 74816
# start, end:74816, 74880
# start, end:74880, 74944
# start, end:74944, 75008
# start, end:75008, 75072
# start, end:75072, 75136
# start, end:75136, 75200
# start, end:75200, 75264
# start, end:75264, 75328
# start, end:75328, 75392
# start, end:75392, 75456
# start, end:75456, 75520
# start, end:75520, 75584
# start, end:75584, 75648
# start, end:75648, 75712
# start, end:75712, 75776
# start, end:75776, 75840
# start, end:75840, 75904
# start, end:75904, 75968
# start, end:75968, 76032
# start, end:76032, 76096
# start, end:76096, 76160
# start, end:76160, 76224
# start, end:76224, 76288
# start, end:76288, 76352
# start, end:76352, 76416
# start, end:76416, 76480
# start, end:76480, 76544
# start, end:76544, 76608
# start, end:76608, 76672
# start, end:76672, 76736
# start, end:76736, 76800
# Phase: train | Epoch: 0 | Count: 1200 \ Start Time: 00:42:36 | Loss: 293
# start, end:76800, 76864
# start, end:76864, 76928
# start, end:76928, 76992
# start, end:76992, 77056
# start, end:77056, 77120
# start, end:77120, 77184
# start, end:77184, 77248
# start, end:77248, 77312
# start, end:77312, 77376
# start, end:77376, 77440
# start, end:77440, 77504
# start, end:77504, 77568
# start, end:77568, 77632
# start, end:77632, 77696
# start, end:77696, 77760
# start, end:77760, 77824
# start, end:77824, 77888
# start, end:77888, 77952
# start, end:77952, 78016
# start, end:78016, 78080
# start, end:78080, 78144
# start, end:78144, 78208
# start, end:78208, 78272
# start, end:78272, 78336
# start, end:78336, 78400
# start, end:78400, 78464
# start, end:78464, 78528
# start, end:78528, 78592
# start, end:78592, 78656
# start, end:78656, 78720
# start, end:78720, 78784
# start, end:78784, 78848
# start, end:78848, 78912
# start, end:78912, 78976
# start, end:78976, 79040
# start, end:79040, 79104
# start, end:79104, 79168
# start, end:79168, 79232
# start, end:79232, 79296
# start, end:79296, 79360
# start, end:79360, 79424
# start, end:79424, 79488
# start, end:79488, 79552
# start, end:79552, 79616
# start, end:79616, 79680
# start, end:79680, 79744
# start, end:79744, 79808
# start, end:79808, 79872
# start, end:79872, 79936
# start, end:79936, 80000
# start, end:80000, 80064
# start, end:80064, 80128
# start, end:80128, 80192
# start, end:80192, 80256
# start, end:80256, 80320
# start, end:80320, 80384
# start, end:80384, 80448
# start, end:80448, 80512
# start, end:80512, 80576
# start, end:80576, 80640
# start, end:80640, 80704
# start, end:80704, 80768
# start, end:80768, 80832
# start, end:80832, 80896
# start, end:80896, 80960
# start, end:80960, 81024
# start, end:81024, 81088
# start, end:81088, 81152
# start, end:81152, 81216
# start, end:81216, 81280
# start, end:81280, 81344
# start, end:81344, 81408
# start, end:81408, 81472
# start, end:81472, 81536
# start, end:81536, 81600
# start, end:81600, 81664
# start, end:81664, 81728
# start, end:81728, 81792
# start, end:81792, 81856
# start, end:81856, 81920
# start, end:81920, 81984
# start, end:81984, 82048
# start, end:82048, 82112
# start, end:82112, 82176
# start, end:82176, 82240
# start, end:82240, 82304
# start, end:82304, 82368
# start, end:82368, 82432
# start, end:82432, 82496
# start, end:82496, 82560
# start, end:82560, 82624
# start, end:82624, 82688
# start, end:82688, 82752
# start, end:82752, 82816
# start, end:82816, 82880
# start, end:82880, 82944
# start, end:82944, 83008
# start, end:83008, 83072
# start, end:83072, 83136
# start, end:83136, 83200
# Phase: train | Epoch: 0 | Count: 1300 \ Start Time: 00:43:22 | Loss: 292
# start, end:83200, 83264
# start, end:83264, 83328
# start, end:83328, 83392
# start, end:83392, 83456
# start, end:83456, 83520
# start, end:83520, 83584
# start, end:83584, 83648
# start, end:83648, 83712
# start, end:83712, 83776
# start, end:83776, 83840
# start, end:83840, 83904
# start, end:83904, 83968
# start, end:83968, 84032
# start, end:84032, 84096
# start, end:84096, 84160
# start, end:84160, 84224
# start, end:84224, 84288
# start, end:84288, 84352
# start, end:84352, 84416
# start, end:84416, 84480
# start, end:84480, 84544
# start, end:84544, 84608
# start, end:84608, 84672
# start, end:84672, 84736
# start, end:84736, 84800
# start, end:84800, 84864
# start, end:84864, 84928
# start, end:84928, 84992
# start, end:84992, 85056
# start, end:85056, 85120
# start, end:85120, 85184
# start, end:85184, 85248
# start, end:85248, 85312
# start, end:85312, 85376
# start, end:85376, 85440
# start, end:85440, 85504
# start, end:85504, 85568
# start, end:85568, 85632
# start, end:85632, 85696
# start, end:85696, 85760
# start, end:85760, 85824
# start, end:85824, 85888
# start, end:85888, 85952
# start, end:85952, 86016
# start, end:86016, 86080
# start, end:86080, 86144
# start, end:86144, 86208
# start, end:86208, 86272
# start, end:86272, 86336
# start, end:86336, 86400
# start, end:86400, 86464
# start, end:86464, 86528
# start, end:86528, 86592
# start, end:86592, 86656
# start, end:86656, 86720
# start, end:86720, 86784
# start, end:86784, 86848
# start, end:86848, 86912
# start, end:86912, 86976
# start, end:86976, 87040
# start, end:87040, 87104
# start, end:87104, 87168
# start, end:87168, 87232
# start, end:87232, 87296
# start, end:87296, 87360
# start, end:87360, 87424
# start, end:87424, 87488
# start, end:87488, 87552
# start, end:87552, 87616
# start, end:87616, 87680
# start, end:87680, 87744
# start, end:87744, 87808
# start, end:87808, 87872
# start, end:87872, 87936
# start, end:87936, 88000
# start, end:88000, 88064
# start, end:88064, 88128
# start, end:88128, 88192
# start, end:88192, 88256
# start, end:88256, 88320
# start, end:88320, 88384
# start, end:88384, 88448
# start, end:88448, 88512
# start, end:88512, 88576
# start, end:88576, 88640
# start, end:88640, 88704
# start, end:88704, 88768
# start, end:88768, 88832
# start, end:88832, 88896
# start, end:88896, 88960
# start, end:88960, 89024
# start, end:89024, 89088
# start, end:89088, 89152
# start, end:89152, 89216
# start, end:89216, 89280
# start, end:89280, 89344
# start, end:89344, 89408
# start, end:89408, 89472
# start, end:89472, 89536
# start, end:89536, 89600
# Phase: train | Epoch: 0 | Count: 1400 \ Start Time: 00:44:04 | Loss: 290
# start, end:89600, 89664
# start, end:89664, 89728
# start, end:89728, 89792
# start, end:89792, 89856
# start, end:89856, 89920
# start, end:89920, 89984
# start, end:89984, 90048
# start, end:90048, 90112
# start, end:90112, 90176
# start, end:90176, 90240
# start, end:90240, 90304
# start, end:90304, 90368
# start, end:90368, 90432
# start, end:90432, 90496
# start, end:90496, 90560
# start, end:90560, 90624
# start, end:90624, 90688
# start, end:90688, 90752
# start, end:90752, 90816
# start, end:90816, 90880
# start, end:90880, 90944
# start, end:90944, 91008
# start, end:91008, 91072
# start, end:91072, 91136
# start, end:91136, 91200
# start, end:91200, 91264
# start, end:91264, 91328
# start, end:91328, 91392
# start, end:91392, 91456
# start, end:91456, 91520
# start, end:91520, 91584
# start, end:91584, 91648
# start, end:91648, 91712
# start, end:91712, 91776
# start, end:91776, 91840
# start, end:91840, 91904
# start, end:91904, 91968
# start, end:91968, 92032
# start, end:92032, 92096
# start, end:92096, 92160
# start, end:92160, 92224
# start, end:92224, 92288
# start, end:92288, 92352
# start, end:92352, 92416
# start, end:92416, 92480
# start, end:92480, 92544
# start, end:92544, 92608
# start, end:92608, 92672
# start, end:92672, 92736
# start, end:92736, 92800
# start, end:92800, 92864
# start, end:92864, 92928
# start, end:92928, 92992
# start, end:92992, 93056
# start, end:93056, 93120
# start, end:93120, 93184
# start, end:93184, 93248
# start, end:93248, 93312
# start, end:93312, 93376
# start, end:93376, 93440
# start, end:93440, 93504
# start, end:93504, 93568
# start, end:93568, 93632
# start, end:93632, 93696
# start, end:93696, 93760
# start, end:93760, 93824
# start, end:93824, 93888
# start, end:93888, 93952
# start, end:93952, 94016
# start, end:94016, 94080
# start, end:94080, 94144
# start, end:94144, 94208
# start, end:94208, 94272
# start, end:94272, 94336
# start, end:94336, 94400
# start, end:94400, 94464
# start, end:94464, 94528
# start, end:94528, 94592
# start, end:94592, 94656
# start, end:94656, 94720
# start, end:94720, 94784
# start, end:94784, 94848
# start, end:94848, 94912
# start, end:94912, 94976
# start, end:94976, 95040
# start, end:95040, 95104
# start, end:95104, 95168
# start, end:95168, 95232
# start, end:95232, 95296
# start, end:95296, 95360
# start, end:95360, 95424
# start, end:95424, 95488
# start, end:95488, 95552
# start, end:95552, 95616
# start, end:95616, 95680
# start, end:95680, 95744
# start, end:95744, 95808
# start, end:95808, 95872
# start, end:95872, 95936
# start, end:95936, 96000
# Phase: train | Epoch: 0 | Count: 1500 \ Start Time: 00:44:50 | Loss: 287
# start, end:96000, 96064
# start, end:96064, 96128
# start, end:96128, 96192
# start, end:96192, 96256
# start, end:96256, 96320
# start, end:96320, 96384
# start, end:96384, 96448
# start, end:96448, 96512
# start, end:96512, 96576
# start, end:96576, 96640
# start, end:96640, 96704
# start, end:96704, 96768
# start, end:96768, 96832
# start, end:96832, 96896
# start, end:96896, 96960
# start, end:96960, 97024
# start, end:97024, 97088
# start, end:97088, 97152
# start, end:97152, 97216
# start, end:97216, 97280
# start, end:97280, 97344
# start, end:97344, 97408
# start, end:97408, 97472
# start, end:97472, 97536
# start, end:97536, 97600
# start, end:97600, 97664
# start, end:97664, 97728
# start, end:97728, 97792
# start, end:97792, 97856
# start, end:97856, 97920
# start, end:97920, 97984
# start, end:97984, 98048
# start, end:98048, 98112
# start, end:98112, 98176
# start, end:98176, 98240
# start, end:98240, 98304
# start, end:98304, 98368
# start, end:98368, 98432
# start, end:98432, 98496
# start, end:98496, 98560
# start, end:0, 63
# start, end:63, 127
# start, end:127, 191
# start, end:191, 255
# start, end:255, 319
# start, end:319, 383
# start, end:383, 447
# start, end:447, 511
# start, end:511, 575
# start, end:575, 639
# start, end:639, 703
# start, end:703, 767
# start, end:767, 831
# start, end:831, 895
# start, end:895, 959
# start, end:959, 1023
# start, end:1023, 1087
# start, end:1087, 1151
# start, end:1151, 1215
# start, end:1215, 1279
# start, end:1279, 1343
# start, end:1343, 1407
# start, end:1407, 1471
# start, end:1471, 1535
# start, end:1535, 1599
# start, end:1599, 1663
# start, end:1663, 1727
# start, end:1727, 1791
# start, end:1791, 1855
# start, end:1855, 1919
# start, end:1919, 1983
# start, end:1983, 2047
# start, end:2047, 2111
# start, end:2111, 2175
# start, end:2175, 2239
# start, end:2239, 2303
# start, end:2303, 2367
# start, end:2367, 2431
# start, end:2431, 2495
# start, end:2495, 2559
# start, end:2559, 2623
# start, end:2623, 2687
# start, end:2687, 2751
# start, end:2751, 2815
# start, end:2815, 2879
# start, end:2879, 2943
# start, end:2943, 3007
# start, end:3007, 3071
# start, end:3071, 3135
# start, end:3135, 3199
# start, end:3199, 3263
# start, end:3263, 3327
# start, end:3327, 3391
# start, end:3391, 3455
# start, end:3455, 3519
# start, end:3519, 3583
# start, end:3583, 3647
# start, end:3647, 3711
# start, end:3711, 3775
# start, end:3775, 3839
# Phase: train | Epoch: 1 | Count: 1600 \ Start Time: 00:45:35 | Loss: 285
# start, end:3839, 3903
# start, end:3903, 3967
# start, end:3967, 4031
# start, end:4031, 4095
# start, end:4095, 4159
# start, end:4159, 4223
# start, end:4223, 4287
# start, end:4287, 4351
# start, end:4351, 4415
# start, end:4415, 4479
# start, end:4479, 4543
# start, end:4543, 4607
# start, end:4607, 4671
# start, end:4671, 4735
# start, end:4735, 4799
# start, end:4799, 4863
# start, end:4863, 4927
# start, end:4927, 4991
# start, end:4991, 5055
# start, end:5055, 5119
# start, end:5119, 5183
# start, end:5183, 5247
# start, end:5247, 5311
# start, end:5311, 5375
# start, end:5375, 5439
# start, end:5439, 5503
# start, end:5503, 5567
# start, end:5567, 5631
# start, end:5631, 5695
# start, end:5695, 5759
# start, end:5759, 5823
# start, end:5823, 5887
# start, end:5887, 5951
# start, end:5951, 6015
# start, end:6015, 6079
# start, end:6079, 6143
# start, end:6143, 6207
# start, end:6207, 6271
# start, end:6271, 6335
# start, end:6335, 6399
# start, end:6399, 6463
# start, end:6463, 6527
# start, end:6527, 6591
# start, end:6591, 6655
# start, end:6655, 6719
# start, end:6719, 6783
# start, end:6783, 6847
# start, end:6847, 6911
# start, end:6911, 6975
# start, end:6975, 7039
# start, end:7039, 7103
# start, end:7103, 7167
# start, end:7167, 7231
# start, end:7231, 7295
# start, end:7295, 7359
# start, end:7359, 7423
# start, end:7423, 7487
# start, end:7487, 7551
# start, end:7551, 7615
# start, end:7615, 7679
# start, end:7679, 7743
# start, end:7743, 7807
# start, end:7807, 7871
# start, end:7871, 7935
# start, end:7935, 7999
# start, end:7999, 8063
# start, end:8063, 8127
# start, end:8127, 8191
# start, end:8191, 8255
# start, end:8255, 8319
# start, end:8319, 8383
# start, end:8383, 8447
# start, end:8447, 8511
# start, end:8511, 8575
# start, end:8575, 8639
# start, end:8639, 8703
# start, end:8703, 8767
# start, end:8767, 8831
# start, end:8831, 8895
# start, end:8895, 8959
# start, end:8959, 9023
# start, end:9023, 9087
# start, end:9087, 9151
# start, end:9151, 9215
# start, end:9215, 9279
# start, end:9279, 9343
# start, end:9343, 9407
# start, end:9407, 9471
# start, end:9471, 9535
# start, end:9535, 9599
# start, end:9599, 9663
# start, end:9663, 9727
# start, end:9727, 9791
# start, end:9791, 9855
# start, end:9855, 9919
# start, end:9919, 9983
# start, end:9983, 10047
# start, end:10047, 10111
# start, end:10111, 10175
# start, end:10175, 10239
# Phase: train | Epoch: 1 | Count: 1700 \ Start Time: 00:46:19 | Loss: 283
# start, end:10239, 10303
# start, end:10303, 10367
# start, end:10367, 10431
# start, end:10431, 10495
# start, end:10495, 10559
# start, end:10559, 10623
# start, end:10623, 10687
# start, end:10687, 10751
# start, end:10751, 10815
# start, end:10815, 10879
# start, end:10879, 10943
# start, end:10943, 11007
# start, end:11007, 11071
# start, end:11071, 11135
# start, end:11135, 11199
# start, end:11199, 11263
# start, end:11263, 11327
# start, end:11327, 11391
# start, end:11391, 11455
# start, end:11455, 11519
# start, end:11519, 11583
# start, end:11583, 11647
# start, end:11647, 11711
# start, end:11711, 11775
# start, end:11775, 11839
# start, end:11839, 11903
# start, end:11903, 11967
# start, end:11967, 12031
# start, end:12031, 12095
# start, end:12095, 12159
# start, end:12159, 12223
# start, end:12223, 12287
# start, end:12287, 12351
# start, end:12351, 12415
# start, end:12415, 12479
# start, end:12479, 12543
# start, end:12543, 12607
# start, end:12607, 12671
# start, end:12671, 12735
# start, end:12735, 12799
# start, end:12799, 12863
# start, end:12863, 12927
# start, end:12927, 12991
# start, end:12991, 13055
# start, end:13055, 13119
# start, end:13119, 13183
# start, end:13183, 13247
# start, end:13247, 13311
# start, end:13311, 13375
# start, end:13375, 13439
# start, end:13439, 13503
# start, end:13503, 13567
# start, end:13567, 13631
# start, end:13631, 13695
# start, end:13695, 13759
# start, end:13759, 13823
# start, end:13823, 13887
# start, end:13887, 13951
# start, end:13951, 14015
# start, end:14015, 14079
# start, end:14079, 14143
# start, end:14143, 14207
# start, end:14207, 14271
# start, end:14271, 14335
# start, end:14335, 14399
# start, end:14399, 14463
# start, end:14463, 14527
# start, end:14527, 14591
# start, end:14591, 14655
# start, end:14655, 14719
# start, end:14719, 14783
# start, end:14783, 14847
# start, end:14847, 14911
# start, end:14911, 14975
# start, end:14975, 15039
# start, end:15039, 15103
# start, end:15103, 15167
# start, end:15167, 15231
# start, end:15231, 15295
# start, end:15295, 15359
# start, end:15359, 15423
# start, end:15423, 15487
# start, end:15487, 15551
# start, end:15551, 15615
# start, end:15615, 15679
# start, end:15679, 15743
# start, end:15743, 15807
# start, end:15807, 15871
# start, end:15871, 15935
# start, end:15935, 15999
# start, end:15999, 16063
# start, end:16063, 16127
# start, end:16127, 16191
# start, end:16191, 16255
# start, end:16255, 16319
# start, end:16319, 16383
# start, end:16383, 16447
# start, end:16447, 16511
# start, end:16511, 16575
# start, end:16575, 16639
# Phase: train | Epoch: 1 | Count: 1800 \ Start Time: 00:47:02 | Loss: 283
# start, end:16639, 16703
# start, end:16703, 16767
# start, end:16767, 16831
# start, end:16831, 16895
# start, end:16895, 16959
# start, end:16959, 17023
# start, end:17023, 17087
# start, end:17087, 17151
# start, end:17151, 17215
# start, end:17215, 17279
# start, end:17279, 17343
# start, end:17343, 17407
# start, end:17407, 17471
# start, end:17471, 17535
# start, end:17535, 17599
# start, end:17599, 17663
# start, end:17663, 17727
# start, end:17727, 17791
# start, end:17791, 17855
# start, end:17855, 17919
# start, end:17919, 17983
# start, end:17983, 18047
# start, end:18047, 18111
# start, end:18111, 18175
# start, end:18175, 18239
# start, end:18239, 18303
# start, end:18303, 18367
# start, end:18367, 18431
# start, end:18431, 18495
# start, end:18495, 18559
# start, end:18559, 18623
# start, end:18623, 18687
# start, end:18687, 18751
# start, end:18751, 18815
# start, end:18815, 18879
# start, end:18879, 18943
# start, end:18943, 19007
# start, end:19007, 19071
# start, end:19071, 19135
# start, end:19135, 19199
# start, end:19199, 19263
# start, end:19263, 19327
# start, end:19327, 19391
# start, end:19391, 19455
# start, end:19455, 19519
# start, end:19519, 19583
# start, end:19583, 19647
# start, end:19647, 19711
# start, end:19711, 19775
# start, end:19775, 19839
# start, end:19839, 19903
# start, end:19903, 19967
# start, end:19967, 20031
# start, end:20031, 20095
# start, end:20095, 20159
# start, end:20159, 20223
# start, end:20223, 20287
# start, end:20287, 20351
# start, end:20351, 20415
# start, end:20415, 20479
# start, end:20479, 20543
# start, end:20543, 20607
# start, end:20607, 20671
# start, end:20671, 20735
# start, end:20735, 20799
# start, end:20799, 20863
# start, end:20863, 20927
# start, end:20927, 20991
# start, end:20991, 21055
# start, end:21055, 21119
# start, end:21119, 21183
# start, end:21183, 21247
# start, end:21247, 21311
# start, end:21311, 21375
# start, end:21375, 21439
# start, end:21439, 21503
# start, end:21503, 21567
# start, end:21567, 21631
# start, end:21631, 21695
# start, end:21695, 21759
# start, end:21759, 21823
# start, end:21823, 21887
# start, end:21887, 21951
# start, end:21951, 22015
# start, end:22015, 22079
# start, end:22079, 22143
# start, end:22143, 22207
# start, end:22207, 22271
# start, end:22271, 22335
# start, end:22335, 22399
# start, end:22399, 22463
# start, end:22463, 22527
# start, end:22527, 22591
# start, end:22591, 22655
# start, end:22655, 22719
# start, end:22719, 22783
# start, end:22783, 22847
# start, end:22847, 22911
# start, end:22911, 22975
# start, end:22975, 23039
# Phase: train | Epoch: 1 | Count: 1900 \ Start Time: 00:47:52 | Loss: 280
# start, end:23039, 23103
# start, end:23103, 23167
# start, end:23167, 23231
# start, end:23231, 23295
# start, end:23295, 23359
# start, end:23359, 23423
# start, end:23423, 23487
# start, end:23487, 23551
# start, end:23551, 23615
# start, end:23615, 23679
# start, end:23679, 23743
# start, end:23743, 23807
# start, end:23807, 23871
# start, end:23871, 23935
# start, end:23935, 23999
# start, end:23999, 24063
# start, end:24063, 24127
# start, end:24127, 24191
# start, end:24191, 24255
# start, end:24255, 24319
# start, end:24319, 24383
# start, end:24383, 24447
# start, end:24447, 24511
# start, end:24511, 24575
# start, end:24575, 24639
# start, end:24639, 24703
# start, end:24703, 24767
# start, end:24767, 24831
# start, end:24831, 24895
# start, end:24895, 24959
# start, end:24959, 25023
# start, end:25023, 25087
# start, end:25087, 25151
# start, end:25151, 25215
# start, end:25215, 25279
# start, end:25279, 25343
# start, end:25343, 25407
# start, end:25407, 25471
# start, end:25471, 25535
# start, end:25535, 25599
# start, end:25599, 25663
# start, end:25663, 25727
# start, end:25727, 25791
# start, end:25791, 25855
# start, end:25855, 25919
# start, end:25919, 25983
# start, end:25983, 26047
# start, end:26047, 26111
# start, end:26111, 26175
# start, end:26175, 26239
# start, end:26239, 26303
# start, end:26303, 26367
# start, end:26367, 26431
# start, end:26431, 26495
# start, end:26495, 26559
# start, end:26559, 26623
# start, end:26623, 26687
# start, end:26687, 26751
# start, end:26751, 26815
# start, end:26815, 26879
# start, end:26879, 26943
# ...
# start, end:62135, 62199
# start, end:62199, 62263
# start, end:62263, 62327
# start, end:62327, 62391
# start, end:62391, 62455
# start, end:62455, 62519
# start, end:62519, 62583
# start, end:62583, 62647
# start, end:62647, 62711
# start, end:62711, 62775
# start, end:62775, 62839
# start, end:62839, 62903
# start, end:62903, 62967
# start, end:62967, 63031
# start, end:63031, 63095
# start, end:63095, 63159
# start, end:63159, 63223
# start, end:63223, 63287
# start, end:63287, 63351
# start, end:63351, 63415
# start, end:63415, 63479
# start, end:63479, 63543
# start, end:63543, 63607
# start, end:63607, 63671
# start, end:63671, 63735
# start, end:63735, 63799
# start, end:63799, 63863
# start, end:63863, 63927
# start, end:63927, 63991
# start, end:63991, 64055
# start, end:64055, 64119
# start, end:64119, 64183
# start, end:64183, 64247
# start, end:64247, 64311
# start, end:64311, 64375
# start, end:64375, 64439
# start, end:64439, 64503
# start, end:64503, 64567
# start, end:64567, 64631
# start, end:64631, 64695
# start, end:64695, 64759
# start, end:64759, 64823
# start, end:64823, 64887
# start, end:64887, 64951
# start, end:64951, 65015
# start, end:65015, 65079
# start, end:65079, 65143
# start, end:65143, 65207
# start, end:65207, 65271
# start, end:65271, 65335
# start, end:65335, 65399
# start, end:65399, 65463
# start, end:65463, 65527
# start, end:65527, 65591
# start, end:65591, 65655
# start, end:65655, 65719
# start, end:65719, 65783
# start, end:65783, 65847
# start, end:65847, 65911
# start, end:65911, 65975
# start, end:65975, 66039
# start, end:66039, 66103
# start, end:66103, 66167
# start, end:66167, 66231
# start, end:66231, 66295
# start, end:66295, 66359
# start, end:66359, 66423
# start, end:66423, 66487
# start, end:66487, 66551
# Phase: train | Epoch: 9 | Count: 14900 \ Start Time: 02:16:13 | Loss: 237
# start, end:66551, 66615
# start, end:66615, 66679
# start, end:66679, 66743
# start, end:66743, 66807
# start, end:66807, 66871
# start, end:66871, 66935
# start, end:66935, 66999
# start, end:66999, 67063
# start, end:67063, 67127
# start, end:67127, 67191
# start, end:67191, 67255
# start, end:67255, 67319
# start, end:67319, 67383
# start, end:67383, 67447
# start, end:67447, 67511
# start, end:67511, 67575
# start, end:67575, 67639
# start, end:67639, 67703
# start, end:67703, 67767
# start, end:67767, 67831
# start, end:67831, 67895
# start, end:67895, 67959
# start, end:67959, 68023
# start, end:68023, 68087
# start, end:68087, 68151
# start, end:68151, 68215
# start, end:68215, 68279
# start, end:68279, 68343
# start, end:68343, 68407
# start, end:68407, 68471
# start, end:68471, 68535
# start, end:68535, 68599
# start, end:68599, 68663
# start, end:68663, 68727
# start, end:68727, 68791
# start, end:68791, 68855
# start, end:68855, 68919
# start, end:68919, 68983
# start, end:68983, 69047
# start, end:69047, 69111
# start, end:69111, 69175
# start, end:69175, 69239
# start, end:69239, 69303
# start, end:69303, 69367
# start, end:69367, 69431
# start, end:69431, 69495
# start, end:69495, 69559
# start, end:69559, 69623
# start, end:69623, 69687
# start, end:69687, 69751
# start, end:69751, 69815
# start, end:69815, 69879
# start, end:69879, 69943
# start, end:69943, 70007
# start, end:70007, 70071
# start, end:70071, 70135
# start, end:70135, 70199
# start, end:70199, 70263
# start, end:70263, 70327
# start, end:70327, 70391
# start, end:70391, 70455
# start, end:70455, 70519
# start, end:70519, 70583
# start, end:70583, 70647
# start, end:70647, 70711
# start, end:70711, 70775
# start, end:70775, 70839
# start, end:70839, 70903
# start, end:70903, 70967
# start, end:70967, 71031
# start, end:71031, 71095
# start, end:71095, 71159
# start, end:71159, 71223
# start, end:71223, 71287
# start, end:71287, 71351
# start, end:71351, 71415
# start, end:71415, 71479
# start, end:71479, 71543
# start, end:71543, 71607
# start, end:71607, 71671
# start, end:71671, 71735
# start, end:71735, 71799
# start, end:71799, 71863
# start, end:71863, 71927
# start, end:71927, 71991
# start, end:71991, 72055
# start, end:72055, 72119
# start, end:72119, 72183
# start, end:72183, 72247
# start, end:72247, 72311
# start, end:72311, 72375
# start, end:72375, 72439
# start, end:72439, 72503
# start, end:72503, 72567
# start, end:72567, 72631
# start, end:72631, 72695
# start, end:72695, 72759
# start, end:72759, 72823
# start, end:72823, 72887
# start, end:72887, 72951
# Phase: train | Epoch: 9 | Count: 15000 \ Start Time: 02:16:52 | Loss: 238
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15000_test_0.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15000_test_1.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15000_test_2.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15000_test_3.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15000_test_4.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15000_test_5.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15000_test_6.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15000_test_7.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15000_test_8.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15000_test_9.png
# start, end:72951, 73015
# start, end:73015, 73079
# start, end:73079, 73143
# start, end:73143, 73207
# start, end:73207, 73271
# start, end:73271, 73335
# start, end:73335, 73399
# start, end:73399, 73463
# start, end:73463, 73527
# start, end:73527, 73591
# start, end:73591, 73655
# start, end:73655, 73719
# start, end:73719, 73783
# start, end:73783, 73847
# start, end:73847, 73911
# start, end:73911, 73975
# start, end:73975, 74039
# start, end:74039, 74103
# start, end:74103, 74167
# start, end:74167, 74231
# start, end:74231, 74295
# start, end:74295, 74359
# start, end:74359, 74423
# start, end:74423, 74487
# start, end:74487, 74551
# start, end:74551, 74615
# start, end:74615, 74679
# start, end:74679, 74743
# start, end:74743, 74807
# start, end:74807, 74871
# start, end:74871, 74935
# start, end:74935, 74999
# start, end:74999, 75063
# start, end:75063, 75127
# start, end:75127, 75191
# start, end:75191, 75255
# start, end:75255, 75319
# start, end:75319, 75383
# start, end:75383, 75447
# start, end:75447, 75511
# start, end:75511, 75575
# start, end:75575, 75639
# start, end:75639, 75703
# start, end:75703, 75767
# start, end:75767, 75831
# start, end:75831, 75895
# start, end:75895, 75959
# start, end:75959, 76023
# start, end:76023, 76087
# start, end:76087, 76151
# start, end:76151, 76215
# start, end:76215, 76279
# start, end:76279, 76343
# start, end:76343, 76407
# start, end:76407, 76471
# start, end:76471, 76535
# start, end:76535, 76599
# start, end:76599, 76663
# start, end:76663, 76727
# start, end:76727, 76791
# start, end:76791, 76855
# start, end:76855, 76919
# start, end:76919, 76983
# start, end:76983, 77047
# start, end:77047, 77111
# start, end:77111, 77175
# start, end:77175, 77239
# start, end:77239, 77303
# start, end:77303, 77367
# start, end:77367, 77431
# start, end:77431, 77495
# start, end:77495, 77559
# start, end:77559, 77623
# start, end:77623, 77687
# start, end:77687, 77751
# start, end:77751, 77815
# start, end:77815, 77879
# start, end:77879, 77943
# start, end:77943, 78007
# start, end:78007, 78071
# start, end:78071, 78135
# start, end:78135, 78199
# start, end:78199, 78263
# start, end:78263, 78327
# start, end:78327, 78391
# start, end:78391, 78455
# start, end:78455, 78519
# start, end:78519, 78583
# start, end:78583, 78647
# start, end:78647, 78711
# start, end:78711, 78775
# start, end:78775, 78839
# start, end:78839, 78903
# start, end:78903, 78967
# start, end:78967, 79031
# start, end:79031, 79095
# start, end:79095, 79159
# start, end:79159, 79223
# start, end:79223, 79287
# start, end:79287, 79351
# Phase: train | Epoch: 9 | Count: 15100 \ Start Time: 02:17:34 | Loss: 238
# start, end:79351, 79415
# start, end:79415, 79479
# start, end:79479, 79543
# start, end:79543, 79607
# start, end:79607, 79671
# start, end:79671, 79735
# start, end:79735, 79799
# start, end:79799, 79863
# start, end:79863, 79927
# start, end:79927, 79991
# start, end:79991, 80055
# start, end:80055, 80119
# start, end:80119, 80183
# start, end:80183, 80247
# start, end:80247, 80311
# start, end:80311, 80375
# start, end:80375, 80439
# start, end:80439, 80503
# start, end:80503, 80567
# start, end:80567, 80631
# start, end:80631, 80695
# start, end:80695, 80759
# start, end:80759, 80823
# start, end:80823, 80887
# start, end:80887, 80951
# start, end:80951, 81015
# start, end:81015, 81079
# start, end:81079, 81143
# start, end:81143, 81207
# start, end:81207, 81271
# start, end:81271, 81335
# start, end:81335, 81399
# start, end:81399, 81463
# start, end:81463, 81527
# start, end:81527, 81591
# start, end:81591, 81655
# start, end:81655, 81719
# start, end:81719, 81783
# start, end:81783, 81847
# start, end:81847, 81911
# start, end:81911, 81975
# start, end:81975, 82039
# start, end:82039, 82103
# start, end:82103, 82167
# start, end:82167, 82231
# start, end:82231, 82295
# start, end:82295, 82359
# start, end:82359, 82423
# start, end:82423, 82487
# start, end:82487, 82551
# start, end:82551, 82615
# start, end:82615, 82679
# start, end:82679, 82743
# start, end:82743, 82807
# start, end:82807, 82871
# start, end:82871, 82935
# start, end:82935, 82999
# start, end:82999, 83063
# start, end:83063, 83127
# start, end:83127, 83191
# start, end:83191, 83255
# start, end:83255, 83319
# start, end:83319, 83383
# start, end:83383, 83447
# start, end:83447, 83511
# start, end:83511, 83575
# start, end:83575, 83639
# start, end:83639, 83703
# start, end:83703, 83767
# start, end:83767, 83831
# start, end:83831, 83895
# start, end:83895, 83959
# start, end:83959, 84023
# start, end:84023, 84087
# start, end:84087, 84151
# start, end:84151, 84215
# start, end:84215, 84279
# start, end:84279, 84343
# start, end:84343, 84407
# start, end:84407, 84471
# start, end:84471, 84535
# start, end:84535, 84599
# start, end:84599, 84663
# start, end:84663, 84727
# start, end:84727, 84791
# start, end:84791, 84855
# start, end:84855, 84919
# start, end:84919, 84983
# start, end:84983, 85047
# start, end:85047, 85111
# start, end:85111, 85175
# start, end:85175, 85239
# start, end:85239, 85303
# start, end:85303, 85367
# start, end:85367, 85431
# start, end:85431, 85495
# start, end:85495, 85559
# start, end:85559, 85623
# start, end:85623, 85687
# start, end:85687, 85751
# Phase: train | Epoch: 9 | Count: 15200 \ Start Time: 02:18:13 | Loss: 238
# start, end:85751, 85815
# start, end:85815, 85879
# start, end:85879, 85943
# start, end:85943, 86007
# start, end:86007, 86071
# start, end:86071, 86135
# start, end:86135, 86199
# start, end:86199, 86263
# start, end:86263, 86327
# start, end:86327, 86391
# start, end:86391, 86455
# start, end:86455, 86519
# start, end:86519, 86583
# start, end:86583, 86647
# start, end:86647, 86711
# start, end:86711, 86775
# start, end:86775, 86839
# start, end:86839, 86903
# start, end:86903, 86967
# start, end:86967, 87031
# start, end:87031, 87095
# start, end:87095, 87159
# start, end:87159, 87223
# start, end:87223, 87287
# start, end:87287, 87351
# start, end:87351, 87415
# start, end:87415, 87479
# start, end:87479, 87543
# start, end:87543, 87607
# start, end:87607, 87671
# start, end:87671, 87735
# start, end:87735, 87799
# start, end:87799, 87863
# start, end:87863, 87927
# start, end:87927, 87991
# start, end:87991, 88055
# start, end:88055, 88119
# start, end:88119, 88183
# start, end:88183, 88247
# start, end:88247, 88311
# start, end:88311, 88375
# start, end:88375, 88439
# start, end:88439, 88503
# start, end:88503, 88567
# start, end:88567, 88631
# start, end:88631, 88695
# start, end:88695, 88759
# start, end:88759, 88823
# start, end:88823, 88887
# start, end:88887, 88951
# start, end:88951, 89015
# start, end:89015, 89079
# start, end:89079, 89143
# start, end:89143, 89207
# start, end:89207, 89271
# start, end:89271, 89335
# start, end:89335, 89399
# start, end:89399, 89463
# start, end:89463, 89527
# start, end:89527, 89591
# start, end:89591, 89655
# start, end:89655, 89719
# start, end:89719, 89783
# start, end:89783, 89847
# start, end:89847, 89911
# start, end:89911, 89975
# start, end:89975, 90039
# start, end:90039, 90103
# start, end:90103, 90167
# start, end:90167, 90231
# start, end:90231, 90295
# start, end:90295, 90359
# start, end:90359, 90423
# start, end:90423, 90487
# start, end:90487, 90551
# start, end:90551, 90615
# start, end:90615, 90679
# start, end:90679, 90743
# start, end:90743, 90807
# start, end:90807, 90871
# start, end:90871, 90935
# start, end:90935, 90999
# start, end:90999, 91063
# start, end:91063, 91127
# start, end:91127, 91191
# start, end:91191, 91255
# start, end:91255, 91319
# start, end:91319, 91383
# start, end:91383, 91447
# start, end:91447, 91511
# start, end:91511, 91575
# start, end:91575, 91639
# start, end:91639, 91703
# start, end:91703, 91767
# start, end:91767, 91831
# start, end:91831, 91895
# start, end:91895, 91959
# start, end:91959, 92023
# start, end:92023, 92087
# start, end:92087, 92151
# Phase: train | Epoch: 9 | Count: 15300 \ Start Time: 02:18:51 | Loss: 237
# start, end:92151, 92215
# start, end:92215, 92279
# start, end:92279, 92343
# start, end:92343, 92407
# start, end:92407, 92471
# start, end:92471, 92535
# start, end:92535, 92599
# start, end:92599, 92663
# start, end:92663, 92727
# start, end:92727, 92791
# start, end:92791, 92855
# start, end:92855, 92919
# start, end:92919, 92983
# start, end:92983, 93047
# start, end:93047, 93111
# start, end:93111, 93175
# start, end:93175, 93239
# start, end:93239, 93303
# start, end:93303, 93367
# start, end:93367, 93431
# start, end:93431, 93495
# start, end:93495, 93559
# start, end:93559, 93623
# start, end:93623, 93687
# start, end:93687, 93751
# start, end:93751, 93815
# start, end:93815, 93879
# start, end:93879, 93943
# start, end:93943, 94007
# start, end:94007, 94071
# start, end:94071, 94135
# start, end:94135, 94199
# start, end:94199, 94263
# start, end:94263, 94327
# start, end:94327, 94391
# start, end:94391, 94455
# start, end:94455, 94519
# start, end:94519, 94583
# start, end:94583, 94647
# start, end:94647, 94711
# start, end:94711, 94775
# start, end:94775, 94839
# start, end:94839, 94903
# start, end:94903, 94967
# start, end:94967, 95031
# start, end:95031, 95095
# start, end:95095, 95159
# start, end:95159, 95223
# start, end:95223, 95287
# start, end:95287, 95351
# start, end:95351, 95415
# start, end:95415, 95479
# start, end:95479, 95543
# start, end:95543, 95607
# start, end:95607, 95671
# start, end:95671, 95735
# start, end:95735, 95799
# start, end:95799, 95863
# start, end:95863, 95927
# start, end:95927, 95991
# start, end:95991, 96055
# start, end:96055, 96119
# start, end:96119, 96183
# start, end:96183, 96247
# start, end:96247, 96311
# start, end:96311, 96375
# start, end:96375, 96439
# start, end:96439, 96503
# start, end:96503, 96567
# start, end:96567, 96631
# start, end:96631, 96695
# start, end:96695, 96759
# start, end:96759, 96823
# start, end:96823, 96887
# start, end:96887, 96951
# start, end:96951, 97015
# start, end:97015, 97079
# start, end:97079, 97143
# start, end:97143, 97207
# start, end:97207, 97271
# start, end:97271, 97335
# start, end:97335, 97399
# start, end:97399, 97463
# start, end:97463, 97527
# start, end:97527, 97591
# start, end:97591, 97655
# start, end:97655, 97719
# start, end:97719, 97783
# start, end:97783, 97847
# start, end:97847, 97911
# start, end:97911, 97975
# start, end:97975, 98039
# start, end:98039, 98103
# start, end:98103, 98167
# start, end:98167, 98231
# start, end:98231, 98295
# start, end:98295, 98359
# start, end:98359, 98423
# start, end:98423, 98487
# start, end:98487, 98551
# Phase: train | Epoch: 9 | Count: 15400 \ Start Time: 02:19:29 | Loss: 237
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15400_test_0.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15400_test_1.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15400_test_2.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15400_test_3.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15400_test_4.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15400_test_5.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15400_test_6.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15400_test_7.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15400_test_8.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_15400_test_9.png

# %%
# SAVING MODEL
model_path = os.path.join(root_path, "src", "save", category, '%s.pth' % category)
torch.save(model.state_dict(), model_path)

# %%
def load_model(T, A, B, batch_size, z_size, N, dec_size, enc_size, learning_rate, beta1, clip, path, category):
    torch.set_default_tensor_type('torch.FloatTensor')
    model = DRAW(T, A, B, batch_size, z_size, N, dec_size, enc_size, learning_rate, beta1, clip, path, category)
    root_path = os.getcwd().split('notebook')[0]
    model_path = os.path.join(root_path, "src", "save", category, '%s.pth' % category)
    model.load_state_dict(torch.load(model_path))
    
    return model

def load_weights(T, A, B, batch_size, z_size, N, dec_size, enc_size, learning_rate, beta1, clip, path, category):
    torch.set_default_tensor_type('torch.FloatTensor')
    model = DRAW(T, A, B, batch_size, z_size, N, dec_size, enc_size, learning_rate, beta1, clip, path, category)
    if USE_CUDA:
        model.cuda()
    root_path = os.getcwd().split('notebook')[0]
    weights_file = os.path.join(root_path, "src", "save", category, '%s_weights.tar' % category)
    state_dict = torch.load(weights_file, map_location=torch.device('cpu'))
    model.load_state_dict(state_dict)
    
    return model

# %%
# OPTION 1: LOADS MODEL WEIGHTS
model = load_weights(T, A, B, batch_size, z_size, N, dec_size, enc_size, learning_rate, beta1, clip, path, category)
model.eval()
# Out:
# DRAW(
#   (encoder): LSTMCell(306, 256)
#   (mu_linear): Linear(in_features=256, out_features=10, bias=True)
#   (sigma_linear): Linear(in_features=256, out_features=10, bias=True)
#   (decoder): LSTMCell(10, 256)
#   (dec_linear): Linear(in_features=256, out_features=5, bias=True)
#   (dec_w_linear): Linear(in_features=256, out_features=25, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
# OPTION2: LOADS MODEL
model = load_model(T, A, B, batch_size, z_size, N, dec_size, enc_size, learning_rate, beta1, clip, path, category)
model.eval()
# Out:
# DRAW(
#   (encoder): LSTMCell(306, 256)
#   (mu_linear): Linear(in_features=256, out_features=10, bias=True)
#   (sigma_linear): Linear(in_features=256, out_features=10, bias=True)
#   (decoder): LSTMCell(10, 256)
#   (dec_linear): Linear(in_features=256, out_features=5, bias=True)
#   (dec_w_linear): Linear(in_features=256, out_features=25, bias=True)
#   (sigmoid): Sigmoid()
# )

# %% [markdown]
# ## Testing

# %%
# OPTION 1: LOADS MODEL WEIGHTS
model = load_weights(T, A, B, batch_size, z_size, N, dec_size, enc_size, learning_rate, beta1, clip, path, category)
model.eval()
# Out:
# DRAW(
#   (encoder): LSTMCell(306, 256)
#   (mu_linear): Linear(in_features=256, out_features=10, bias=True)
#   (sigma_linear): Linear(in_features=256, out_features=10, bias=True)
#   (decoder): LSTMCell(10, 256)
#   (dec_linear): Linear(in_features=256, out_features=5, bias=True)
#   (dec_w_linear): Linear(in_features=256, out_features=25, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
# OPTION 2: LOADS MODEL
model = load_model(T, A, B, batch_size, z_size, N, dec_size, enc_size, learning_rate, beta1, clip, path, category)
model.eval()
# Out:
# DRAW(
#   (encoder): LSTMCell(306, 256)
#   (mu_linear): Linear(in_features=256, out_features=10, bias=True)
#   (sigma_linear): Linear(in_features=256, out_features=10, bias=True)
#   (decoder): LSTMCell(10, 256)
#   (dec_linear): Linear(in_features=256, out_features=5, bias=True)
#   (dec_w_linear): Linear(in_features=256, out_features=25, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
test()
# Out:
# testing...
# start, end:0, 64
# start, end:64, 128
# start, end:128, 192
# start, end:192, 256
# start, end:256, 320
# start, end:320, 384
# start, end:384, 448
# start, end:448, 512
# start, end:512, 576
# start, end:576, 640
# start, end:640, 704
# start, end:704, 768
# start, end:768, 832
# start, end:832, 896
# start, end:896, 960
# start, end:960, 1024
# start, end:1024, 1088
# start, end:1088, 1152
# start, end:1152, 1216
# start, end:1216, 1280
# start, end:1280, 1344
# start, end:1344, 1408
# start, end:1408, 1472
# start, end:1472, 1536
# start, end:1536, 1600
# Phase: test | Epoch: 0 | Count: 25 \ Start Time: 02:19:55 | Loss: 60
# start, end:1600, 1664
# start, end:1664, 1728
# start, end:1728, 1792
# start, end:1792, 1856
# start, end:1856, 1920
# start, end:1920, 1984
# start, end:1984, 2048
# start, end:2048, 2112
# start, end:2112, 2176
# start, end:2176, 2240
# start, end:2240, 2304
# start, end:2304, 2368
# start, end:2368, 2432
# start, end:2432, 2496
# start, end:2496, 2560
# start, end:2560, 2624
# start, end:2624, 2688
# start, end:2688, 2752
# start, end:2752, 2816
# start, end:2816, 2880
# start, end:2880, 2944
# start, end:2944, 3008
# start, end:3008, 3072
# start, end:3072, 3136
# start, end:3136, 3200
# Phase: test | Epoch: 0 | Count: 50 \ Start Time: 02:19:59 | Loss: 59
# start, end:3200, 3264
# start, end:3264, 3328
# start, end:3328, 3392
# start, end:3392, 3456
# start, end:3456, 3520
# start, end:3520, 3584
# start, end:3584, 3648
# start, end:3648, 3712
# start, end:3712, 3776
# start, end:3776, 3840
# start, end:3840, 3904
# start, end:3904, 3968
# start, end:3968, 4032
# start, end:4032, 4096
# start, end:4096, 4160
# start, end:4160, 4224
# start, end:4224, 4288
# start, end:4288, 4352
# start, end:4352, 4416
# start, end:4416, 4480
# start, end:4480, 4544
# start, end:4544, 4608
# start, end:4608, 4672
# start, end:4672, 4736
# start, end:4736, 4800
# Phase: test | Epoch: 0 | Count: 75 \ Start Time: 02:20:02 | Loss: 59
# start, end:4800, 4864
# start, end:4864, 4928
# start, end:4928, 4992
# start, end:4992, 5056
# start, end:5056, 5120
# start, end:5120, 5184
# start, end:5184, 5248
# start, end:5248, 5312
# start, end:5312, 5376
# start, end:5376, 5440
# start, end:5440, 5504
# start, end:5504, 5568
# start, end:5568, 5632
# start, end:5632, 5696
# start, end:5696, 5760
# start, end:5760, 5824
# start, end:5824, 5888
# start, end:5888, 5952
# start, end:5952, 6016
# start, end:6016, 6080
# start, end:6080, 6144
# start, end:6144, 6208
# start, end:6208, 6272
# start, end:6272, 6336
# start, end:6336, 6400
# Phase: test | Epoch: 0 | Count: 100 \ Start Time: 02:20:05 | Loss: 60
# start, end:6400, 6464
# start, end:6464, 6528
# start, end:6528, 6592
# start, end:6592, 6656
# start, end:6656, 6720
# start, end:6720, 6784
# start, end:6784, 6848
# start, end:6848, 6912
# start, end:6912, 6976
# start, end:6976, 7040
# start, end:7040, 7104
# start, end:7104, 7168
# start, end:7168, 7232
# start, end:7232, 7296
# start, end:7296, 7360
# start, end:7360, 7424
# start, end:7424, 7488
# start, end:7488, 7552
# start, end:7552, 7616
# start, end:7616, 7680
# start, end:7680, 7744
# start, end:7744, 7808
# start, end:7808, 7872
# start, end:7872, 7936
# start, end:7936, 8000
# Phase: test | Epoch: 0 | Count: 125 \ Start Time: 02:20:09 | Loss: 59
# start, end:8000, 8064
# start, end:8064, 8128
# start, end:8128, 8192
# start, end:8192, 8256
# start, end:8256, 8320
# start, end:8320, 8384
# start, end:8384, 8448
# start, end:8448, 8512
# start, end:8512, 8576
# start, end:8576, 8640
# start, end:8640, 8704
# start, end:8704, 8768
# start, end:8768, 8832
# start, end:8832, 8896
# start, end:8896, 8960
# start, end:8960, 9024
# start, end:9024, 9088
# start, end:9088, 9152
# start, end:9152, 9216
# start, end:9216, 9280
# start, end:9280, 9344
# start, end:9344, 9408
# start, end:9408, 9472
# start, end:9472, 9536
# start, end:9536, 9600
# Phase: test | Epoch: 0 | Count: 150 \ Start Time: 02:20:12 | Loss: 59
# start, end:9600, 9664
# start, end:9664, 9728
# start, end:9728, 9792
# start, end:9792, 9856
# start, end:9856, 9920
# start, end:9920, 9984
# start, end:9984, 10048
# start, end:10048, 10112
# start, end:10112, 10176
# start, end:10176, 10240
# start, end:10240, 10304
# start, end:10304, 10368
# start, end:10368, 10432
# start, end:10432, 10496
# start, end:10496, 10560
# start, end:10560, 10624
# start, end:10624, 10688
# start, end:10688, 10752
# start, end:10752, 10816
# start, end:10816, 10880
# start, end:10880, 10944
# start, end:10944, 11008
# start, end:11008, 11072
# start, end:11072, 11136
# start, end:11136, 11200
# Phase: test | Epoch: 0 | Count: 175 \ Start Time: 02:20:16 | Loss: 60
# start, end:11200, 11264
# start, end:11264, 11328
# start, end:11328, 11392
# start, end:11392, 11456
# start, end:11456, 11520
# start, end:11520, 11584
# start, end:11584, 11648
# start, end:11648, 11712
# start, end:11712, 11776
# start, end:11776, 11840
# start, end:11840, 11904
# start, end:11904, 11968
# start, end:11968, 12032
# start, end:12032, 12096
# start, end:12096, 12160
# start, end:12160, 12224
# start, end:12224, 12288
# start, end:12288, 12352
# start, end:12352, 12416
# start, end:12416, 12480
# start, end:12480, 12544
# start, end:12544, 12608
# start, end:12608, 12672
# start, end:12672, 12736
# start, end:12736, 12800
# Phase: test | Epoch: 0 | Count: 200 \ Start Time: 02:20:19 | Loss: 59
# start, end:12800, 12864
# start, end:12864, 12928
# start, end:12928, 12992
# start, end:12992, 13056
# start, end:13056, 13120
# start, end:13120, 13184
# start, end:13184, 13248
# start, end:13248, 13312
# start, end:13312, 13376
# start, end:13376, 13440
# start, end:13440, 13504
# start, end:13504, 13568
# start, end:13568, 13632
# start, end:13632, 13696
# start, end:13696, 13760
# start, end:13760, 13824
# start, end:13824, 13888
# start, end:13888, 13952
# start, end:13952, 14016
# start, end:14016, 14080
# start, end:14080, 14144
# start, end:14144, 14208
# start, end:14208, 14272
# start, end:14272, 14336
# start, end:14336, 14400
# Phase: test | Epoch: 0 | Count: 225 \ Start Time: 02:20:22 | Loss: 59
# start, end:14400, 14464
# start, end:14464, 14528
# start, end:14528, 14592
# start, end:14592, 14656
# start, end:14656, 14720
# start, end:14720, 14784
# start, end:14784, 14848
# start, end:14848, 14912
# start, end:14912, 14976
# start, end:14976, 15040
# start, end:15040, 15104
# start, end:15104, 15168
# start, end:15168, 15232
# start, end:15232, 15296
# start, end:15296, 15360
# start, end:15360, 15424
# start, end:15424, 15488
# start, end:15488, 15552
# start, end:15552, 15616
# start, end:15616, 15680
# start, end:15680, 15744
# start, end:15744, 15808
# start, end:15808, 15872
# start, end:15872, 15936
# start, end:15936, 16000
# Phase: test | Epoch: 0 | Count: 250 \ Start Time: 02:20:26 | Loss: 59
# start, end:16000, 16064
# start, end:16064, 16128
# start, end:16128, 16192
# start, end:16192, 16256
# start, end:16256, 16320
# start, end:16320, 16384
# start, end:16384, 16448
# start, end:16448, 16512
# start, end:16512, 16576
# start, end:16576, 16640
# start, end:16640, 16704
# start, end:16704, 16768
# start, end:16768, 16832
# start, end:16832, 16896
# start, end:16896, 16960
# start, end:16960, 17024
# start, end:17024, 17088
# start, end:17088, 17152
# start, end:17152, 17216
# start, end:17216, 17280
# start, end:17280, 17344
# start, end:17344, 17408
# start, end:17408, 17472
# start, end:17472, 17536
# start, end:17536, 17600
# Phase: test | Epoch: 0 | Count: 275 \ Start Time: 02:20:29 | Loss: 59
# start, end:17600, 17664
# start, end:17664, 17728
# start, end:17728, 17792
# start, end:17792, 17856
# start, end:17856, 17920
# start, end:17920, 17984
# start, end:17984, 18048
# start, end:18048, 18112
# start, end:18112, 18176
# start, end:18176, 18240
# start, end:18240, 18304
# start, end:18304, 18368
# start, end:18368, 18432
# start, end:18432, 18496
# start, end:18496, 18560
# start, end:18560, 18624
# start, end:18624, 18688
# start, end:18688, 18752
# start, end:18752, 18816
# start, end:18816, 18880
# start, end:18880, 18944
# start, end:18944, 19008
# start, end:19008, 19072
# start, end:19072, 19136
# start, end:19136, 19200
# Phase: test | Epoch: 0 | Count: 300 \ Start Time: 02:20:33 | Loss: 60
# start, end:19200, 19264
# start, end:19264, 19328
# start, end:19328, 19392
# start, end:19392, 19456
# start, end:19456, 19520
# start, end:19520, 19584
# start, end:19584, 19648
# start, end:19648, 19712
# start, end:19712, 19776
# start, end:19776, 19840
# start, end:19840, 19904
# start, end:19904, 19968
# start, end:19968, 20032
# start, end:20032, 20096
# start, end:20096, 20160
# start, end:20160, 20224
# start, end:20224, 20288
# start, end:20288, 20352
# start, end:20352, 20416
# start, end:20416, 20480
# start, end:20480, 20544
# start, end:20544, 20608
# start, end:20608, 20672
# start, end:20672, 20736
# start, end:20736, 20800
# Phase: test | Epoch: 0 | Count: 325 \ Start Time: 02:20:36 | Loss: 59
# start, end:20800, 20864
# start, end:20864, 20928
# start, end:20928, 20992
# start, end:20992, 21056
# start, end:21056, 21120
# start, end:21120, 21184
# start, end:21184, 21248
# start, end:21248, 21312
# start, end:21312, 21376
# start, end:21376, 21440
# start, end:21440, 21504
# start, end:21504, 21568
# start, end:21568, 21632
# start, end:21632, 21696
# start, end:21696, 21760
# start, end:21760, 21824
# start, end:21824, 21888
# start, end:21888, 21952
# start, end:21952, 22016
# start, end:22016, 22080
# start, end:22080, 22144
# start, end:22144, 22208
# start, end:22208, 22272
# start, end:22272, 22336
# start, end:22336, 22400
# Phase: test | Epoch: 0 | Count: 350 \ Start Time: 02:20:39 | Loss: 59
# start, end:22400, 22464
# start, end:22464, 22528
# start, end:22528, 22592
# start, end:22592, 22656
# start, end:22656, 22720
# start, end:22720, 22784
# start, end:22784, 22848
# start, end:22848, 22912
# start, end:22912, 22976
# start, end:22976, 23040
# start, end:23040, 23104
# start, end:23104, 23168
# start, end:23168, 23232
# start, end:23232, 23296
# start, end:23296, 23360
# start, end:23360, 23424
# start, end:23424, 23488
# start, end:23488, 23552
# start, end:23552, 23616
# start, end:23616, 23680
# start, end:23680, 23744
# start, end:23744, 23808
# start, end:23808, 23872
# start, end:23872, 23936
# start, end:23936, 24000
# Phase: test | Epoch: 0 | Count: 375 \ Start Time: 02:20:43 | Loss: 59
# start, end:24000, 24064
# start, end:24064, 24128
# start, end:24128, 24192
# start, end:24192, 24256
# start, end:24256, 24320
# start, end:24320, 24384
# start, end:24384, 24448
# start, end:24448, 24512
# start, end:24512, 24576
# start, end:24576, 24640
# start, end:0, 63
# start, end:63, 127
# start, end:127, 191
# start, end:191, 255
# start, end:255, 319
# start, end:319, 383
# start, end:383, 447
# start, end:447, 511
# start, end:511, 575
# start, end:575, 639
# start, end:639, 703
# start, end:703, 767
# start, end:767, 831
# start, end:831, 895
# start, end:895, 959
# Phase: test | Epoch: 1 | Count: 400 \ Start Time: 02:20:46 | Loss: 59
# start, end:959, 1023
# start, end:1023, 1087
# start, end:1087, 1151
# start, end:1151, 1215
# start, end:1215, 1279
# start, end:1279, 1343
# start, end:1343, 1407
# start, end:1407, 1471
# start, end:1471, 1535
# start, end:1535, 1599
# start, end:1599, 1663
# start, end:1663, 1727
# start, end:1727, 1791
# start, end:1791, 1855
# start, end:1855, 1919
# start, end:1919, 1983
# start, end:1983, 2047
# start, end:2047, 2111
# start, end:2111, 2175
# start, end:2175, 2239
# start, end:2239, 2303
# start, end:2303, 2367
# start, end:2367, 2431
# start, end:2431, 2495
# start, end:2495, 2559
# Phase: test | Epoch: 1 | Count: 425 \ Start Time: 02:20:50 | Loss: 60
# start, end:2559, 2623
# start, end:2623, 2687
# start, end:2687, 2751
# start, end:2751, 2815
# start, end:2815, 2879
# start, end:2879, 2943
# start, end:2943, 3007
# start, end:3007, 3071
# start, end:3071, 3135
# start, end:3135, 3199
# start, end:3199, 3263
# start, end:3263, 3327
# start, end:3327, 3391
# start, end:3391, 3455
# start, end:3455, 3519
# start, end:3519, 3583
# start, end:3583, 3647
# start, end:3647, 3711
# start, end:3711, 3775
# start, end:3775, 3839
# start, end:3839, 3903
# start, end:3903, 3967
# start, end:3967, 4031
# start, end:4031, 4095
# start, end:4095, 4159
# Phase: test | Epoch: 1 | Count: 450 \ Start Time: 02:20:53 | Loss: 59
# start, end:4159, 4223
# start, end:4223, 4287
# start, end:4287, 4351
# start, end:4351, 4415
# start, end:4415, 4479
# start, end:4479, 4543
# start, end:4543, 4607
# start, end:4607, 4671
# start, end:4671, 4735
# start, end:4735, 4799
# start, end:4799, 4863
# start, end:4863, 4927
# start, end:4927, 4991
# start, end:4991, 5055
# start, end:5055, 5119
# start, end:5119, 5183
# start, end:5183, 5247
# start, end:5247, 5311
# start, end:5311, 5375
# start, end:5375, 5439
# start, end:5439, 5503
# start, end:5503, 5567
# start, end:5567, 5631
# start, end:5631, 5695
# start, end:5695, 5759
# Phase: test | Epoch: 1 | Count: 475 \ Start Time: 02:20:56 | Loss: 59
# start, end:5759, 5823
# start, end:5823, 5887
# start, end:5887, 5951
# start, end:5951, 6015
# start, end:6015, 6079
# start, end:6079, 6143
# start, end:6143, 6207
# start, end:6207, 6271
# start, end:6271, 6335
# start, end:6335, 6399
# start, end:6399, 6463
# start, end:6463, 6527
# start, end:6527, 6591
# start, end:6591, 6655
# start, end:6655, 6719
# start, end:6719, 6783
# start, end:6783, 6847
# start, end:6847, 6911
# start, end:6911, 6975
# start, end:6975, 7039
# start, end:7039, 7103
# start, end:7103, 7167
# start, end:7167, 7231
# start, end:7231, 7295
# start, end:7295, 7359
# Phase: test | Epoch: 1 | Count: 500 \ Start Time: 02:21:00 | Loss: 59
# start, end:7359, 7423
# start, end:7423, 7487
# start, end:7487, 7551
# start, end:7551, 7615
# start, end:7615, 7679
# start, end:7679, 7743
# start, end:7743, 7807
# start, end:7807, 7871
# start, end:7871, 7935
# start, end:7935, 7999
# start, end:7999, 8063
# start, end:8063, 8127
# start, end:8127, 8191
# start, end:8191, 8255
# start, end:8255, 8319
# start, end:8319, 8383
# start, end:8383, 8447
# start, end:8447, 8511
# start, end:8511, 8575
# start, end:8575, 8639
# start, end:8639, 8703
# start, end:8703, 8767
# start, end:8767, 8831
# start, end:8831, 8895
# start, end:8895, 8959
# Phase: test | Epoch: 1 | Count: 525 \ Start Time: 02:21:03 | Loss: 59
# start, end:8959, 9023
# start, end:9023, 9087
# start, end:9087, 9151
# start, end:9151, 9215
# start, end:9215, 9279
# start, end:9279, 9343
# start, end:9343, 9407
# start, end:9407, 9471
# start, end:9471, 9535
# start, end:9535, 9599
# start, end:9599, 9663
# start, end:9663, 9727
# start, end:9727, 9791
# start, end:9791, 9855
# start, end:9855, 9919
# start, end:9919, 9983
# start, end:9983, 10047
# start, end:10047, 10111
# start, end:10111, 10175
# start, end:10175, 10239
# start, end:10239, 10303
# start, end:10303, 10367
# start, end:10367, 10431
# start, end:10431, 10495
# start, end:10495, 10559
# Phase: test | Epoch: 1 | Count: 550 \ Start Time: 02:21:06 | Loss: 60
# start, end:10559, 10623
# start, end:10623, 10687
# start, end:10687, 10751
# start, end:10751, 10815
# start, end:10815, 10879
# start, end:10879, 10943
# start, end:10943, 11007
# start, end:11007, 11071
# start, end:11071, 11135
# start, end:11135, 11199
# start, end:11199, 11263
# start, end:11263, 11327
# start, end:11327, 11391
# start, end:11391, 11455
# start, end:11455, 11519
# start, end:11519, 11583
# start, end:11583, 11647
# start, end:11647, 11711
# start, end:11711, 11775
# start, end:11775, 11839
# start, end:11839, 11903
# start, end:11903, 11967
# start, end:11967, 12031
# start, end:12031, 12095
# start, end:12095, 12159
# Phase: test | Epoch: 1 | Count: 575 \ Start Time: 02:21:10 | Loss: 59
# start, end:12159, 12223
# start, end:12223, 12287
# start, end:12287, 12351
# start, end:12351, 12415
# start, end:12415, 12479
# start, end:12479, 12543
# start, end:12543, 12607
# start, end:12607, 12671
# start, end:12671, 12735
# start, end:12735, 12799
# start, end:12799, 12863
# start, end:12863, 12927
# start, end:12927, 12991
# start, end:12991, 13055
# start, end:13055, 13119
# start, end:13119, 13183
# start, end:13183, 13247
# start, end:13247, 13311
# start, end:13311, 13375
# start, end:13375, 13439
# start, end:13439, 13503
# start, end:13503, 13567
# start, end:13567, 13631
# start, end:13631, 13695
# start, end:13695, 13759
# Phase: test | Epoch: 1 | Count: 600 \ Start Time: 02:21:13 | Loss: 59
# start, end:13759, 13823
# start, end:13823, 13887
# start, end:13887, 13951
# start, end:13951, 14015
# start, end:14015, 14079
# start, end:14079, 14143
# start, end:14143, 14207
# start, end:14207, 14271
# start, end:14271, 14335
# start, end:14335, 14399
# start, end:14399, 14463
# start, end:14463, 14527
# start, end:14527, 14591
# start, end:14591, 14655
# start, end:14655, 14719
# start, end:14719, 14783
# start, end:14783, 14847
# start, end:14847, 14911
# start, end:14911, 14975
# start, end:14975, 15039
# start, end:15039, 15103
# start, end:15103, 15167
# start, end:15167, 15231
# start, end:15231, 15295
# start, end:15295, 15359
# Phase: test | Epoch: 1 | Count: 625 \ Start Time: 02:21:16 | Loss: 59
# start, end:15359, 15423
# start, end:15423, 15487
# start, end:15487, 15551
# start, end:15551, 15615
# start, end:15615, 15679
# start, end:15679, 15743
# start, end:15743, 15807
# start, end:15807, 15871
# start, end:15871, 15935
# start, end:15935, 15999
# start, end:15999, 16063
# start, end:16063, 16127
# start, end:16127, 16191
# start, end:16191, 16255
# start, end:16255, 16319
# start, end:16319, 16383
# start, end:16383, 16447
# start, end:16447, 16511
# start, end:16511, 16575
# start, end:16575, 16639
# start, end:16639, 16703
# start, end:16703, 16767
# start, end:16767, 16831
# start, end:16831, 16895
# start, end:16895, 16959
# Phase: test | Epoch: 1 | Count: 650 \ Start Time: 02:21:20 | Loss: 59
# start, end:16959, 17023
# start, end:17023, 17087
# start, end:17087, 17151
# start, end:17151, 17215
# start, end:17215, 17279
# start, end:17279, 17343
# start, end:17343, 17407
# start, end:17407, 17471
# start, end:17471, 17535
# start, end:17535, 17599
# start, end:17599, 17663
# start, end:17663, 17727
# start, end:17727, 17791
# start, end:17791, 17855
# start, end:17855, 17919
# start, end:17919, 17983
# start, end:17983, 18047
# start, end:18047, 18111
# start, end:18111, 18175
# start, end:18175, 18239
# start, end:18239, 18303
# start, end:18303, 18367
# start, end:18367, 18431
# start, end:18431, 18495
# start, end:18495, 18559
# Phase: test | Epoch: 1 | Count: 675 \ Start Time: 02:21:23 | Loss: 59
# start, end:18559, 18623
# start, end:18623, 18687
# start, end:18687, 18751
# start, end:18751, 18815
# start, end:18815, 18879
# start, end:18879, 18943
# start, end:18943, 19007
# start, end:19007, 19071
# start, end:19071, 19135
# start, end:19135, 19199
# start, end:19199, 19263
# start, end:19263, 19327
# start, end:19327, 19391
# start, end:19391, 19455
# start, end:19455, 19519
# start, end:19519, 19583
# start, end:19583, 19647
# start, end:19647, 19711
# start, end:19711, 19775
# start, end:19775, 19839
# start, end:19839, 19903
# start, end:19903, 19967
# start, end:19967, 20031
# start, end:20031, 20095
# start, end:20095, 20159
# Phase: test | Epoch: 1 | Count: 700 \ Start Time: 02:21:26 | Loss: 59
# start, end:20159, 20223
# start, end:20223, 20287
# start, end:20287, 20351
# start, end:20351, 20415
# start, end:20415, 20479
# start, end:20479, 20543
# start, end:20543, 20607
# start, end:20607, 20671
# start, end:20671, 20735
# start, end:20735, 20799
# start, end:20799, 20863
# start, end:20863, 20927
# start, end:20927, 20991
# start, end:20991, 21055
# start, end:21055, 21119
# start, end:21119, 21183
# start, end:21183, 21247
# start, end:21247, 21311
# start, end:21311, 21375
# start, end:21375, 21439
# start, end:21439, 21503
# start, end:21503, 21567
# start, end:21567, 21631
# start, end:21631, 21695
# start, end:21695, 21759
# Phase: test | Epoch: 1 | Count: 725 \ Start Time: 02:21:30 | Loss: 59
# start, end:21759, 21823
# start, end:21823, 21887
# start, end:21887, 21951
# start, end:21951, 22015
# start, end:22015, 22079
# start, end:22079, 22143
# start, end:22143, 22207
# start, end:22207, 22271
# start, end:22271, 22335
# start, end:22335, 22399
# start, end:22399, 22463
# start, end:22463, 22527
# start, end:22527, 22591
# start, end:22591, 22655
# start, end:22655, 22719
# start, end:22719, 22783
# start, end:22783, 22847
# start, end:22847, 22911
# start, end:22911, 22975
# start, end:22975, 23039
# start, end:23039, 23103
# start, end:23103, 23167
# start, end:23167, 23231
# start, end:23231, 23295
# start, end:23295, 23359
# Phase: test | Epoch: 1 | Count: 750 \ Start Time: 02:21:33 | Loss: 59
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_750_test_0.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_750_test_1.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_750_test_2.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_750_test_3.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_750_test_4.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_750_test_5.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_750_test_6.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_750_test_7.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_750_test_8.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_750_test_9.png
# start, end:23359, 23423
# start, end:23423, 23487
# start, end:23487, 23551
# start, end:23551, 23615
# start, end:23615, 23679
# start, end:23679, 23743
# start, end:23743, 23807
# start, end:23807, 23871
# start, end:23871, 23935
# start, end:23935, 23999
# start, end:23999, 24063
# start, end:24063, 24127
# start, end:24127, 24191
# start, end:24191, 24255
# start, end:24255, 24319
# start, end:24319, 24383
# start, end:24383, 24447
# start, end:24447, 24511
# start, end:24511, 24575
# start, end:24575, 24639
# start, end:0, 62
# start, end:62, 126
# start, end:126, 190
# start, end:190, 254
# start, end:254, 318
# Phase: test | Epoch: 2 | Count: 775 \ Start Time: 02:21:38 | Loss: 59
# start, end:318, 382
# start, end:382, 446
# start, end:446, 510
# start, end:510, 574
# start, end:574, 638
# start, end:638, 702
# start, end:702, 766
# start, end:766, 830
# start, end:830, 894
# start, end:894, 958
# start, end:958, 1022
# start, end:1022, 1086
# start, end:1086, 1150
# start, end:1150, 1214
# start, end:1214, 1278
# start, end:1278, 1342
# start, end:1342, 1406
# start, end:1406, 1470
# start, end:1470, 1534
# start, end:1534, 1598
# start, end:1598, 1662
# start, end:1662, 1726
# start, end:1726, 1790
# start, end:1790, 1854
# start, end:1854, 1918
# Phase: test | Epoch: 2 | Count: 800 \ Start Time: 02:21:42 | Loss: 60
# start, end:1918, 1982
# start, end:1982, 2046
# start, end:2046, 2110
# start, end:2110, 2174
# start, end:2174, 2238
# start, end:2238, 2302
# start, end:2302, 2366
# start, end:2366, 2430
# start, end:2430, 2494
# start, end:2494, 2558
# start, end:2558, 2622
# start, end:2622, 2686
# start, end:2686, 2750
# start, end:2750, 2814
# start, end:2814, 2878
# start, end:2878, 2942
# start, end:2942, 3006
# start, end:3006, 3070
# start, end:3070, 3134
# start, end:3134, 3198
# start, end:3198, 3262
# start, end:3262, 3326
# start, end:3326, 3390
# start, end:3390, 3454
# start, end:3454, 3518
# Phase: test | Epoch: 2 | Count: 825 \ Start Time: 02:21:45 | Loss: 59
# start, end:3518, 3582
# start, end:3582, 3646
# start, end:3646, 3710
# start, end:3710, 3774
# start, end:3774, 3838
# start, end:3838, 3902
# start, end:3902, 3966
# start, end:3966, 4030
# start, end:4030, 4094
# start, end:4094, 4158
# start, end:4158, 4222
# start, end:4222, 4286
# start, end:4286, 4350
# start, end:4350, 4414
# start, end:4414, 4478
# start, end:4478, 4542
# start, end:4542, 4606
# start, end:4606, 4670
# start, end:4670, 4734
# start, end:4734, 4798
# start, end:4798, 4862
# start, end:4862, 4926
# start, end:4926, 4990
# start, end:4990, 5054
# start, end:5054, 5118
# Phase: test | Epoch: 2 | Count: 850 \ Start Time: 02:21:48 | Loss: 59
# start, end:5118, 5182
# start, end:5182, 5246
# start, end:5246, 5310
# start, end:5310, 5374
# start, end:5374, 5438
# start, end:5438, 5502
# start, end:5502, 5566
# start, end:5566, 5630
# start, end:5630, 5694
# start, end:5694, 5758
# start, end:5758, 5822
# start, end:5822, 5886
# start, end:5886, 5950
# start, end:5950, 6014
# start, end:6014, 6078
# start, end:6078, 6142
# start, end:6142, 6206
# start, end:6206, 6270
# start, end:6270, 6334
# start, end:6334, 6398
# start, end:6398, 6462
# start, end:6462, 6526
# start, end:6526, 6590
# start, end:6590, 6654
# start, end:6654, 6718
# Phase: test | Epoch: 2 | Count: 875 \ Start Time: 02:21:52 | Loss: 59
# start, end:6718, 6782
# start, end:6782, 6846
# start, end:6846, 6910
# start, end:6910, 6974
# start, end:6974, 7038
# start, end:7038, 7102
# start, end:7102, 7166
# start, end:7166, 7230
# start, end:7230, 7294
# start, end:7294, 7358
# start, end:7358, 7422
# start, end:7422, 7486
# start, end:7486, 7550
# start, end:7550, 7614
# start, end:7614, 7678
# start, end:7678, 7742
# start, end:7742, 7806
# start, end:7806, 7870
# start, end:7870, 7934
# start, end:7934, 7998
# start, end:7998, 8062
# start, end:8062, 8126
# start, end:8126, 8190
# start, end:8190, 8254
# start, end:8254, 8318
# Phase: test | Epoch: 2 | Count: 900 \ Start Time: 02:21:55 | Loss: 59
# start, end:8318, 8382
# start, end:8382, 8446
# start, end:8446, 8510
# start, end:8510, 8574
# start, end:8574, 8638
# start, end:8638, 8702
# start, end:8702, 8766
# start, end:8766, 8830
# start, end:8830, 8894
# start, end:8894, 8958
# start, end:8958, 9022
# start, end:9022, 9086
# start, end:9086, 9150
# start, end:9150, 9214
# start, end:9214, 9278
# start, end:9278, 9342
# start, end:9342, 9406
# start, end:9406, 9470
# start, end:9470, 9534
# start, end:9534, 9598
# start, end:9598, 9662
# start, end:9662, 9726
# start, end:9726, 9790
# start, end:9790, 9854
# start, end:9854, 9918
# Phase: test | Epoch: 2 | Count: 925 \ Start Time: 02:21:59 | Loss: 59
# start, end:9918, 9982
# start, end:9982, 10046
# start, end:10046, 10110
# start, end:10110, 10174
# start, end:10174, 10238
# start, end:10238, 10302
# start, end:10302, 10366
# start, end:10366, 10430
# start, end:10430, 10494
# start, end:10494, 10558
# start, end:10558, 10622
# start, end:10622, 10686
# start, end:10686, 10750
# start, end:10750, 10814
# start, end:10814, 10878
# start, end:10878, 10942
# start, end:10942, 11006
# start, end:11006, 11070
# start, end:11070, 11134
# start, end:11134, 11198
# start, end:11198, 11262
# start, end:11262, 11326
# start, end:11326, 11390
# start, end:11390, 11454
# start, end:11454, 11518
# Phase: test | Epoch: 2 | Count: 950 \ Start Time: 02:22:02 | Loss: 60
# start, end:11518, 11582
# start, end:11582, 11646
# start, end:11646, 11710
# start, end:11710, 11774
# start, end:11774, 11838
# start, end:11838, 11902
# start, end:11902, 11966
# start, end:11966, 12030
# start, end:12030, 12094
# start, end:12094, 12158
# start, end:12158, 12222
# start, end:12222, 12286
# start, end:12286, 12350
# start, end:12350, 12414
# start, end:12414, 12478
# start, end:12478, 12542
# start, end:12542, 12606
# start, end:12606, 12670
# start, end:12670, 12734
# start, end:12734, 12798
# start, end:12798, 12862
# start, end:12862, 12926
# start, end:12926, 12990
# start, end:12990, 13054
# start, end:13054, 13118
# Phase: test | Epoch: 2 | Count: 975 \ Start Time: 02:22:05 | Loss: 59
# start, end:13118, 13182
# start, end:13182, 13246
# start, end:13246, 13310
# start, end:13310, 13374
# start, end:13374, 13438
# start, end:13438, 13502
# start, end:13502, 13566
# start, end:13566, 13630
# start, end:13630, 13694
# start, end:13694, 13758
# start, end:13758, 13822
# start, end:13822, 13886
# start, end:13886, 13950
# start, end:13950, 14014
# start, end:14014, 14078
# start, end:14078, 14142
# start, end:14142, 14206
# start, end:14206, 14270
# start, end:14270, 14334
# start, end:14334, 14398
# start, end:14398, 14462
# start, end:14462, 14526
# start, end:14526, 14590
# start, end:14590, 14654
# start, end:14654, 14718
# Phase: test | Epoch: 2 | Count: 1000 \ Start Time: 02:22:09 | Loss: 59
# start, end:14718, 14782
# start, end:14782, 14846
# start, end:14846, 14910
# start, end:14910, 14974
# start, end:14974, 15038
# start, end:15038, 15102
# start, end:15102, 15166
# start, end:15166, 15230
# start, end:15230, 15294
# start, end:15294, 15358
# start, end:15358, 15422
# start, end:15422, 15486
# start, end:15486, 15550
# start, end:15550, 15614
# start, end:15614, 15678
# start, end:15678, 15742
# start, end:15742, 15806
# start, end:15806, 15870
# start, end:15870, 15934
# start, end:15934, 15998
# start, end:15998, 16062
# start, end:16062, 16126
# start, end:16126, 16190
# start, end:16190, 16254
# start, end:16254, 16318
# Phase: test | Epoch: 2 | Count: 1025 \ Start Time: 02:22:12 | Loss: 59
# start, end:16318, 16382
# start, end:16382, 16446
# start, end:16446, 16510
# start, end:16510, 16574
# start, end:16574, 16638
# start, end:16638, 16702
# start, end:16702, 16766
# start, end:16766, 16830
# start, end:16830, 16894
# start, end:16894, 16958
# start, end:16958, 17022
# start, end:17022, 17086
# start, end:17086, 17150
# start, end:17150, 17214
# start, end:17214, 17278
# start, end:17278, 17342
# start, end:17342, 17406
# start, end:17406, 17470
# start, end:17470, 17534
# start, end:17534, 17598
# start, end:17598, 17662
# start, end:17662, 17726
# start, end:17726, 17790
# start, end:17790, 17854
# start, end:17854, 17918
# Phase: test | Epoch: 2 | Count: 1050 \ Start Time: 02:22:15 | Loss: 59
# start, end:17918, 17982
# start, end:17982, 18046
# start, end:18046, 18110
# start, end:18110, 18174
# start, end:18174, 18238
# start, end:18238, 18302
# start, end:18302, 18366
# start, end:18366, 18430
# start, end:18430, 18494
# start, end:18494, 18558
# start, end:18558, 18622
# start, end:18622, 18686
# start, end:18686, 18750
# start, end:18750, 18814
# start, end:18814, 18878
# start, end:18878, 18942
# start, end:18942, 19006
# start, end:19006, 19070
# start, end:19070, 19134
# start, end:19134, 19198
# start, end:19198, 19262
# start, end:19262, 19326
# start, end:19326, 19390
# start, end:19390, 19454
# start, end:19454, 19518
# Phase: test | Epoch: 2 | Count: 1075 \ Start Time: 02:22:19 | Loss: 59
# start, end:19518, 19582
# start, end:19582, 19646
# start, end:19646, 19710
# start, end:19710, 19774
# start, end:19774, 19838
# start, end:19838, 19902
# start, end:19902, 19966
# start, end:19966, 20030
# start, end:20030, 20094
# start, end:20094, 20158
# start, end:20158, 20222
# start, end:20222, 20286
# start, end:20286, 20350
# start, end:20350, 20414
# start, end:20414, 20478
# start, end:20478, 20542
# start, end:20542, 20606
# start, end:20606, 20670
# start, end:20670, 20734
# start, end:20734, 20798
# start, end:20798, 20862
# start, end:20862, 20926
# start, end:20926, 20990
# start, end:20990, 21054
# start, end:21054, 21118
# Phase: test | Epoch: 2 | Count: 1100 \ Start Time: 02:22:22 | Loss: 59
# start, end:21118, 21182
# start, end:21182, 21246
# start, end:21246, 21310
# start, end:21310, 21374
# start, end:21374, 21438
# start, end:21438, 21502
# start, end:21502, 21566
# start, end:21566, 21630
# start, end:21630, 21694
# start, end:21694, 21758
# start, end:21758, 21822
# start, end:21822, 21886
# start, end:21886, 21950
# start, end:21950, 22014
# start, end:22014, 22078
# start, end:22078, 22142
# start, end:22142, 22206
# start, end:22206, 22270
# start, end:22270, 22334
# start, end:22334, 22398
# start, end:22398, 22462
# start, end:22462, 22526
# start, end:22526, 22590
# start, end:22590, 22654
# start, end:22654, 22718
# Phase: test | Epoch: 2 | Count: 1125 \ Start Time: 02:22:26 | Loss: 59
# start, end:22718, 22782
# start, end:22782, 22846
# start, end:22846, 22910
# start, end:22910, 22974
# start, end:22974, 23038
# start, end:23038, 23102
# start, end:23102, 23166
# start, end:23166, 23230
# start, end:23230, 23294
# start, end:23294, 23358
# start, end:23358, 23422
# start, end:23422, 23486
# start, end:23486, 23550
# start, end:23550, 23614
# start, end:23614, 23678
# start, end:23678, 23742
# start, end:23742, 23806
# start, end:23806, 23870
# start, end:23870, 23934
# start, end:23934, 23998
# start, end:23998, 24062
# start, end:24062, 24126
# start, end:24126, 24190
# start, end:24190, 24254
# start, end:24254, 24318
# Phase: test | Epoch: 2 | Count: 1150 \ Start Time: 02:22:29 | Loss: 59
# start, end:24318, 24382
# start, end:24382, 24446
# start, end:24446, 24510
# start, end:24510, 24574
# start, end:24574, 24638
# start, end:0, 61
# start, end:61, 125
# start, end:125, 189
# start, end:189, 253
# start, end:253, 317
# start, end:317, 381
# start, end:381, 445
# start, end:445, 509
# start, end:509, 573
# start, end:573, 637
# start, end:637, 701
# start, end:701, 765
# start, end:765, 829
# start, end:829, 893
# start, end:893, 957
# start, end:957, 1021
# start, end:1021, 1085
# start, end:1085, 1149
# start, end:1149, 1213
# start, end:1213, 1277
# Phase: test | Epoch: 3 | Count: 1175 \ Start Time: 02:22:32 | Loss: 60
# start, end:1277, 1341
# start, end:1341, 1405
# start, end:1405, 1469
# start, end:1469, 1533
# start, end:1533, 1597
# start, end:1597, 1661
# start, end:1661, 1725
# start, end:1725, 1789
# start, end:1789, 1853
# start, end:1853, 1917
# start, end:1917, 1981
# start, end:1981, 2045
# start, end:2045, 2109
# start, end:2109, 2173
# start, end:2173, 2237
# start, end:2237, 2301
# start, end:2301, 2365
# start, end:2365, 2429
# start, end:2429, 2493
# start, end:2493, 2557
# start, end:2557, 2621
# start, end:2621, 2685
# start, end:2685, 2749
# start, end:2749, 2813
# start, end:2813, 2877
# Phase: test | Epoch: 3 | Count: 1200 \ Start Time: 02:22:36 | Loss: 59
# start, end:2877, 2941
# start, end:2941, 3005
# start, end:3005, 3069
# start, end:3069, 3133
# start, end:3133, 3197
# start, end:3197, 3261
# start, end:3261, 3325
# start, end:3325, 3389
# start, end:3389, 3453
# start, end:3453, 3517
# start, end:3517, 3581
# start, end:3581, 3645
# start, end:3645, 3709
# start, end:3709, 3773
# start, end:3773, 3837
# start, end:3837, 3901
# start, end:3901, 3965
# start, end:3965, 4029
# start, end:4029, 4093
# start, end:4093, 4157
# start, end:4157, 4221
# start, end:4221, 4285
# start, end:4285, 4349
# start, end:4349, 4413
# start, end:4413, 4477
# Phase: test | Epoch: 3 | Count: 1225 \ Start Time: 02:22:39 | Loss: 59
# start, end:4477, 4541
# start, end:4541, 4605
# start, end:4605, 4669
# start, end:4669, 4733
# start, end:4733, 4797
# start, end:4797, 4861
# start, end:4861, 4925
# start, end:4925, 4989
# start, end:4989, 5053
# start, end:5053, 5117
# start, end:5117, 5181
# start, end:5181, 5245
# start, end:5245, 5309
# start, end:5309, 5373
# start, end:5373, 5437
# start, end:5437, 5501
# start, end:5501, 5565
# start, end:5565, 5629
# start, end:5629, 5693
# start, end:5693, 5757
# start, end:5757, 5821
# start, end:5821, 5885
# start, end:5885, 5949
# start, end:5949, 6013
# start, end:6013, 6077
# Phase: test | Epoch: 3 | Count: 1250 \ Start Time: 02:22:43 | Loss: 59
# start, end:6077, 6141
# start, end:6141, 6205
# start, end:6205, 6269
# start, end:6269, 6333
# start, end:6333, 6397
# start, end:6397, 6461
# start, end:6461, 6525
# start, end:6525, 6589
# start, end:6589, 6653
# start, end:6653, 6717
# start, end:6717, 6781
# start, end:6781, 6845
# start, end:6845, 6909
# start, end:6909, 6973
# start, end:6973, 7037
# start, end:7037, 7101
# start, end:7101, 7165
# start, end:7165, 7229
# start, end:7229, 7293
# start, end:7293, 7357
# start, end:7357, 7421
# start, end:7421, 7485
# start, end:7485, 7549
# start, end:7549, 7613
# start, end:7613, 7677
# Phase: test | Epoch: 3 | Count: 1275 \ Start Time: 02:22:46 | Loss: 59
# start, end:7677, 7741
# start, end:7741, 7805
# start, end:7805, 7869
# start, end:7869, 7933
# start, end:7933, 7997
# start, end:7997, 8061
# start, end:8061, 8125
# start, end:8125, 8189
# start, end:8189, 8253
# start, end:8253, 8317
# start, end:8317, 8381
# start, end:8381, 8445
# start, end:8445, 8509
# start, end:8509, 8573
# start, end:8573, 8637
# start, end:8637, 8701
# start, end:8701, 8765
# start, end:8765, 8829
# start, end:8829, 8893
# start, end:8893, 8957
# start, end:8957, 9021
# start, end:9021, 9085
# start, end:9085, 9149
# start, end:9149, 9213
# start, end:9213, 9277
# Phase: test | Epoch: 3 | Count: 1300 \ Start Time: 02:22:49 | Loss: 59
# start, end:9277, 9341
# start, end:9341, 9405
# start, end:9405, 9469
# start, end:9469, 9533
# start, end:9533, 9597
# start, end:9597, 9661
# start, end:9661, 9725
# start, end:9725, 9789
# start, end:9789, 9853
# start, end:9853, 9917
# start, end:9917, 9981
# start, end:9981, 10045
# start, end:10045, 10109
# start, end:10109, 10173
# start, end:10173, 10237
# start, end:10237, 10301
# start, end:10301, 10365
# start, end:10365, 10429
# start, end:10429, 10493
# start, end:10493, 10557
# start, end:10557, 10621
# start, end:10621, 10685
# start, end:10685, 10749
# start, end:10749, 10813
# start, end:10813, 10877
# Phase: test | Epoch: 3 | Count: 1325 \ Start Time: 02:22:53 | Loss: 60
# start, end:10877, 10941
# start, end:10941, 11005
# start, end:11005, 11069
# start, end:11069, 11133
# start, end:11133, 11197
# start, end:11197, 11261
# start, end:11261, 11325
# start, end:11325, 11389
# start, end:11389, 11453
# start, end:11453, 11517
# start, end:11517, 11581
# start, end:11581, 11645
# start, end:11645, 11709
# start, end:11709, 11773
# start, end:11773, 11837
# start, end:11837, 11901
# start, end:11901, 11965
# start, end:11965, 12029
# start, end:12029, 12093
# start, end:12093, 12157
# start, end:12157, 12221
# start, end:12221, 12285
# start, end:12285, 12349
# start, end:12349, 12413
# start, end:12413, 12477
# Phase: test | Epoch: 3 | Count: 1350 \ Start Time: 02:22:56 | Loss: 59
# start, end:12477, 12541
# start, end:12541, 12605
# start, end:12605, 12669
# start, end:12669, 12733
# start, end:12733, 12797
# start, end:12797, 12861
# start, end:12861, 12925
# start, end:12925, 12989
# start, end:12989, 13053
# start, end:13053, 13117
# start, end:13117, 13181
# start, end:13181, 13245
# start, end:13245, 13309
# start, end:13309, 13373
# start, end:13373, 13437
# start, end:13437, 13501
# start, end:13501, 13565
# start, end:13565, 13629
# start, end:13629, 13693
# start, end:13693, 13757
# start, end:13757, 13821
# start, end:13821, 13885
# start, end:13885, 13949
# start, end:13949, 14013
# start, end:14013, 14077
# Phase: test | Epoch: 3 | Count: 1375 \ Start Time: 02:23:00 | Loss: 59
# start, end:14077, 14141
# start, end:14141, 14205
# start, end:14205, 14269
# start, end:14269, 14333
# start, end:14333, 14397
# start, end:14397, 14461
# start, end:14461, 14525
# start, end:14525, 14589
# start, end:14589, 14653
# start, end:14653, 14717
# start, end:14717, 14781
# start, end:14781, 14845
# start, end:14845, 14909
# start, end:14909, 14973
# start, end:14973, 15037
# start, end:15037, 15101
# start, end:15101, 15165
# start, end:15165, 15229
# start, end:15229, 15293
# start, end:15293, 15357
# start, end:15357, 15421
# start, end:15421, 15485
# start, end:15485, 15549
# start, end:15549, 15613
# start, end:15613, 15677
# Phase: test | Epoch: 3 | Count: 1400 \ Start Time: 02:23:03 | Loss: 59
# start, end:15677, 15741
# start, end:15741, 15805
# start, end:15805, 15869
# start, end:15869, 15933
# start, end:15933, 15997
# start, end:15997, 16061
# start, end:16061, 16125
# start, end:16125, 16189
# start, end:16189, 16253
# start, end:16253, 16317
# start, end:16317, 16381
# start, end:16381, 16445
# start, end:16445, 16509
# start, end:16509, 16573
# start, end:16573, 16637
# start, end:16637, 16701
# start, end:16701, 16765
# start, end:16765, 16829
# start, end:16829, 16893
# start, end:16893, 16957
# start, end:16957, 17021
# start, end:17021, 17085
# start, end:17085, 17149
# start, end:17149, 17213
# start, end:17213, 17277
# Phase: test | Epoch: 3 | Count: 1425 \ Start Time: 02:23:07 | Loss: 59
# start, end:17277, 17341
# start, end:17341, 17405
# start, end:17405, 17469
# start, end:17469, 17533
# start, end:17533, 17597
# start, end:17597, 17661
# start, end:17661, 17725
# start, end:17725, 17789
# start, end:17789, 17853
# start, end:17853, 17917
# start, end:17917, 17981
# start, end:17981, 18045
# start, end:18045, 18109
# start, end:18109, 18173
# start, end:18173, 18237
# start, end:18237, 18301
# start, end:18301, 18365
# start, end:18365, 18429
# start, end:18429, 18493
# start, end:18493, 18557
# start, end:18557, 18621
# start, end:18621, 18685
# start, end:18685, 18749
# start, end:18749, 18813
# start, end:18813, 18877
# Phase: test | Epoch: 3 | Count: 1450 \ Start Time: 02:23:10 | Loss: 59
# start, end:18877, 18941
# start, end:18941, 19005
# start, end:19005, 19069
# start, end:19069, 19133
# start, end:19133, 19197
# start, end:19197, 19261
# start, end:19261, 19325
# start, end:19325, 19389
# start, end:19389, 19453
# start, end:19453, 19517
# start, end:19517, 19581
# start, end:19581, 19645
# start, end:19645, 19709
# start, end:19709, 19773
# start, end:19773, 19837
# start, end:19837, 19901
# start, end:19901, 19965
# start, end:19965, 20029
# start, end:20029, 20093
# start, end:20093, 20157
# start, end:20157, 20221
# start, end:20221, 20285
# start, end:20285, 20349
# start, end:20349, 20413
# start, end:20413, 20477
# Phase: test | Epoch: 3 | Count: 1475 \ Start Time: 02:23:14 | Loss: 60
# start, end:20477, 20541
# start, end:20541, 20605
# start, end:20605, 20669
# start, end:20669, 20733
# start, end:20733, 20797
# start, end:20797, 20861
# start, end:20861, 20925
# start, end:20925, 20989
# start, end:20989, 21053
# start, end:21053, 21117
# start, end:21117, 21181
# start, end:21181, 21245
# start, end:21245, 21309
# start, end:21309, 21373
# start, end:21373, 21437
# start, end:21437, 21501
# start, end:21501, 21565
# start, end:21565, 21629
# start, end:21629, 21693
# start, end:21693, 21757
# start, end:21757, 21821
# start, end:21821, 21885
# start, end:21885, 21949
# start, end:21949, 22013
# start, end:22013, 22077
# Phase: test | Epoch: 3 | Count: 1500 \ Start Time: 02:23:17 | Loss: 59
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_1500_test_0.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_1500_test_1.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_1500_test_2.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_1500_test_3.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_1500_test_4.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_1500_test_5.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_1500_test_6.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_1500_test_7.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_1500_test_8.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_1500_test_9.png
# start, end:22077, 22141
# start, end:22141, 22205
# start, end:22205, 22269
# start, end:22269, 22333
# start, end:22333, 22397
# start, end:22397, 22461
# start, end:22461, 22525
# start, end:22525, 22589
# start, end:22589, 22653
# start, end:22653, 22717
# start, end:22717, 22781
# start, end:22781, 22845
# start, end:22845, 22909
# start, end:22909, 22973
# start, end:22973, 23037
# start, end:23037, 23101
# start, end:23101, 23165
# start, end:23165, 23229
# start, end:23229, 23293
# start, end:23293, 23357
# start, end:23357, 23421
# start, end:23421, 23485
# start, end:23485, 23549
# start, end:23549, 23613
# start, end:23613, 23677
# Phase: test | Epoch: 3 | Count: 1525 \ Start Time: 02:23:22 | Loss: 59
# start, end:23677, 23741
# start, end:23741, 23805
# start, end:23805, 23869
# start, end:23869, 23933
# start, end:23933, 23997
# start, end:23997, 24061
# start, end:24061, 24125
# start, end:24125, 24189
# start, end:24189, 24253
# start, end:24253, 24317
# start, end:24317, 24381
# start, end:24381, 24445
# start, end:24445, 24509
# start, end:24509, 24573
# start, end:24573, 24637
# start, end:0, 60
# start, end:60, 124
# start, end:124, 188
# start, end:188, 252
# start, end:252, 316
# start, end:316, 380
# start, end:380, 444
# start, end:444, 508
# start, end:508, 572
# start, end:572, 636
# Phase: test | Epoch: 4 | Count: 1550 \ Start Time: 02:23:26 | Loss: 59
# start, end:636, 700
# start, end:700, 764
# start, end:764, 828
# start, end:828, 892
# start, end:892, 956
# start, end:956, 1020
# start, end:1020, 1084
# start, end:1084, 1148
# start, end:1148, 1212
# start, end:1212, 1276
# start, end:1276, 1340
# start, end:1340, 1404
# start, end:1404, 1468
# start, end:1468, 1532
# start, end:1532, 1596
# start, end:1596, 1660
# start, end:1660, 1724
# start, end:1724, 1788
# start, end:1788, 1852
# start, end:1852, 1916
# start, end:1916, 1980
# start, end:1980, 2044
# start, end:2044, 2108
# start, end:2108, 2172
# start, end:2172, 2236
# Phase: test | Epoch: 4 | Count: 1575 \ Start Time: 02:23:29 | Loss: 60
# start, end:2236, 2300
# start, end:2300, 2364
# start, end:2364, 2428
# start, end:2428, 2492
# start, end:2492, 2556
# start, end:2556, 2620
# start, end:2620, 2684
# start, end:2684, 2748
# start, end:2748, 2812
# start, end:2812, 2876
# start, end:2876, 2940
# start, end:2940, 3004
# start, end:3004, 3068
# start, end:3068, 3132
# start, end:3132, 3196
# start, end:3196, 3260
# start, end:3260, 3324
# start, end:3324, 3388
# start, end:3388, 3452
# start, end:3452, 3516
# start, end:3516, 3580
# start, end:3580, 3644
# start, end:3644, 3708
# start, end:3708, 3772
# start, end:3772, 3836
# Phase: test | Epoch: 4 | Count: 1600 \ Start Time: 02:23:32 | Loss: 59
# start, end:3836, 3900
# start, end:3900, 3964
# start, end:3964, 4028
# start, end:4028, 4092
# start, end:4092, 4156
# start, end:4156, 4220
# start, end:4220, 4284
# start, end:4284, 4348
# start, end:4348, 4412
# start, end:4412, 4476
# start, end:4476, 4540
# start, end:4540, 4604
# start, end:4604, 4668
# start, end:4668, 4732
# start, end:4732, 4796
# start, end:4796, 4860
# start, end:4860, 4924
# start, end:4924, 4988
# start, end:4988, 5052
# start, end:5052, 5116
# start, end:5116, 5180
# start, end:5180, 5244
# start, end:5244, 5308
# start, end:5308, 5372
# start, end:5372, 5436
# Phase: test | Epoch: 4 | Count: 1625 \ Start Time: 02:23:36 | Loss: 60
# start, end:5436, 5500
# start, end:5500, 5564
# start, end:5564, 5628
# start, end:5628, 5692
# start, end:5692, 5756
# start, end:5756, 5820
# start, end:5820, 5884
# start, end:5884, 5948
# start, end:5948, 6012
# start, end:6012, 6076
# start, end:6076, 6140
# start, end:6140, 6204
# start, end:6204, 6268
# start, end:6268, 6332
# start, end:6332, 6396
# start, end:6396, 6460
# start, end:6460, 6524
# start, end:6524, 6588
# start, end:6588, 6652
# start, end:6652, 6716
# start, end:6716, 6780
# start, end:6780, 6844
# start, end:6844, 6908
# start, end:6908, 6972
# start, end:6972, 7036
# Phase: test | Epoch: 4 | Count: 1650 \ Start Time: 02:23:39 | Loss: 59
# start, end:7036, 7100
# start, end:7100, 7164
# start, end:7164, 7228
# start, end:7228, 7292
# start, end:7292, 7356
# start, end:7356, 7420
# start, end:7420, 7484
# start, end:7484, 7548
# start, end:7548, 7612
# start, end:7612, 7676
# start, end:7676, 7740
# start, end:7740, 7804
# start, end:7804, 7868
# start, end:7868, 7932
# start, end:7932, 7996
# start, end:7996, 8060
# start, end:8060, 8124
# start, end:8124, 8188
# start, end:8188, 8252
# start, end:8252, 8316
# start, end:8316, 8380
# start, end:8380, 8444
# start, end:8444, 8508
# start, end:8508, 8572
# start, end:8572, 8636
# Phase: test | Epoch: 4 | Count: 1675 \ Start Time: 02:23:43 | Loss: 59
# start, end:8636, 8700
# start, end:8700, 8764
# start, end:8764, 8828
# start, end:8828, 8892
# start, end:8892, 8956
# start, end:8956, 9020
# start, end:9020, 9084
# start, end:9084, 9148
# start, end:9148, 9212
# start, end:9212, 9276
# start, end:9276, 9340
# start, end:9340, 9404
# start, end:9404, 9468
# start, end:9468, 9532
# start, end:9532, 9596
# start, end:9596, 9660
# start, end:9660, 9724
# start, end:9724, 9788
# start, end:9788, 9852
# start, end:9852, 9916
# start, end:9916, 9980
# start, end:9980, 10044
# start, end:10044, 10108
# start, end:10108, 10172
# start, end:10172, 10236
# Phase: test | Epoch: 4 | Count: 1700 \ Start Time: 02:23:46 | Loss: 60
# start, end:10236, 10300
# start, end:10300, 10364
# start, end:10364, 10428
# start, end:10428, 10492
# start, end:10492, 10556
# start, end:10556, 10620
# start, end:10620, 10684
# start, end:10684, 10748
# start, end:10748, 10812
# start, end:10812, 10876
# start, end:10876, 10940
# start, end:10940, 11004
# start, end:11004, 11068
# start, end:11068, 11132
# start, end:11132, 11196
# start, end:11196, 11260
# start, end:11260, 11324
# start, end:11324, 11388
# start, end:11388, 11452
# start, end:11452, 11516
# start, end:11516, 11580
# start, end:11580, 11644
# start, end:11644, 11708
# start, end:11708, 11772
# start, end:11772, 11836
# Phase: test | Epoch: 4 | Count: 1725 \ Start Time: 02:23:49 | Loss: 60
# start, end:11836, 11900
# start, end:11900, 11964
# start, end:11964, 12028
# start, end:12028, 12092
# start, end:12092, 12156
# start, end:12156, 12220
# start, end:12220, 12284
# start, end:12284, 12348
# start, end:12348, 12412
# start, end:12412, 12476
# start, end:12476, 12540
# start, end:12540, 12604
# start, end:12604, 12668
# start, end:12668, 12732
# start, end:12732, 12796
# start, end:12796, 12860
# start, end:12860, 12924
# start, end:12924, 12988
# start, end:12988, 13052
# start, end:13052, 13116
# start, end:13116, 13180
# start, end:13180, 13244
# start, end:13244, 13308
# start, end:13308, 13372
# start, end:13372, 13436
# Phase: test | Epoch: 4 | Count: 1750 \ Start Time: 02:23:53 | Loss: 59
# start, end:13436, 13500
# start, end:13500, 13564
# start, end:13564, 13628
# start, end:13628, 13692
# start, end:13692, 13756
# start, end:13756, 13820
# start, end:13820, 13884
# start, end:13884, 13948
# start, end:13948, 14012
# start, end:14012, 14076
# start, end:14076, 14140
# start, end:14140, 14204
# start, end:14204, 14268
# start, end:14268, 14332
# start, end:14332, 14396
# start, end:14396, 14460
# start, end:14460, 14524
# start, end:14524, 14588
# start, end:14588, 14652
# start, end:14652, 14716
# start, end:14716, 14780
# start, end:14780, 14844
# start, end:14844, 14908
# start, end:14908, 14972
# start, end:14972, 15036
# Phase: test | Epoch: 4 | Count: 1775 \ Start Time: 02:23:56 | Loss: 59
# start, end:15036, 15100
# start, end:15100, 15164
# start, end:15164, 15228
# start, end:15228, 15292
# start, end:15292, 15356
# start, end:15356, 15420
# start, end:15420, 15484
# start, end:15484, 15548
# start, end:15548, 15612
# start, end:15612, 15676
# start, end:15676, 15740
# ...
# start, end:14840, 14904
# start, end:14904, 14968
# start, end:14968, 15032
# start, end:15032, 15096
# start, end:15096, 15160
# start, end:15160, 15224
# start, end:15224, 15288
# start, end:15288, 15352
# start, end:15352, 15416
# start, end:15416, 15480
# start, end:15480, 15544
# start, end:15544, 15608
# start, end:15608, 15672
# Phase: test | Epoch: 8 | Count: 3325 \ Start Time: 02:27:30 | Loss: 59
# start, end:15672, 15736
# start, end:15736, 15800
# start, end:15800, 15864
# start, end:15864, 15928
# start, end:15928, 15992
# start, end:15992, 16056
# start, end:16056, 16120
# start, end:16120, 16184
# start, end:16184, 16248
# start, end:16248, 16312
# start, end:16312, 16376
# start, end:16376, 16440
# start, end:16440, 16504
# start, end:16504, 16568
# start, end:16568, 16632
# start, end:16632, 16696
# start, end:16696, 16760
# start, end:16760, 16824
# start, end:16824, 16888
# start, end:16888, 16952
# start, end:16952, 17016
# start, end:17016, 17080
# start, end:17080, 17144
# start, end:17144, 17208
# start, end:17208, 17272
# Phase: test | Epoch: 8 | Count: 3350 \ Start Time: 02:27:33 | Loss: 59
# start, end:17272, 17336
# start, end:17336, 17400
# start, end:17400, 17464
# start, end:17464, 17528
# start, end:17528, 17592
# start, end:17592, 17656
# start, end:17656, 17720
# start, end:17720, 17784
# start, end:17784, 17848
# start, end:17848, 17912
# start, end:17912, 17976
# start, end:17976, 18040
# start, end:18040, 18104
# start, end:18104, 18168
# start, end:18168, 18232
# start, end:18232, 18296
# start, end:18296, 18360
# start, end:18360, 18424
# start, end:18424, 18488
# start, end:18488, 18552
# start, end:18552, 18616
# start, end:18616, 18680
# start, end:18680, 18744
# start, end:18744, 18808
# start, end:18808, 18872
# Phase: test | Epoch: 8 | Count: 3375 \ Start Time: 02:27:36 | Loss: 59
# start, end:18872, 18936
# start, end:18936, 19000
# start, end:19000, 19064
# start, end:19064, 19128
# start, end:19128, 19192
# start, end:19192, 19256
# start, end:19256, 19320
# start, end:19320, 19384
# start, end:19384, 19448
# start, end:19448, 19512
# start, end:19512, 19576
# start, end:19576, 19640
# start, end:19640, 19704
# start, end:19704, 19768
# start, end:19768, 19832
# start, end:19832, 19896
# start, end:19896, 19960
# start, end:19960, 20024
# start, end:20024, 20088
# start, end:20088, 20152
# start, end:20152, 20216
# start, end:20216, 20280
# start, end:20280, 20344
# start, end:20344, 20408
# start, end:20408, 20472
# Phase: test | Epoch: 8 | Count: 3400 \ Start Time: 02:27:38 | Loss: 60
# start, end:20472, 20536
# start, end:20536, 20600
# start, end:20600, 20664
# start, end:20664, 20728
# start, end:20728, 20792
# start, end:20792, 20856
# start, end:20856, 20920
# start, end:20920, 20984
# start, end:20984, 21048
# start, end:21048, 21112
# start, end:21112, 21176
# start, end:21176, 21240
# start, end:21240, 21304
# start, end:21304, 21368
# start, end:21368, 21432
# start, end:21432, 21496
# start, end:21496, 21560
# start, end:21560, 21624
# start, end:21624, 21688
# start, end:21688, 21752
# start, end:21752, 21816
# start, end:21816, 21880
# start, end:21880, 21944
# start, end:21944, 22008
# start, end:22008, 22072
# Phase: test | Epoch: 8 | Count: 3425 \ Start Time: 02:27:41 | Loss: 59
# start, end:22072, 22136
# start, end:22136, 22200
# start, end:22200, 22264
# start, end:22264, 22328
# start, end:22328, 22392
# start, end:22392, 22456
# start, end:22456, 22520
# start, end:22520, 22584
# start, end:22584, 22648
# start, end:22648, 22712
# start, end:22712, 22776
# start, end:22776, 22840
# start, end:22840, 22904
# start, end:22904, 22968
# start, end:22968, 23032
# start, end:23032, 23096
# start, end:23096, 23160
# start, end:23160, 23224
# start, end:23224, 23288
# start, end:23288, 23352
# start, end:23352, 23416
# start, end:23416, 23480
# start, end:23480, 23544
# start, end:23544, 23608
# start, end:23608, 23672
# Phase: test | Epoch: 8 | Count: 3450 \ Start Time: 02:27:44 | Loss: 59
# start, end:23672, 23736
# start, end:23736, 23800
# start, end:23800, 23864
# start, end:23864, 23928
# start, end:23928, 23992
# start, end:23992, 24056
# start, end:24056, 24120
# start, end:24120, 24184
# start, end:24184, 24248
# start, end:24248, 24312
# start, end:24312, 24376
# start, end:24376, 24440
# start, end:24440, 24504
# start, end:24504, 24568
# start, end:24568, 24632
# start, end:0, 55
# start, end:55, 119
# start, end:119, 183
# start, end:183, 247
# start, end:247, 311
# start, end:311, 375
# start, end:375, 439
# start, end:439, 503
# start, end:503, 567
# start, end:567, 631
# Phase: test | Epoch: 9 | Count: 3475 \ Start Time: 02:27:46 | Loss: 59
# start, end:631, 695
# start, end:695, 759
# start, end:759, 823
# start, end:823, 887
# start, end:887, 951
# start, end:951, 1015
# start, end:1015, 1079
# start, end:1079, 1143
# start, end:1143, 1207
# start, end:1207, 1271
# start, end:1271, 1335
# start, end:1335, 1399
# start, end:1399, 1463
# start, end:1463, 1527
# start, end:1527, 1591
# start, end:1591, 1655
# start, end:1655, 1719
# start, end:1719, 1783
# start, end:1783, 1847
# start, end:1847, 1911
# start, end:1911, 1975
# start, end:1975, 2039
# start, end:2039, 2103
# start, end:2103, 2167
# start, end:2167, 2231
# Phase: test | Epoch: 9 | Count: 3500 \ Start Time: 02:27:49 | Loss: 60
# start, end:2231, 2295
# start, end:2295, 2359
# start, end:2359, 2423
# start, end:2423, 2487
# start, end:2487, 2551
# start, end:2551, 2615
# start, end:2615, 2679
# start, end:2679, 2743
# start, end:2743, 2807
# start, end:2807, 2871
# start, end:2871, 2935
# start, end:2935, 2999
# start, end:2999, 3063
# start, end:3063, 3127
# start, end:3127, 3191
# start, end:3191, 3255
# start, end:3255, 3319
# start, end:3319, 3383
# start, end:3383, 3447
# start, end:3447, 3511
# start, end:3511, 3575
# start, end:3575, 3639
# start, end:3639, 3703
# start, end:3703, 3767
# start, end:3767, 3831
# Phase: test | Epoch: 9 | Count: 3525 \ Start Time: 02:27:51 | Loss: 59
# start, end:3831, 3895
# start, end:3895, 3959
# start, end:3959, 4023
# start, end:4023, 4087
# start, end:4087, 4151
# start, end:4151, 4215
# start, end:4215, 4279
# start, end:4279, 4343
# start, end:4343, 4407
# start, end:4407, 4471
# start, end:4471, 4535
# start, end:4535, 4599
# start, end:4599, 4663
# start, end:4663, 4727
# start, end:4727, 4791
# start, end:4791, 4855
# start, end:4855, 4919
# start, end:4919, 4983
# start, end:4983, 5047
# start, end:5047, 5111
# start, end:5111, 5175
# start, end:5175, 5239
# start, end:5239, 5303
# start, end:5303, 5367
# start, end:5367, 5431
# Phase: test | Epoch: 9 | Count: 3550 \ Start Time: 02:27:54 | Loss: 60
# start, end:5431, 5495
# start, end:5495, 5559
# start, end:5559, 5623
# start, end:5623, 5687
# start, end:5687, 5751
# start, end:5751, 5815
# start, end:5815, 5879
# start, end:5879, 5943
# start, end:5943, 6007
# start, end:6007, 6071
# start, end:6071, 6135
# start, end:6135, 6199
# start, end:6199, 6263
# start, end:6263, 6327
# start, end:6327, 6391
# start, end:6391, 6455
# start, end:6455, 6519
# start, end:6519, 6583
# start, end:6583, 6647
# start, end:6647, 6711
# start, end:6711, 6775
# start, end:6775, 6839
# start, end:6839, 6903
# start, end:6903, 6967
# start, end:6967, 7031
# Phase: test | Epoch: 9 | Count: 3575 \ Start Time: 02:27:56 | Loss: 59
# start, end:7031, 7095
# start, end:7095, 7159
# start, end:7159, 7223
# start, end:7223, 7287
# start, end:7287, 7351
# start, end:7351, 7415
# start, end:7415, 7479
# start, end:7479, 7543
# start, end:7543, 7607
# start, end:7607, 7671
# start, end:7671, 7735
# start, end:7735, 7799
# start, end:7799, 7863
# start, end:7863, 7927
# start, end:7927, 7991
# start, end:7991, 8055
# start, end:8055, 8119
# start, end:8119, 8183
# start, end:8183, 8247
# start, end:8247, 8311
# start, end:8311, 8375
# start, end:8375, 8439
# start, end:8439, 8503
# start, end:8503, 8567
# start, end:8567, 8631
# Phase: test | Epoch: 9 | Count: 3600 \ Start Time: 02:27:58 | Loss: 59
# start, end:8631, 8695
# start, end:8695, 8759
# start, end:8759, 8823
# start, end:8823, 8887
# start, end:8887, 8951
# start, end:8951, 9015
# start, end:9015, 9079
# start, end:9079, 9143
# start, end:9143, 9207
# start, end:9207, 9271
# start, end:9271, 9335
# start, end:9335, 9399
# start, end:9399, 9463
# start, end:9463, 9527
# start, end:9527, 9591
# start, end:9591, 9655
# start, end:9655, 9719
# start, end:9719, 9783
# start, end:9783, 9847
# start, end:9847, 9911
# start, end:9911, 9975
# start, end:9975, 10039
# start, end:10039, 10103
# start, end:10103, 10167
# start, end:10167, 10231
# Phase: test | Epoch: 9 | Count: 3625 \ Start Time: 02:28:00 | Loss: 59
# start, end:10231, 10295
# start, end:10295, 10359
# start, end:10359, 10423
# start, end:10423, 10487
# start, end:10487, 10551
# start, end:10551, 10615
# start, end:10615, 10679
# start, end:10679, 10743
# start, end:10743, 10807
# start, end:10807, 10871
# start, end:10871, 10935
# start, end:10935, 10999
# start, end:10999, 11063
# start, end:11063, 11127
# start, end:11127, 11191
# start, end:11191, 11255
# start, end:11255, 11319
# start, end:11319, 11383
# start, end:11383, 11447
# start, end:11447, 11511
# start, end:11511, 11575
# start, end:11575, 11639
# start, end:11639, 11703
# start, end:11703, 11767
# start, end:11767, 11831
# Phase: test | Epoch: 9 | Count: 3650 \ Start Time: 02:28:03 | Loss: 60
# start, end:11831, 11895
# start, end:11895, 11959
# start, end:11959, 12023
# start, end:12023, 12087
# start, end:12087, 12151
# start, end:12151, 12215
# start, end:12215, 12279
# start, end:12279, 12343
# start, end:12343, 12407
# start, end:12407, 12471
# start, end:12471, 12535
# start, end:12535, 12599
# start, end:12599, 12663
# start, end:12663, 12727
# start, end:12727, 12791
# start, end:12791, 12855
# start, end:12855, 12919
# start, end:12919, 12983
# start, end:12983, 13047
# start, end:13047, 13111
# start, end:13111, 13175
# start, end:13175, 13239
# start, end:13239, 13303
# start, end:13303, 13367
# start, end:13367, 13431
# Phase: test | Epoch: 9 | Count: 3675 \ Start Time: 02:28:05 | Loss: 59
# start, end:13431, 13495
# start, end:13495, 13559
# start, end:13559, 13623
# start, end:13623, 13687
# start, end:13687, 13751
# start, end:13751, 13815
# start, end:13815, 13879
# start, end:13879, 13943
# start, end:13943, 14007
# start, end:14007, 14071
# start, end:14071, 14135
# start, end:14135, 14199
# start, end:14199, 14263
# start, end:14263, 14327
# start, end:14327, 14391
# start, end:14391, 14455
# start, end:14455, 14519
# start, end:14519, 14583
# start, end:14583, 14647
# start, end:14647, 14711
# start, end:14711, 14775
# start, end:14775, 14839
# start, end:14839, 14903
# start, end:14903, 14967
# start, end:14967, 15031
# Phase: test | Epoch: 9 | Count: 3700 \ Start Time: 02:28:07 | Loss: 59
# start, end:15031, 15095
# start, end:15095, 15159
# start, end:15159, 15223
# start, end:15223, 15287
# start, end:15287, 15351
# start, end:15351, 15415
# start, end:15415, 15479
# start, end:15479, 15543
# start, end:15543, 15607
# start, end:15607, 15671
# start, end:15671, 15735
# start, end:15735, 15799
# start, end:15799, 15863
# start, end:15863, 15927
# start, end:15927, 15991
# start, end:15991, 16055
# start, end:16055, 16119
# start, end:16119, 16183
# start, end:16183, 16247
# start, end:16247, 16311
# start, end:16311, 16375
# start, end:16375, 16439
# start, end:16439, 16503
# start, end:16503, 16567
# start, end:16567, 16631
# Phase: test | Epoch: 9 | Count: 3725 \ Start Time: 02:28:10 | Loss: 59
# start, end:16631, 16695
# start, end:16695, 16759
# start, end:16759, 16823
# start, end:16823, 16887
# start, end:16887, 16951
# start, end:16951, 17015
# start, end:17015, 17079
# start, end:17079, 17143
# start, end:17143, 17207
# start, end:17207, 17271
# start, end:17271, 17335
# start, end:17335, 17399
# start, end:17399, 17463
# start, end:17463, 17527
# start, end:17527, 17591
# start, end:17591, 17655
# start, end:17655, 17719
# start, end:17719, 17783
# start, end:17783, 17847
# start, end:17847, 17911
# start, end:17911, 17975
# start, end:17975, 18039
# start, end:18039, 18103
# start, end:18103, 18167
# start, end:18167, 18231
# Phase: test | Epoch: 9 | Count: 3750 \ Start Time: 02:28:12 | Loss: 59
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3750_test_0.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3750_test_1.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3750_test_2.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3750_test_3.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3750_test_4.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3750_test_5.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3750_test_6.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3750_test_7.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3750_test_8.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3750_test_9.png
# start, end:18231, 18295
# start, end:18295, 18359
# start, end:18359, 18423
# start, end:18423, 18487
# start, end:18487, 18551
# start, end:18551, 18615
# start, end:18615, 18679
# start, end:18679, 18743
# start, end:18743, 18807
# start, end:18807, 18871
# start, end:18871, 18935
# start, end:18935, 18999
# start, end:18999, 19063
# start, end:19063, 19127
# start, end:19127, 19191
# start, end:19191, 19255
# start, end:19255, 19319
# start, end:19319, 19383
# start, end:19383, 19447
# start, end:19447, 19511
# start, end:19511, 19575
# start, end:19575, 19639
# start, end:19639, 19703
# start, end:19703, 19767
# start, end:19767, 19831
# Phase: test | Epoch: 9 | Count: 3775 \ Start Time: 02:28:16 | Loss: 59
# start, end:19831, 19895
# start, end:19895, 19959
# start, end:19959, 20023
# start, end:20023, 20087
# start, end:20087, 20151
# start, end:20151, 20215
# start, end:20215, 20279
# start, end:20279, 20343
# start, end:20343, 20407
# start, end:20407, 20471
# start, end:20471, 20535
# start, end:20535, 20599
# start, end:20599, 20663
# start, end:20663, 20727
# start, end:20727, 20791
# start, end:20791, 20855
# start, end:20855, 20919
# start, end:20919, 20983
# start, end:20983, 21047
# start, end:21047, 21111
# start, end:21111, 21175
# start, end:21175, 21239
# start, end:21239, 21303
# start, end:21303, 21367
# start, end:21367, 21431
# Phase: test | Epoch: 9 | Count: 3800 \ Start Time: 02:28:18 | Loss: 59
# start, end:21431, 21495
# start, end:21495, 21559
# start, end:21559, 21623
# start, end:21623, 21687
# start, end:21687, 21751
# start, end:21751, 21815
# start, end:21815, 21879
# start, end:21879, 21943
# start, end:21943, 22007
# start, end:22007, 22071
# start, end:22071, 22135
# start, end:22135, 22199
# start, end:22199, 22263
# start, end:22263, 22327
# start, end:22327, 22391
# start, end:22391, 22455
# start, end:22455, 22519
# start, end:22519, 22583
# start, end:22583, 22647
# start, end:22647, 22711
# start, end:22711, 22775
# start, end:22775, 22839
# start, end:22839, 22903
# start, end:22903, 22967
# start, end:22967, 23031
# Phase: test | Epoch: 9 | Count: 3825 \ Start Time: 02:28:20 | Loss: 59
# start, end:23031, 23095
# start, end:23095, 23159
# start, end:23159, 23223
# start, end:23223, 23287
# start, end:23287, 23351
# start, end:23351, 23415
# start, end:23415, 23479
# start, end:23479, 23543
# start, end:23543, 23607
# start, end:23607, 23671
# start, end:23671, 23735
# start, end:23735, 23799
# start, end:23799, 23863
# start, end:23863, 23927
# start, end:23927, 23991
# start, end:23991, 24055
# start, end:24055, 24119
# start, end:24119, 24183
# start, end:24183, 24247
# start, end:24247, 24311
# start, end:24311, 24375
# start, end:24375, 24439
# start, end:24439, 24503
# start, end:24503, 24567
# start, end:24567, 24631
# Phase: test | Epoch: 9 | Count: 3850 \ Start Time: 02:28:22 | Loss: 59
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3850_test_0.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3850_test_1.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3850_test_2.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3850_test_3.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3850_test_4.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3850_test_5.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3850_test_6.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3850_test_7.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3850_test_8.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_3850_test_9.png

# %% [markdown]
# ## Idx Validation

# %%
# Loading model
model = load_model(T, A, B, batch_size, z_size, N, dec_size, enc_size, learning_rate, beta1, clip, path, category)
model.eval()
# Out:
# DRAW(
#   (encoder): LSTMCell(306, 256)
#   (mu_linear): Linear(in_features=256, out_features=10, bias=True)
#   (sigma_linear): Linear(in_features=256, out_features=10, bias=True)
#   (decoder): LSTMCell(10, 256)
#   (dec_linear): Linear(in_features=256, out_features=5, bias=True)
#   (dec_w_linear): Linear(in_features=256, out_features=25, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
batch_size = 64

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (98561, 784)
# (24641, 784)

# %%
print('There are ', len(npy_data), ' images in selected database')
print("Enter image index from 0 to", len(npy_data)-1, "to display and compare bitmap and raw images:")
index=int(input())
# Out:
# There are  123202  images in selected database
# Enter image index from 0 to 123201 to display and compare bitmap and raw images:
# 0

# %%
def plot_bitmap():
    print("Bitmap image:")
    plt.imshow(npy_data[int(index)].reshape(28,28))
    plt.show()

def plot_raw():
    print("Raw image:")
    i = 0
    for stroke in ndjson_data[int(index)]['drawing']:
        stroke = np.array(stroke)
        plt.plot(stroke[0], stroke[1]*-1)
        i += 1
    plt.show()
    print('There are', i, 'number of strokes in this raw image file!')
    print('Image key id:', ndjson_data[int(index)]['key_id'])

# %%
plot_bitmap()
# Out:
# Bitmap image:

# %%
plot_raw()
# Out:
# Raw image:
# There are 9 number of strokes in this raw image file!
# Image key id: 5201136883597312

# %%
def validate():    
    print("validating...")
    img_loc = {'startr':0,
               'endr':30,
               'startc':0,
               'endc':30}   
    avg_loss = 0
    count = 0
    data = npy_data[index:index+64]
    data = np.reshape(data, (data.shape[0], 1, A, B))
    data = torch.Tensor(data)
    bs = data.size()[0]
    data = Variable(data).view(bs, -1)
    print('data.shape', data.shape)
    loss = model.loss(data)
    avg_loss += loss.cpu().data.numpy()
      
    
    xrecons_grid(batch_size, B, A, T, category, model, img_loc, count=0)

# %%
validate()
# Out:
# validating...
# data.shape torch.Size([64, 784])
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_0_test_0.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_0_test_1.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_0_test_2.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_0_test_3.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_0_test_4.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_0_test_5.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_0_test_6.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_0_test_7.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_0_test_8.png
# C:\Users\ozgur\Desktop\sandbox\sliver-maestro\src\data\output\images\cat\cat_0_test_9.png
